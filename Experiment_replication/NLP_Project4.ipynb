# %%
# !pip install OpenNMT-py
# Out:
# Collecting OpenNMT-py
#   Downloading OpenNMT_py-2.2.0-py3-none-any.whl (216 kB)
#      |████████████████████████████████| 216 kB 4.9 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (3.13)
# Collecting torchtext==0.5.0
#   Downloading torchtext-0.5.0-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.7 MB/s
# Requirement already satisfied: tensorboard>=2.3 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (2.8.0)
# Collecting waitress
#   Downloading waitress-2.1.1-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.3 MB/s
# Collecting configargparse
#   Downloading ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (1.10.0+cu111)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (1.1.4)
# Collecting pyonmttok<2,>=1.23
#   Downloading pyonmttok-1.31.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (16.6 MB)
#      |████████████████████████████████| 16.6 MB 280 kB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (4.63.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (1.21.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 41.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (57.4.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.44.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.3->OpenNMT-py) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.3->OpenNMT-py) (4.11.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.3->OpenNMT-py) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.3->OpenNMT-py) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.3->OpenNMT-py) (3.2.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->OpenNMT-py) (2.0.1)
# Installing collected packages: sentencepiece, waitress, torchtext, pyonmttok, configargparse, OpenNMT-py
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.11.0
#     Uninstalling torchtext-0.11.0:
#       Successfully uninstalled torchtext-0.11.0
# Successfully installed OpenNMT-py-2.2.0 configargparse-1.5.3 pyonmttok-1.31.0 sentencepiece-0.1.96 torchtext-0.5.0 waitress-2.1.1

# %%
# !onmt_build_vocab -config config-exp1.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-03-19 08:37:28,833 INFO] Counter vocab from 10000 samples.
# [2022-03-19 08:37:28,833 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-03-19 08:37:28,846 INFO] corpus_1's transforms: TransformPipe()
# [2022-03-19 08:37:28,949 INFO] Counters src:38
# [2022-03-19 08:37:28,949 INFO] Counters tgt:38

# %%
# !onmt_train -config config-exp1.yaml
# Out:
# [2022-03-19 08:39:28,265 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-03-19 08:39:28,265 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-03-19 08:39:28,265 INFO] Missing transforms field for valid data, set to default: [].
# [2022-03-19 08:39:28,265 INFO] Parsed 2 corpora from -data.
# [2022-03-19 08:39:28,265 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-03-19 08:39:28,265 INFO] Loading vocab from text file...
# [2022-03-19 08:39:28,265 INFO] Loading src vocabulary from experiment_1/run/example.vocab.src
# [2022-03-19 08:39:28,266 INFO] Loaded src vocab has 38 tokens.
# [2022-03-19 08:39:28,266 INFO] Loading tgt vocabulary from experiment_1/run/example.vocab.tgt
# [2022-03-19 08:39:28,266 INFO] Loaded tgt vocab has 38 tokens.
# [2022-03-19 08:39:28,266 INFO] Building fields with vocab in counters...
# [2022-03-19 08:39:28,266 INFO]  * tgt vocab size: 42.
# [2022-03-19 08:39:28,267 INFO]  * src vocab size: 40.
# [2022-03-19 08:39:28,267 INFO]  * src vocab size = 40
# [2022-03-19 08:39:28,267 INFO]  * tgt vocab size = 42
# [2022-03-19 08:39:28,268 INFO] Building model...
# [2022-03-19 08:39:36,700 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(40, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(42, 500, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
#       (linear_in): Linear(in_features=500, out_features=500, bias=False)
#       (linear_out): Linear(in_features=1000, out_features=500, bias=False)
#     )
#   )
#   (generator): Sequential(
#     (0): Linear(in_features=500, out_features=42, bias=True)
#     (1): Cast()
#     (2): LogSoftmax(dim=-1)
#   )
# )
# [2022-03-19 08:39:36,701 INFO] encoder: 4028000
# [2022-03-19 08:39:36,701 INFO] decoder: 5800042
# [2022-03-19 08:39:36,701 INFO] * number of parameters: 9828042
# [2022-03-19 08:39:36,702 INFO] Starting training on GPU: [0]
# [2022-03-19 08:39:36,702 INFO] Start training loop and validate every 500 steps...
# [2022-03-19 08:39:36,702 INFO] corpus_1's transforms: TransformPipe()
# [2022-03-19 08:39:36,702 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2022-03-19 08:39:38,572 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2022-03-19 08:39:39,507 INFO] Step 50/ 1000; acc:  12.43; ppl: 110.96; xent: 4.71; lr: 1.00000; 6886/9146 tok/s;      3 sec
# [2022-03-19 08:39:41,963 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2022-03-19 08:39:42,215 INFO] Step 100/ 1000; acc:  16.99; ppl: 57.17; xent: 4.05; lr: 1.00000; 7422/9884 tok/s;      6 sec
# [2022-03-19 08:39:43,653 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2022-03-19 08:39:44,812 INFO] Step 150/ 1000; acc:  24.10; ppl: 27.65; xent: 3.32; lr: 1.00000; 7517/9936 tok/s;      8 sec
# [2022-03-19 08:39:46,988 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2022-03-19 08:39:47,459 INFO] Step 200/ 1000; acc:  34.54; ppl: 14.79; xent: 2.69; lr: 1.00000; 7489/9995 tok/s;     11 sec
# [2022-03-19 08:39:48,679 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2022-03-19 08:39:50,060 INFO] Step 250/ 1000; acc:  50.91; ppl:  6.47; xent: 1.87; lr: 1.00000; 7443/9865 tok/s;     13 sec
# [2022-03-19 08:39:52,055 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 7
# [2022-03-19 08:39:52,716 INFO] Step 300/ 1000; acc:  71.80; ppl:  2.91; xent: 1.07; lr: 1.00000; 7387/9889 tok/s;     16 sec
# [2022-03-19 08:39:55,299 INFO] Step 350/ 1000; acc:  91.15; ppl:  1.42; xent: 0.35; lr: 1.00000; 7542/10006 tok/s;     19 sec
# [2022-03-19 08:39:55,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 8
# [2022-03-19 08:39:57,100 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9
# [2022-03-19 08:39:57,972 INFO] Step 400/ 1000; acc:  94.63; ppl:  1.27; xent: 0.24; lr: 1.00000; 7372/9733 tok/s;     21 sec
# [2022-03-19 08:40:00,483 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 10
# [2022-03-19 08:40:00,648 INFO] Step 450/ 1000; acc:  98.27; ppl:  1.08; xent: 0.08; lr: 1.00000; 7486/9999 tok/s;     24 sec
# [2022-03-19 08:40:02,179 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 11
# [2022-03-19 08:40:03,231 INFO] Step 500/ 1000; acc:  98.51; ppl:  1.07; xent: 0.07; lr: 1.00000; 7432/9875 tok/s;     27 sec
# [2022-03-19 08:40:03,231 INFO] valid's transforms: TransformPipe()
# [2022-03-19 08:40:03,498 INFO] Validation perplexity: 1.08896
# [2022-03-19 08:40:03,499 INFO] Validation accuracy: 98.4708
# [2022-03-19 08:40:03,499 INFO] Saving checkpoint experiment_1/run/model_step_500.pt
# [2022-03-19 08:40:05,851 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 12
# [2022-03-19 08:40:06,273 INFO] Step 550/ 1000; acc:  99.07; ppl:  1.04; xent: 0.04; lr: 1.00000; 6643/8821 tok/s;     30 sec
# [2022-03-19 08:40:07,590 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 13
# [2022-03-19 08:40:08,851 INFO] Step 600/ 1000; acc:  99.10; ppl:  1.04; xent: 0.04; lr: 1.00000; 7456/9913 tok/s;     32 sec
# [2022-03-19 08:40:10,961 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 14
# [2022-03-19 08:40:11,515 INFO] Step 650/ 1000; acc:  99.06; ppl:  1.04; xent: 0.03; lr: 1.00000; 7384/9874 tok/s;     35 sec
# [2022-03-19 08:40:14,114 INFO] Step 700/ 1000; acc:  99.26; ppl:  1.03; xent: 0.03; lr: 1.00000; 7451/9882 tok/s;     37 sec
# [2022-03-19 08:40:14,315 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 15
# [2022-03-19 08:40:16,041 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 16
# [2022-03-19 08:40:16,794 INFO] Step 750/ 1000; acc:  99.32; ppl:  1.02; xent: 0.02; lr: 1.00000; 7401/9819 tok/s;     40 sec
# [2022-03-19 08:40:19,400 INFO] Step 800/ 1000; acc:  99.40; ppl:  1.02; xent: 0.02; lr: 1.00000; 7546/10030 tok/s;     43 sec
# [2022-03-19 08:40:19,402 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 17
# [2022-03-19 08:40:21,096 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 18
# [2022-03-19 08:40:22,022 INFO] Step 850/ 1000; acc:  99.45; ppl:  1.02; xent: 0.02; lr: 1.00000; 7383/9821 tok/s;     45 sec
# [2022-03-19 08:40:24,501 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 19
# [2022-03-19 08:40:24,751 INFO] Step 900/ 1000; acc:  99.73; ppl:  1.01; xent: 0.01; lr: 1.00000; 7348/9772 tok/s;     48 sec
# [2022-03-19 08:40:26,191 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 20
# [2022-03-19 08:40:27,362 INFO] Step 950/ 1000; acc:  99.59; ppl:  1.01; xent: 0.01; lr: 1.00000; 7467/9897 tok/s;     51 sec
# [2022-03-19 08:40:29,552 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 21
# [2022-03-19 08:40:30,023 INFO] Step 1000/ 1000; acc:  99.69; ppl:  1.01; xent: 0.01; lr: 1.00000; 7476/9957 tok/s;     53 sec
# [2022-03-19 08:40:30,291 INFO] Validation perplexity: 1.07534
# [2022-03-19 08:40:30,291 INFO] Validation accuracy: 99.0705
# [2022-03-19 08:40:30,292 INFO] Saving checkpoint experiment_1/run/model_step_1000.pt

# %%
# !onmt_translate -model experiment_1/run/model_step_1000.pt -src experiment_1/src_test.txt -output experiment_1/test-decoded.txt -gpu 0 -verbose -beam_size 12
# Out:
# [2022-03-19 08:50:08,512 INFO] Translating shard 0.
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:282: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   self._batch_index = self.topk_ids // vocab_size
# [2022-03-19 08:50:08,674 INFO]
# SENT 1: ['k', 'l', 'O', 'z', 'I', 't']
# PRED 1: k l O z I t I d
# PRED SCORE: -0.0136
#
# [2022-03-19 08:50:08,674 INFO]
# SENT 2: ['p', '@', 'U', 's', 't']
# PRED 2: p @ U s t I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:08,674 INFO]
# SENT 3: ['v', '&', 'l', 'j', 'U']
# PRED 3: v & l j U d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:08,674 INFO]
# SENT 4: ['I', 'N', 'k', 'A', ':', 's', '@', 'r', 'e', 'I', 't']
# PRED 4: I N k A : s @ r e I t I d
# PRED SCORE: -0.0027
#
# [2022-03-19 08:50:08,675 INFO]
# SENT 5: ['f', 'I', 'd', 'Z', 'I', 't']
# PRED 5: f I d Z I t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:08,675 INFO]
# SENT 6: ['m', '@', 'U', 't', '@', 'r', 'a', 'I', 'z']
# PRED 6: m @ U t @ r a I z d
# PRED SCORE: -0.0044
#
# [2022-03-19 08:50:08,675 INFO]
# SENT 7: ['v', 'E', 'd', 'Z', '@', 't', 'e', 'I', 't']
# PRED 7: v E d Z @ t e I t I d
# PRED SCORE: -0.0323
#
# [2022-03-19 08:50:08,675 INFO]
# SENT 8: ['m', 'e', 'I', 'm']
# PRED 8: m e I m d
# PRED SCORE: -0.0000
#
# [2022-03-19 08:50:08,676 INFO]
# SENT 9: ['t', 'i', ':', 'z']
# PRED 9: t i : z d
# PRED SCORE: -0.0060
#
# [2022-03-19 08:50:08,676 INFO]
# SENT 10: ['I', 'N', 'k', '@', 'n', 'v', 'i', ':', 'n', 'I', '@', 'n', 's']
# PRED 10: I N k @ n v i : n I @ n d
# PRED SCORE: -0.7042
#
# [2022-03-19 08:50:08,676 INFO]
# SENT 11: ['@', 'p', 'E', 'n', 'd']
# PRED 11: @ p E n d I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:08,676 INFO]
# SENT 12: ['t', 'r', 'I', 'g', '@', 'r', '*']
# PRED 12: t r I g @ d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:08,676 INFO]
# SENT 13: ['@', 'b', 'z', 't', 'r', 'V', 'k', 't']
# PRED 13: @ b z t r V k t I d
# PRED SCORE: -0.0048
#
# [2022-03-19 08:50:08,677 INFO]
# SENT 14: ['k', 'a', 'U', 'n', 's', 'l', ',']
# PRED 14: k a U n s l , d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:08,677 INFO]
# SENT 15: ['d', 'I', 's', 'O', 'r', 'I', '@', 'n', 't']
# PRED 15: d I s O r I @ n t I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:08,677 INFO]
# SENT 16: ['S', 'E', 'l', 'v']
# PRED 16: S E l v d
# PRED SCORE: -0.0021
#
# [2022-03-19 08:50:08,677 INFO]
# SENT 17: ['s', 't', 'I', 'l']
# PRED 17: s t V l d
# PRED SCORE: -1.0278
#
# [2022-03-19 08:50:08,678 INFO]
# SENT 18: ['@', 'd', 'Z', 'V', 's', 't']
# PRED 18: @ d Z V s t I d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:08,678 INFO]
# SENT 19: ['r', '@', 'z', '3', ':', 'v']
# PRED 19: r @ z 3 : v d
# PRED SCORE: -0.0035
#
# [2022-03-19 08:50:08,678 INFO]
# SENT 20: ['n', '&', 'g']
# PRED 20: n & g d
# PRED SCORE: -0.0091
#
# [2022-03-19 08:50:08,678 INFO]
# SENT 21: ['p', '@', 't', 'I', 'k', 'j', '@', 'l', '@', 'r', 'a', 'I', 'z']
# PRED 21: p @ t I k j @ l @ r a I z d
# PRED SCORE: -0.3951
#
# [2022-03-19 08:50:08,678 INFO]
# SENT 22: ['w', 'O', ':', 't', '@', 'r', '*']
# PRED 22: w O : t @ d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,679 INFO]
# SENT 23: ['h', 'V', 'N', 'g', '@', 'r', '*']
# PRED 23: h V N g @ d
# PRED SCORE: -0.0025
#
# [2022-03-19 08:50:08,679 INFO]
# SENT 24: ['t', 'S', '3', ':', 'n']
# PRED 24: t S 3 : n d
# PRED SCORE: -0.0021
#
# [2022-03-19 08:50:08,679 INFO]
# SENT 25: ['t', 'I', 'p']
# PRED 25: t I p t
# PRED SCORE: -0.0391
#
# [2022-03-19 08:50:08,679 INFO]
# SENT 26: ['b', 'r', '&', 'n', 'd', 'I', 'S']
# PRED 26: b r & n d I S t
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:08,679 INFO]
# SENT 27: ['k', 'e', 'I', 'd', 'Z']
# PRED 27: k e I d Z d
# PRED SCORE: -0.0000
#
# [2022-03-19 08:50:08,680 INFO]
# SENT 28: ['E', 'g', 'z', '&', 'k', 't']
# PRED 28: E g z & k t I d
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:08,680 INFO]
# SENT 29: ['k', 'r', 'a', 'U', 'n']
# PRED 29: k r a U n d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:08,680 INFO]
# SENT 30: ['d', 'I', 'f', 'O', 'l', 't']
# PRED 30: d I f O l t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,814 INFO]
# SENT 31: ['I', 'k', 'w', 'I', 'v', 'U', 'k', 'e', 'I', 't']
# PRED 31: I k w I v U k e I t I d
# PRED SCORE: -0.0571
#
# [2022-03-19 08:50:08,815 INFO]
# SENT 32: ['s', 'I', 'g', 'n', 'I', 'f', 'a', 'I']
# PRED 32: s I g n I f a I d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:08,815 INFO]
# SENT 33: ['w', 'U', 'l', 'f']
# PRED 33: w U l f t
# PRED SCORE: -0.0203
#
# [2022-03-19 08:50:08,815 INFO]
# SENT 34: ['s', '@', 'r', 'a', 'U', 'n', 'd']
# PRED 34: s @ r a U n d I d
# PRED SCORE: -0.0102
#
# [2022-03-19 08:50:08,815 INFO]
# SENT 35: ['s', 'l', 'e', 'I', 't']
# PRED 35: s l e I t I d
# PRED SCORE: -0.0000
#
# [2022-03-19 08:50:08,816 INFO]
# SENT 36: ['m', 'E', 'm', 'r', 'a', 'I', 'z']
# PRED 36: m E m r a I z d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:08,816 INFO]
# SENT 37: ['r', 'a', 'I', 'D']
# PRED 37: r a I D d
# PRED SCORE: -0.0489
#
# [2022-03-19 08:50:08,816 INFO]
# SENT 38: ['@', 'p', 'r', 'a', 'I', 'z']
# PRED 38: @ p r a I z d
# PRED SCORE: -0.0023
#
# [2022-03-19 08:50:08,816 INFO]
# SENT 39: ['l', 'I', 'k']
# PRED 39: l I k t
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:08,816 INFO]
# SENT 40: ['r', '@', 'z', 'a', 'I', 'n']
# PRED 40: r @ z a I n d
# PRED SCORE: -0.0037
#
# [2022-03-19 08:50:08,817 INFO]
# SENT 41: ['h', 'V', 'm']
# PRED 41: h V m d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:08,817 INFO]
# SENT 42: ['d', 'r', 'e', 'I', 'p']
# PRED 42: d r e I p t
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:08,817 INFO]
# SENT 43: ['&', 'n', '@', 't', 'e', 'I', 't']
# PRED 43: & n @ t e I t I d
# PRED SCORE: -0.0084
#
# [2022-03-19 08:50:08,817 INFO]
# SENT 44: ['S', '&', 'd', '@', 'U']
# PRED 44: S & d @ U d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:08,818 INFO]
# SENT 45: ['E', 'k', 's', 'I', 'l', '@', 'r', 'e', 'I', 't']
# PRED 45: E k s I l @ r e I t I d
# PRED SCORE: -0.0076
#
# [2022-03-19 08:50:08,818 INFO]
# SENT 46: ['f', 'O', ':', 'S', '&', 'd', '@', 'U']
# PRED 46: f O : S & d @ U d
# PRED SCORE: -0.0068
#
# [2022-03-19 08:50:08,818 INFO]
# SENT 47: ['s', 'I', 'N', 'k']
# PRED 47: s I N k t
# PRED SCORE: -0.1450
#
# [2022-03-19 08:50:08,818 INFO]
# SENT 48: ['r', 'i', ':', 't', 'S', 'A', ':', 'd', 'Z']
# PRED 48: r i : t S A : d Z d
# PRED SCORE: -0.0010
#
# [2022-03-19 08:50:08,819 INFO]
# SENT 49: ['k', '@', 'n', 'd', 'E', 'm']
# PRED 49: k @ n d E m d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:08,819 INFO]
# SENT 50: ['d', 'I', 't', 'E', 's', 't']
# PRED 50: d I t E s t I d
# PRED SCORE: -0.0041
#
# [2022-03-19 08:50:08,819 INFO]
# SENT 51: ['k', '&', 'p']
# PRED 51: k & p t
# PRED SCORE: -0.0018
#
# [2022-03-19 08:50:08,819 INFO]
# SENT 52: ['d', 'Z', 'O', 'I', 'n']
# PRED 52: d Z O I n d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:08,819 INFO]
# SENT 53: ['E', 'k', 's', 'p', 'E', 'r', 'I', 'm', '@', 'n', 't']
# PRED 53: E k s p E r I m @ n t I d
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:08,820 INFO]
# SENT 54: ['p', 'E', 's', 't', '@', 'r', '*']
# PRED 54: p E s t @ d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:08,820 INFO]
# SENT 55: ['s', 't', '&', 'b']
# PRED 55: s t & b d
# PRED SCORE: -0.0422
#
# [2022-03-19 08:50:08,820 INFO]
# SENT 56: ['t', 'S', 'i', ':', 'k']
# PRED 56: t S i : k t
# PRED SCORE: -0.0032
#
# [2022-03-19 08:50:08,820 INFO]
# SENT 57: ['v', 'E', 'n', 'd']
# PRED 57: v E n d I d
# PRED SCORE: -0.0013
#
# [2022-03-19 08:50:08,821 INFO]
# SENT 58: ['s', '&', 'N', 'S', 'n', ',']
# PRED 58: s & N S n , d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:08,821 INFO]
# SENT 59: ['s', 'p', 'O', ':', 'n']
# PRED 59: s p O : n d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:08,821 INFO]
# SENT 60: ['g', 'r', 'V', 'd', 'Z']
# PRED 60: g r V d Z d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:08,964 INFO]
# SENT 61: ['t', 'r', 'V', 'n', 'd', 'l', ',']
# PRED 61: t r V n d l , d
# PRED SCORE: -0.0027
#
# [2022-03-19 08:50:08,964 INFO]
# SENT 62: ['l', 'u', ':', 't']
# PRED 62: l u : t I d
# PRED SCORE: -0.0406
#
# [2022-03-19 08:50:08,964 INFO]
# SENT 63: ['d', 'a', 'I', 'n']
# PRED 63: d a I n d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:08,964 INFO]
# SENT 64: ['s', 'k', 'V', 'l', 'p', 't']
# PRED 64: s k V l p t I d
# PRED SCORE: -0.0269
#
# [2022-03-19 08:50:08,965 INFO]
# SENT 65: ['g', 'r', '&', 't', 'I', 'f', 'a', 'I']
# PRED 65: g r & t I f a I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:08,965 INFO]
# SENT 66: ['f', 'I', 'g', '@', 'r', '*']
# PRED 66: f I g @ d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,965 INFO]
# SENT 67: ['I', 'N', 'k', 'w', 'a', 'I', '@', 'r', '*']
# PRED 67: I N k w a I @ d
# PRED SCORE: -0.0013
#
# [2022-03-19 08:50:08,965 INFO]
# SENT 68: ['p', 'r', 'i', ':', 'n']
# PRED 68: p r i : n d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:08,965 INFO]
# SENT 69: ['m', '@', 'n', 'I', 'p', 'j', '@', 'l', 'e', 'I', 't']
# PRED 69: m @ n I p j @ l e I t I d
# PRED SCORE: -0.0697
#
# [2022-03-19 08:50:08,966 INFO]
# SENT 70: ['r', 'E', 'm', 'I', 'd', 'I']
# PRED 70: r E m I d I d
# PRED SCORE: -0.0028
#
# [2022-03-19 08:50:08,966 INFO]
# SENT 71: ['f', 'l', 'I', 'p']
# PRED 71: f l I p t
# PRED SCORE: -0.0016
#
# [2022-03-19 08:50:08,966 INFO]
# SENT 72: ['k', 'w', 'E', 's', 't']
# PRED 72: k w E s t I d
# PRED SCORE: -0.0062
#
# [2022-03-19 08:50:08,966 INFO]
# SENT 73: ['d', 'E', 'd', 'I', 'k', 'e', 'I', 't']
# PRED 73: d E d I k e I t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,967 INFO]
# SENT 74: ['b', '@', 'g', 'r', 'V', 'd', 'Z']
# PRED 74: b @ g r V d Z d
# PRED SCORE: -0.0136
#
# [2022-03-19 08:50:08,967 INFO]
# SENT 75: ['e', 'I', 'd']
# PRED 75: e I d I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:08,967 INFO]
# SENT 76: ['s', '@', 'l', 'I', 's', 'I', 't']
# PRED 76: s @ l I s I t I d
# PRED SCORE: -0.0010
#
# [2022-03-19 08:50:08,967 INFO]
# SENT 77: ['k', '&', 't', 'S']
# PRED 77: k & t S t
# PRED SCORE: -0.0038
#
# [2022-03-19 08:50:08,967 INFO]
# SENT 78: ['s', 'I', 'l', 'U', 'E', 't']
# PRED 78: s I l U E t I d
# PRED SCORE: -1.2977
#
# [2022-03-19 08:50:08,968 INFO]
# SENT 79: ['l', 'e', 'I', 'd', 'l', ',']
# PRED 79: l e I d l , d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:08,968 INFO]
# SENT 80: ['I', 'n', 'f', 'I', 'l', 't', 'r', 'e', 'I', 't']
# PRED 80: I n f I l t r e I t I d
# PRED SCORE: -0.0031
#
# [2022-03-19 08:50:08,968 INFO]
# SENT 81: ['d', 'r', 'A', ':', 'f', 't']
# PRED 81: d r A : f t I d
# PRED SCORE: -0.0018
#
# [2022-03-19 08:50:08,968 INFO]
# SENT 82: ['k', 'O', ':', 'd']
# PRED 82: k O : d I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:08,969 INFO]
# SENT 83: ['s', 'k', 'r', '&', 'm', 'b', 'l', ',']
# PRED 83: s k r & m b l , d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:08,969 INFO]
# SENT 84: ['E', 'n', 'k', '&', 'm', 'p']
# PRED 84: E n k & m p t
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:08,969 INFO]
# SENT 85: ['@', 'p', 'r', 'E', 's']
# PRED 85: @ p r E s t
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,969 INFO]
# SENT 86: ['r', 'I', 'p', 'e', 'I', 'n', 't']
# PRED 86: r I p e I n t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,970 INFO]
# SENT 87: ['w', 'i', ':', 'l', 'd']
# PRED 87: w i : l d I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:08,970 INFO]
# SENT 88: ['d', 'I', 'p', 'r', 'e', 'I', 'v']
# PRED 88: d I p r e I v d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:08,970 INFO]
# SENT 89: ['d', 'u', ':', 'd', 'l', ',']
# PRED 89: d u : d l , d
# PRED SCORE: -0.4374
#
# [2022-03-19 08:50:08,970 INFO]
# SENT 90: ['@', 'U', 'v', '@', 'p', 'e', 'I']
# PRED 90: @ U v @ p e I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,111 INFO]
# SENT 91: ['a', 'U', 't', 'w', 'I', 't']
# PRED 91: a U t w I t I d
# PRED SCORE: -0.0505
#
# [2022-03-19 08:50:09,111 INFO]
# SENT 92: ['m', 'V', 'k']
# PRED 92: m V k t
# PRED SCORE: -0.0000
#
# [2022-03-19 08:50:09,111 INFO]
# SENT 93: ['s', 'w', 'i', ':', 't', 'n', ',']
# PRED 93: s w i : t n , d
# PRED SCORE: -0.0034
#
# [2022-03-19 08:50:09,112 INFO]
# SENT 94: ['E', 'n', 't', 'r', '&', 'p']
# PRED 94: E n t r & p t
# PRED SCORE: -0.0022
#
# [2022-03-19 08:50:09,112 INFO]
# SENT 95: ['r', 'E', 'k', 'l', ',', 'E', 'k', 't']
# PRED 95: r E k l , E k t I d
# PRED SCORE: -0.0106
#
# [2022-03-19 08:50:09,112 INFO]
# SENT 96: ['E', 'k', 's', 'p', 'E', 'n', 'd']
# PRED 96: E k s p E n d I d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:09,112 INFO]
# SENT 97: ['b', '@', 'g', 'E', 't']
# PRED 97: b @ g E t I d
# PRED SCORE: -0.8588
#
# [2022-03-19 08:50:09,112 INFO]
# SENT 98: ['k', '@', 'd', 'Z', '@', 'U', 'l']
# PRED 98: k @ d Z @ U l d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,113 INFO]
# SENT 99: ['s', 'k', '&', 'v', 'n', ',', 'd', 'Z']
# PRED 99: s k & v n , d Z d
# PRED SCORE: -0.0022
#
# [2022-03-19 08:50:09,113 INFO]
# SENT 100: ['i', ':', 'z']
# PRED 100: i : z d
# PRED SCORE: -0.0059
#
# [2022-03-19 08:50:09,113 INFO]
# SENT 101: ['n', '@', 'U']
# PRED 101: n @ U d
# PRED SCORE: -0.0031
#
# [2022-03-19 08:50:09,113 INFO]
# SENT 102: ['b', '&', 'k', 'f', 'a', 'I', '@', 'r', '*']
# PRED 102: b & k f a I @ d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:09,113 INFO]
# SENT 103: ['k', '@', 'r', 'i', ':', 'n']
# PRED 103: k @ r i : n d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:09,114 INFO]
# SENT 104: ['g', '3', ':', 'd', 'l', ',']
# PRED 104: g 3 : d l , d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,114 INFO]
# SENT 105: ['k', 'l', '&', 'r', 'I', 'f', 'a', 'I']
# PRED 105: k l & r I f a I d
# PRED SCORE: -0.0074
#
# [2022-03-19 08:50:09,114 INFO]
# SENT 106: ['r', '&', 'p']
# PRED 106: r & p t
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:09,114 INFO]
# SENT 107: ['d', 'Z', 'E', 's', 't', 'I', 'k', 'j', 'U', 'l', 'e', 'I', 't']
# PRED 107: d Z E s t I k j U l e I t I d
# PRED SCORE: -0.0155
#
# [2022-03-19 08:50:09,115 INFO]
# SENT 108: ['k', '@', 'n', 'v', 'i', ':', 'n']
# PRED 108: k @ n v i : n d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:09,115 INFO]
# SENT 109: ['r', '@', 'l', 'i', ':', 's']
# PRED 109: r @ l i : s t
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:09,115 INFO]
# SENT 110: ['f', 'O', ':', 's', 'f', 'i', ':', 'd']
# PRED 110: f O : s f E d
# PRED SCORE: -0.3008
#
# [2022-03-19 08:50:09,115 INFO]
# SENT 111: ['t', 'S', 'E', '@', 'r', '*']
# PRED 111: t S E @ d
# PRED SCORE: -0.0057
#
# [2022-03-19 08:50:09,115 INFO]
# SENT 112: ['d', 'I', 'f', 'r', 'O', ':', 'd']
# PRED 112: d I f r O : d I d
# PRED SCORE: -0.0035
#
# [2022-03-19 08:50:09,116 INFO]
# SENT 113: ['&', 'd', 'Z', 'I', 't', 'e', 'I', 't']
# PRED 113: & d Z I t e I t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,116 INFO]
# SENT 114: ['k', '@', 'n', 's', 'I', 'd', '@', 'r', '*']
# PRED 114: k @ n s I d @ d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,116 INFO]
# SENT 115: ['d', 'i', ':', 'k', '&', 'p', 'I', 't', 'e', 'I', 't']
# PRED 115: d i : k & p I t e I t I d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:09,116 INFO]
# SENT 116: ['s', 'n', 'I', '@', 'r', '*']
# PRED 116: s n I @ d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,116 INFO]
# SENT 117: ['g', '@', 'f', 'O', ':']
# PRED 117: g @ f O : d
# PRED SCORE: -0.7084
#
# [2022-03-19 08:50:09,117 INFO]
# SENT 118: ['b', 'V', 'm', 'p']
# PRED 118: b V m p t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,117 INFO]
# SENT 119: ['t', 'r', 'A', ':', 'n', 's', 'm', 'j', 'u', ':', 't']
# PRED 119: t r A : n s m j u : t I d
# PRED SCORE: -0.0027
#
# [2022-03-19 08:50:09,117 INFO]
# SENT 120: ['p', 'V', 't']
# PRED 120: p V t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,257 INFO]
# SENT 121: ['O', ':', 'T', 'E', 'n', 't', 'I', 'k', 'e', 'I', 't']
# PRED 121: O : T E n t I k e I t I d
# PRED SCORE: -0.0317
#
# [2022-03-19 08:50:09,257 INFO]
# SENT 122: ['V', 'n', 'n', '3', ':', 'v']
# PRED 122: V n 3 : v d
# PRED SCORE: -0.0445
#
# [2022-03-19 08:50:09,257 INFO]
# SENT 123: ['d', 'I', 's', 'E', 'k', 't']
# PRED 123: d I s E k t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,257 INFO]
# SENT 124: ['s', 'l', 'O', 't']
# PRED 124: s l O t I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:09,257 INFO]
# SENT 125: ['b', 'V', 'g', '@', 'r', '*']
# PRED 125: b V g @ d
# PRED SCORE: -0.0022
#
# [2022-03-19 08:50:09,258 INFO]
# SENT 126: ['d', 'I', 's', '@', 'U', 'n']
# PRED 126: d I s @ U n d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,258 INFO]
# SENT 127: ['b', 'O', ':', 'l']
# PRED 127: b O : l d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,258 INFO]
# SENT 128: ['s', 'm', '@', 'U', 'l', 'd', '@', 'r', '*']
# PRED 128: s m @ U l d @ d
# PRED SCORE: -0.0021
#
# [2022-03-19 08:50:09,258 INFO]
# SENT 129: ['V', 'n', 's', 'i', ':', 't']
# PRED 129: V n s i : t I d
# PRED SCORE: -0.0042
#
# [2022-03-19 08:50:09,259 INFO]
# SENT 130: ['b', 'l', 'E', '@', 'r', '*']
# PRED 130: b l E @ d
# PRED SCORE: -0.0027
#
# [2022-03-19 08:50:09,259 INFO]
# SENT 131: ['b', 'r', 'E', 'k', 'f', '@', 's', 't']
# PRED 131: b r E k f @ s t I d
# PRED SCORE: -0.0040
#
# [2022-03-19 08:50:09,259 INFO]
# SENT 132: ['d', 'I', 'p', 'r', 'E', 's']
# PRED 132: d I p r E s t
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:09,259 INFO]
# SENT 133: ['t', 'I', 'p', 't', '@', 'U']
# PRED 133: t I p t @ U d
# PRED SCORE: -0.0018
#
# [2022-03-19 08:50:09,259 INFO]
# SENT 134: ['I', 'm', 'p', 'r', 'E', 'g', 'n', 'e', 'I', 't']
# PRED 134: I m p r E g n e I t I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:09,260 INFO]
# SENT 135: ['I', 'n', 'O', 'k', 'j', 'U', 'l', 'e', 'I', 't']
# PRED 135: I n O k j U l e I t I d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:09,260 INFO]
# SENT 136: ['S', 'O', 'k']
# PRED 136: S O k t
# PRED SCORE: -0.0021
#
# [2022-03-19 08:50:09,260 INFO]
# SENT 137: ['S', 'V', 't', 'l', ',']
# PRED 137: S V t l , d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,260 INFO]
# SENT 138: ['w', 'O', 'n', 'd', '@', 'r', '*']
# PRED 138: w O n d @ d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,260 INFO]
# SENT 139: ['E', 'g', 'z', 'E', 'm', 't']
# PRED 139: E g z E m t I d
# PRED SCORE: -0.0026
#
# [2022-03-19 08:50:09,261 INFO]
# SENT 140: ['I', 'n', 's', '3', ':', 't']
# PRED 140: I n s 3 : t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,261 INFO]
# SENT 141: ['k', '@', 'n', 's', 't', 'r', 'I', 'k', 't']
# PRED 141: k @ n s t r I k t I d
# PRED SCORE: -0.0030
#
# [2022-03-19 08:50:09,261 INFO]
# SENT 142: ['a', 'U', 't', 'f', 'l', '&', 'N', 'k']
# PRED 142: a U t f l & N k t
# PRED SCORE: -0.0945
#
# [2022-03-19 08:50:09,261 INFO]
# SENT 143: ['p', 'E', 't']
# PRED 143: p E t I d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:09,262 INFO]
# SENT 144: ['m', 'E', 'n', 'S', 'n', ',']
# PRED 144: m E n S n , d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:09,262 INFO]
# SENT 145: ['@', 'U', 'v', '@', 'E', 'k', 's', 'p', '@', 'U', 'z']
# PRED 145: @ U v @ E k s p @ U z d
# PRED SCORE: -0.0610
#
# [2022-03-19 08:50:09,262 INFO]
# SENT 146: ['t', 'S', 'e', 'I', 'n', 's', 'm', '@', 'U', 'k']
# PRED 146: t S e I n s m @ U k t
# PRED SCORE: -0.1485
#
# [2022-03-19 08:50:09,262 INFO]
# SENT 147: ['I', 'n', 'Z', '@', 'r', '*']
# PRED 147: I n Z @ d
# PRED SCORE: -0.0054
#
# [2022-03-19 08:50:09,262 INFO]
# SENT 148: ['E', 'n', 'k', 'V', 'r', 'I', 'd', 'Z']
# PRED 148: E n k V r I d Z d
# PRED SCORE: -0.1514
#
# [2022-03-19 08:50:09,263 INFO]
# SENT 149: ['3', ':', 'k']
# PRED 149: 3 : k t
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:09,263 INFO]
# SENT 150: ['s', 'i', ':', 'd']
# PRED 150: s i : d I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,620 INFO]
# SENT 151: ['d', 'I', 's', 'i', ':', 'v']
# PRED 151: d I s i : v d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,621 INFO]
# SENT 152: ['p', '@', 'f', 'O', ':', 'm']
# PRED 152: p @ f O : m d
# PRED SCORE: -0.0044
#
# [2022-03-19 08:50:09,621 INFO]
# SENT 153: ['m', '@', 'U', 't', '@', 'r', '*']
# PRED 153: m @ U t @ d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,621 INFO]
# SENT 154: ['s', '@', 'd', 'Z', 'E', 's', 't']
# PRED 154: s @ d Z E s t I d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:09,621 INFO]
# SENT 155: ['@', 'U', 'v', '@', 'f', 'l', '@', 'U']
# PRED 155: @ U v @ f l @ U d
# PRED SCORE: -0.1059
#
# [2022-03-19 08:50:09,621 INFO]
# SENT 156: ['r', '@', 't', 'A', ':', 'd']
# PRED 156: r @ t A : d I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:09,622 INFO]
# SENT 157: ['r', 'E', 'p', 'l', 'I', 'k', 'e', 'I', 't']
# PRED 157: r E p l I k e I t I d
# PRED SCORE: -0.0066
#
# [2022-03-19 08:50:09,622 INFO]
# SENT 158: ['t', 'e', 'I', 'l', '@', 'r', '*']
# PRED 158: t e I l @ d
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:09,622 INFO]
# SENT 159: ['@', 't', '&', 't', 'S']
# PRED 159: @ t & t S t
# PRED SCORE: -0.0058
#
# [2022-03-19 08:50:09,622 INFO]
# SENT 160: ['@', 'p', 'O', ':', 'S', 'n', ',']
# PRED 160: @ p O : S n , d
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:09,623 INFO]
# SENT 161: ['f', 'r', 'I', 's', 'k']
# PRED 161: f r I s k t
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:09,623 INFO]
# SENT 162: ['t', 'j', 'u', ':', 't', '@', 'r', '*']
# PRED 162: t j u : t @ d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:09,623 INFO]
# SENT 163: ['n', '@', 'U', 't']
# PRED 163: n @ U t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,623 INFO]
# SENT 164: ['@', 'd', 'Z', '3', ':', 'n']
# PRED 164: @ d Z 3 : n d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,624 INFO]
# SENT 165: ['S', '&', 'k', 'l', ',']
# PRED 165: S & k l , d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:09,624 INFO]
# SENT 166: ['d', 'I', 's', 'O', 'r', 'I', 'E', 'n', 't', 'e', 'I', 't']
# PRED 166: d I s O r I E n t e I t I d
# PRED SCORE: -0.0047
#
# [2022-03-19 08:50:09,624 INFO]
# SENT 167: ['t', 'i', ':']
# PRED 167: t i : d
# PRED SCORE: -0.0112
#
# [2022-03-19 08:50:09,624 INFO]
# SENT 168: ['d', 'I', 's', 'r', 'V', 'p', 't']
# PRED 168: d I s r V p t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,624 INFO]
# SENT 169: ['p', 'I', 't', 'I']
# PRED 169: p I t I d
# PRED SCORE: -0.0022
#
# [2022-03-19 08:50:09,625 INFO]
# SENT 170: ['p', '3', ':', 's', 'O', 'n', 'I', 'f', 'a', 'I']
# PRED 170: p 3 : s O n I f a I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,625 INFO]
# SENT 171: ['l', 'O', 'g']
# PRED 171: l O g d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,625 INFO]
# SENT 172: ['@', 'b', 'z', 'O', 'l', 'v']
# PRED 172: @ b z O l v d
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:09,626 INFO]
# SENT 173: ['m', 'V', 'd', 'I']
# PRED 173: m V d I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:09,626 INFO]
# SENT 174: ['E', 'n', 'f', 'O', ':', 's']
# PRED 174: E n f O : s t
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,626 INFO]
# SENT 175: ['@', 'n', 'V', 'l']
# PRED 175: @ n V l d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,626 INFO]
# SENT 176: ['p', 'r', 'O', 'f', 'I', 't']
# PRED 176: p r O f I t I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:09,627 INFO]
# SENT 177: ['V', 'n', 's', 'k', 'r', 'u', ':']
# PRED 177: V n s k r u : d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,627 INFO]
# SENT 178: ['d', 'I', 's', 'l', 'a', 'I', 'k']
# PRED 178: d I s l a I k t
# PRED SCORE: -0.0016
#
# [2022-03-19 08:50:09,627 INFO]
# SENT 179: ['h', 'I', 'n', 'Z']
# PRED 179: h I n Z d
# PRED SCORE: -0.0193
#
# [2022-03-19 08:50:09,627 INFO]
# SENT 180: ['z', 'I', 'g', 'z', '&', 'g']
# PRED 180: z I g z & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g & g
# PRED SCORE: -0.7539
#
# [2022-03-19 08:50:09,760 INFO]
# SENT 181: ['d', 'Z', 'O', 'g', 'l', ',']
# PRED 181: d Z O g l , d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,760 INFO]
# SENT 182: ['h', 'I', 'p', 'n', '@', 't', 'a', 'I', 'z']
# PRED 182: h I p n @ t a I z d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,761 INFO]
# SENT 183: ['f', 'r', 'V', 's', 't', 'r', 'e', 'I', 't']
# PRED 183: f r V s t r e I t I d
# PRED SCORE: -0.0041
#
# [2022-03-19 08:50:09,761 INFO]
# SENT 184: ['k', '@', 'n', 't', 'r', 'a', 'I', 'v']
# PRED 184: k @ n t r a I v d
# PRED SCORE: -0.0464
#
# [2022-03-19 08:50:09,761 INFO]
# SENT 185: ['b', 'A', ':', 'r', '*']
# PRED 185: b A : d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:09,761 INFO]
# SENT 186: ['m', 'I', 's', 'I', 'n', 't', '3', ':', 'p', 'r', 'I', 't']
# PRED 186: m I s I n t 3 : p r I t I d
# PRED SCORE: -0.0889
#
# [2022-03-19 08:50:09,761 INFO]
# SENT 187: ['m', 'V', 'l', 't', 'I', 'p', 'l', 'a', 'I']
# PRED 187: m V l t I p l a I d
# PRED SCORE: -0.1051
#
# [2022-03-19 08:50:09,762 INFO]
# SENT 188: ['i', ':', 't']
# PRED 188: i : t I d
# PRED SCORE: -0.0031
#
# [2022-03-19 08:50:09,762 INFO]
# SENT 189: ['k', 'r', 'i', ':', 'p']
# PRED 189: k r i : p t
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:09,762 INFO]
# SENT 190: ['p', 'i', ':', 'p', 'l', ',']
# PRED 190: p i : p l , d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,762 INFO]
# SENT 191: ['k', 'l', 'V', 'k']
# PRED 191: k l V k t
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,763 INFO]
# SENT 192: ['l', 'O', 'b']
# PRED 192: l O b d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,763 INFO]
# SENT 193: ['s', 'l', 'a', 'I', 'd']
# PRED 193: s l a I d I d
# PRED SCORE: -0.0030
#
# [2022-03-19 08:50:09,763 INFO]
# SENT 194: ['s', 'k', 'I', 'm', 'p']
# PRED 194: s k I m p t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,763 INFO]
# SENT 195: ['r', 'i', ':', 'l', '@', 'U', 'k', 'e', 'I', 't']
# PRED 195: r i : l @ U k e I t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,763 INFO]
# SENT 196: ['m', '&', 'r', 'I']
# PRED 196: m & r I d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:09,764 INFO]
# SENT 197: ['k', '@', 'm', 'p', 'i', ':', 't']
# PRED 197: k @ m p i : t I d
# PRED SCORE: -0.0118
#
# [2022-03-19 08:50:09,764 INFO]
# SENT 198: ['k', '&', 'n', 't', '@', 'r', '*']
# PRED 198: k & n t @ d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:09,764 INFO]
# SENT 199: ['h', 'O', 'I', 's', 't']
# PRED 199: h O I s t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,764 INFO]
# SENT 200: ['h', 'j', 'u', ':']
# PRED 200: h j u : d
# PRED SCORE: -0.0165
#
# [2022-03-19 08:50:09,764 INFO]
# SENT 201: ['I', 'r', '&', 'd', 'I', 'k', 'e', 'I', 't']
# PRED 201: I r & d I k e I t I d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:09,765 INFO]
# SENT 202: ['r', 'V', 'f']
# PRED 202: r V f t
# PRED SCORE: -0.0031
#
# [2022-03-19 08:50:09,765 INFO]
# SENT 203: ['h', '&', 'n', 'd', 'I', 'k', '&', 'p']
# PRED 203: h & n d I k & p t
# PRED SCORE: -0.1092
#
# [2022-03-19 08:50:09,765 INFO]
# SENT 204: ['m', '@', 'r', 'O', ':', 'd']
# PRED 204: m @ r O : d I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:09,765 INFO]
# SENT 205: ['s', 'k', 'O', 't', 'S']
# PRED 205: s k O t S t
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:09,766 INFO]
# SENT 206: ['s', '&', 'b', '@', 't', 'A', ':', 'd', 'Z']
# PRED 206: s & b @ t A : d Z d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:09,766 INFO]
# SENT 207: ['s', 't', 'E', '@', 'r', '*']
# PRED 207: s t E @ d
# PRED SCORE: -0.0054
#
# [2022-03-19 08:50:09,766 INFO]
# SENT 208: ['s', 'I', 'z', 'l', ',']
# PRED 208: s I z l , d
# PRED SCORE: -0.0066
#
# [2022-03-19 08:50:09,766 INFO]
# SENT 209: ['s', 'w', 'O', 'b']
# PRED 209: s w O b d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,766 INFO]
# SENT 210: ['I', 'n', 'v', 'O', 'l', 'v']
# PRED 210: I n v O l v d
# PRED SCORE: -0.0044
#
# [2022-03-19 08:50:09,904 INFO]
# SENT 211: ['r', '@', 'p', 'E', 'l']
# PRED 211: r @ p E l d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,904 INFO]
# SENT 212: ['r', 'V', 'b']
# PRED 212: r V b d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:09,904 INFO]
# SENT 213: ['E', 'n', 'd', 'Z', 'E', 'n', 'd', '@', 'r', '*']
# PRED 213: E n d Z E n d @ d
# PRED SCORE: -0.0082
#
# [2022-03-19 08:50:09,904 INFO]
# SENT 214: ['@', 'l', 'E', 'd', 'Z']
# PRED 214: @ l E d Z d
# PRED SCORE: -0.0026
#
# [2022-03-19 08:50:09,905 INFO]
# SENT 215: ['@', 'U', 'v', '@', 'I', 'n', 'd', 'V', 'l', 'd', 'Z']
# PRED 215: @ U v @ I n d Z d
# PRED SCORE: -0.4288
#
# [2022-03-19 08:50:09,905 INFO]
# SENT 216: ['k', '@', 'l', 'E', 'k', 't', 'I', 'v', 'a', 'I', 'z']
# PRED 216: k @ l E k t I v a I z d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:09,905 INFO]
# SENT 217: ['m', 'V', 'n', 'S']
# PRED 217: m V n S t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,905 INFO]
# SENT 218: ['j', '&', 'N', 'k']
# PRED 218: j & N k t
# PRED SCORE: -0.0039
#
# [2022-03-19 08:50:09,905 INFO]
# SENT 219: ['&', 't', 'r', 'U', 'f', 'I']
# PRED 219: & t r U f I d
# PRED SCORE: -0.3728
#
# [2022-03-19 08:50:09,906 INFO]
# SENT 220: ['s', 'm', '3', ':', 'k']
# PRED 220: s m 3 : k t
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,906 INFO]
# SENT 221: ['V', 'n', 'p', '&', 'k']
# PRED 221: V n p & k t
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:09,906 INFO]
# SENT 222: ['s', 'p', 'r', 'e', 'I']
# PRED 222: s p r e I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,906 INFO]
# SENT 223: ['f', '3', ':', 'm', 'E', 'n', 't']
# PRED 223: f 3 : m E n t I d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:09,907 INFO]
# SENT 224: ['d', 'I', 'v', '3', ':', 'd', 'Z']
# PRED 224: d I v 3 : d Z d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,907 INFO]
# SENT 225: ['O', 'b', 'l', 'I', 'g', 'e', 'I', 't']
# PRED 225: O b l I g e I t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,907 INFO]
# SENT 226: ['b', 'O', ':', 'l', 'k']
# PRED 226: b O : l k t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,907 INFO]
# SENT 227: ['s', 'a', 'I', 'k', 'l', ',']
# PRED 227: s a I k l , d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:09,907 INFO]
# SENT 228: ['I', 'n', 't', '3', ':', 'r', '*']
# PRED 228: I n t 3 : d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,908 INFO]
# SENT 229: ['b', 'r', 'e', 'I', 's']
# PRED 229: b r e I s t
# PRED SCORE: -0.0023
#
# [2022-03-19 08:50:09,908 INFO]
# SENT 230: ['p', '3', ':', 't', 'S', '@', 's']
# PRED 230: p 3 : t S @ s t
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:09,908 INFO]
# SENT 231: ['d', 'I', 'z', '3', ':', 'n']
# PRED 231: d I z 3 : n d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:09,908 INFO]
# SENT 232: ['r', 'i', ':', 'v', 'a', 'I', 't', 'l', ',', 'a', 'I', 'z']
# PRED 232: r i : v a I t l , a I z d
# PRED SCORE: -0.3462
#
# [2022-03-19 08:50:09,909 INFO]
# SENT 233: ['k', '@', 'm', '3', ':', 'S', 'l', ',', 'a', 'I', 'z']
# PRED 233: k @ m 3 : S l , a I z d
# PRED SCORE: -0.0028
#
# [2022-03-19 08:50:09,909 INFO]
# SENT 234: ['e', 'I', 'l', 'I', '@', 'n', 'e', 'I', 't']
# PRED 234: e I l I @ n e I t I d
# PRED SCORE: -0.0146
#
# [2022-03-19 08:50:09,909 INFO]
# SENT 235: ['d', 'E', 'k', '@', 'r', 'e', 'I', 't']
# PRED 235: d E k @ r e I t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:09,909 INFO]
# SENT 236: ['d', 'I', 'k', 'e', 'I']
# PRED 236: d I k e I d
# PRED SCORE: -0.0032
#
# [2022-03-19 08:50:09,909 INFO]
# SENT 237: ['s', 'k', '&', 'm', 'p', '@', 'r', '*']
# PRED 237: s k & m p @ d
# PRED SCORE: -0.0010
#
# [2022-03-19 08:50:09,910 INFO]
# SENT 238: ['E', 'n', 'd', 'j', 'O', ':', 'r', '*']
# PRED 238: E n d j O : d
# PRED SCORE: -0.0036
#
# [2022-03-19 08:50:09,910 INFO]
# SENT 239: ['h', 'I', 'n', 'd', '@', 'r', '*']
# PRED 239: h I n d @ d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:09,910 INFO]
# SENT 240: ['@', 'U', 'v', '@', 't', 'e', 'I', 'k']
# PRED 240: @ U v @ t e I k t
# PRED SCORE: -0.0046
#
# [2022-03-19 08:50:10,046 INFO]
# SENT 241: ['r', 'I', 'b', 'V', 'f']
# PRED 241: r I b V f t
# PRED SCORE: -0.0039
#
# [2022-03-19 08:50:10,047 INFO]
# SENT 242: ['s', 'V', 'l', 'I']
# PRED 242: s V l I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,047 INFO]
# SENT 243: ['t', 'r', 'O', 't']
# PRED 243: t r O t I d
# PRED SCORE: -0.0019
#
# [2022-03-19 08:50:10,047 INFO]
# SENT 244: ['V', 'p', 'E', 'n', 'd']
# PRED 244: V p E n d I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,047 INFO]
# SENT 245: ['E', 'g', 'z', 'E', 'm', 'p', 'l', 'I', 'f', 'a', 'I']
# PRED 245: E g z E m p l I f a I d
# PRED SCORE: -0.0040
#
# [2022-03-19 08:50:10,047 INFO]
# SENT 246: ['l', 'I', 'm', 'p']
# PRED 246: l I m p t
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,048 INFO]
# SENT 247: ['g', 'r', '@', 'U']
# PRED 247: g r @ U d
# PRED SCORE: -0.2283
#
# [2022-03-19 08:50:10,048 INFO]
# SENT 248: ['E', 's', 't', 'r', 'e', 'I', 'n', 'Z']
# PRED 248: E s t r e I n Z d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:10,048 INFO]
# SENT 249: ['@', 'b', 'a', 'U', 'n', 'd']
# PRED 249: @ b a U n d I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,048 INFO]
# SENT 250: ['t', 'e', 'I', 'k']
# PRED 250: t e I k t
# PRED SCORE: -0.0080
#
# [2022-03-19 08:50:10,048 INFO]
# SENT 251: ['d', 'V', 'm', 'f', 'a', 'U', 'n', 'd']
# PRED 251: d V m f a U n d I d
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:10,049 INFO]
# SENT 252: ['&', 'k', 's', 'E', 'l', '@', 'r', 'e', 'I', 't']
# PRED 252: & k s E l @ r e I t I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,049 INFO]
# SENT 253: ['k', 'O', 'N', 'k', '@', 'r', '*']
# PRED 253: k O N k @ d
# PRED SCORE: -0.0050
#
# [2022-03-19 08:50:10,049 INFO]
# SENT 254: ['m', 'O', 'l', 'I', 'f', 'a', 'I']
# PRED 254: m O l I f a I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,050 INFO]
# SENT 255: ['p', 'a', 'U', '@', 'r', '*']
# PRED 255: p a U @ d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,050 INFO]
# SENT 256: ['S', 'I', 'p', 'r', 'E', 'k']
# PRED 256: S I p r E k t
# PRED SCORE: -0.1146
#
# [2022-03-19 08:50:10,050 INFO]
# SENT 257: ['s', 'V', 'd', 'Z', '@', 'n']
# PRED 257: s V d Z @ n d
# PRED SCORE: -0.0077
#
# [2022-03-19 08:50:10,050 INFO]
# SENT 258: ['t', 'V', 'n', 'l', ',']
# PRED 258: t V n l , d
# PRED SCORE: -0.0040
#
# [2022-03-19 08:50:10,051 INFO]
# SENT 259: ['f', 'a', 'I', 'n', '&', 'n', 's']
# PRED 259: f a I n & n s t
# PRED SCORE: -0.0922
#
# [2022-03-19 08:50:10,051 INFO]
# SENT 260: ['r', 'i', ':', 's', 'E', 't', 'l', ',']
# PRED 260: r i : s E t l , d
# PRED SCORE: -0.0064
#
# [2022-03-19 08:50:10,051 INFO]
# SENT 261: ['h', 'V', 'f']
# PRED 261: h V f t
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,052 INFO]
# SENT 262: ['d', 'I', 'g', 'r', 'e', 'I', 'd']
# PRED 262: d I g r e I d I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,052 INFO]
# SENT 263: ['I', 'n', 'v', '&', 'l', 'I', 'd', 'e', 'I', 't']
# PRED 263: I n v & l I d e I t I d
# PRED SCORE: -0.0056
#
# [2022-03-19 08:50:10,052 INFO]
# SENT 264: ['p', '3', ':', 'v', 'e', 'I', 'd']
# PRED 264: p 3 : v e I d I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,052 INFO]
# SENT 265: ['t', '&', 'k', 'l', ',']
# PRED 265: t & k l , d
# PRED SCORE: -0.0026
#
# [2022-03-19 08:50:10,053 INFO]
# SENT 266: ['r', '@', 's', 't', 'O', ':', 'r', '*']
# PRED 266: r @ s t O : d
# PRED SCORE: -0.0016
#
# [2022-03-19 08:50:10,053 INFO]
# SENT 267: ['p', 'r', 'a', 'I', 'z']
# PRED 267: p r a I z d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:10,053 INFO]
# SENT 268: ['h', 'O', 'N', 'k']
# PRED 268: h O N k t
# PRED SCORE: -0.0023
#
# [2022-03-19 08:50:10,054 INFO]
# SENT 269: ['d', '&', 'p', 'l', ',']
# PRED 269: d & p l , d
# PRED SCORE: -0.0150
#
# [2022-03-19 08:50:10,054 INFO]
# SENT 270: ['d', 'I', 's', 'p', 'r', 'u', ':', 'v']
# PRED 270: d I s p r u : v d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,189 INFO]
# SENT 271: ['r', '@', 'z', 'I', 's', 't']
# PRED 271: r @ z I s t I d
# PRED SCORE: -0.0038
#
# [2022-03-19 08:50:10,189 INFO]
# SENT 272: ['k', '@', 'm', 'A', ':', 'n', 'd']
# PRED 272: k @ m A : n d I d
# PRED SCORE: -0.0079
#
# [2022-03-19 08:50:10,189 INFO]
# SENT 273: ['s', '@', 'U', 'k']
# PRED 273: s @ U k t
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,189 INFO]
# SENT 274: ['d', 'r', '&', 't']
# PRED 274: d r & t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,190 INFO]
# SENT 275: ['k', 'O', 'n', 'v', '@', 'l', 'E', 's']
# PRED 275: k O n v @ l E s t
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:10,190 INFO]
# SENT 276: ['I', 'l', 'E', 'k', 't', 'r', 'I', 'f', 'a', 'I']
# PRED 276: I l E k t r I f a I d
# PRED SCORE: -0.0149
#
# [2022-03-19 08:50:10,190 INFO]
# SENT 277: ['p', 'r', 'I', 'v', '&', 'r', 'I', 'k', 'e', 'I', 't']
# PRED 277: p r I v & r I k e I t I d
# PRED SCORE: -0.0033
#
# [2022-03-19 08:50:10,190 INFO]
# SENT 278: ['b', 'u', ':', 'm']
# PRED 278: b u : m d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,190 INFO]
# SENT 279: ['m', 'j', 'u', ':', 't']
# PRED 279: m j u : t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,191 INFO]
# SENT 280: ['b', 'r', 'I', 'N']
# PRED 280: b r I N d
# PRED SCORE: -0.1051
#
# [2022-03-19 08:50:10,191 INFO]
# SENT 281: ['I', 'n', 's', 'I', 'n', '@', 'r', 'e', 'I', 't']
# PRED 281: I n s I n @ r e I t I d
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:10,191 INFO]
# SENT 282: ['d', 'I', 'k', 'r', 'a', 'I']
# PRED 282: d I k r a I d
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:10,191 INFO]
# SENT 283: ['m', 'E', 'd', 'l', ',']
# PRED 283: m E d l , d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,191 INFO]
# SENT 284: ['s', 'k', 'w', 'i', ':', 'k']
# PRED 284: s k w i : k t
# PRED SCORE: -0.0029
#
# [2022-03-19 08:50:10,192 INFO]
# SENT 285: ['s', 'm', 'E', 'l', 't']
# PRED 285: s m E l t I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,192 INFO]
# SENT 286: ['m', 'I', 's', 't', 'e', 'I', 'k']
# PRED 286: m I s t e I k t
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,192 INFO]
# SENT 287: ['r', 'i', ':', 's', 't', 'e', 'I', 't']
# PRED 287: r i : s t e I t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,192 INFO]
# SENT 288: ['E', 'p', 'I', 't', '@', 'm', 'a', 'I', 'z']
# PRED 288: E p I t @ m a I z d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,193 INFO]
# SENT 289: ['m', 'I', 's', 'l', 'i', ':', 'd']
# PRED 289: m I s l i : d I d
# PRED SCORE: -0.0062
#
# [2022-03-19 08:50:10,193 INFO]
# SENT 290: ['f', 'O', ':', 'k']
# PRED 290: f O : k t
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:10,193 INFO]
# SENT 291: ['V', 'n', 'f', '@', 'U', 'l', 'd']
# PRED 291: V n f @ U l d I d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:10,193 INFO]
# SENT 292: ['g', 'e', 'I', 'd', 'Z']
# PRED 292: g e I d Z d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,194 INFO]
# SENT 293: ['r', '@', 'p', 'r', '@', 'U', 't', 'S']
# PRED 293: r @ p r @ U t S t
# PRED SCORE: -0.0089
#
# [2022-03-19 08:50:10,194 INFO]
# SENT 294: ['g', 'I', 'v']
# PRED 294: g I v d
# PRED SCORE: -0.5638
#
# [2022-03-19 08:50:10,194 INFO]
# SENT 295: ['i', ':', 'v', '&', 'k', 'j', 'U', 'e', 'I', 't']
# PRED 295: i : v & k j U e I t I d
# PRED SCORE: -0.0032
#
# [2022-03-19 08:50:10,194 INFO]
# SENT 296: ['E', 'n', 'r', '@', 'U', 'l']
# PRED 296: E n r @ U l d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,194 INFO]
# SENT 297: ['s', 'E', 'g', 'r', 'I', 'g', 'e', 'I', 't']
# PRED 297: s E g r I g e I t I d
# PRED SCORE: -0.0027
#
# [2022-03-19 08:50:10,195 INFO]
# SENT 298: ['l', 'e', 'I']
# PRED 298: l e I d
# PRED SCORE: -0.0055
#
# [2022-03-19 08:50:10,195 INFO]
# SENT 299: ['p', 'V', 'l', 'v', '@', 'r', 'a', 'I', 'z']
# PRED 299: p V l v @ r a I z d
# PRED SCORE: -0.0021
#
# [2022-03-19 08:50:10,195 INFO]
# SENT 300: ['d', 'Z', 'I', 'N', 'g', 'l', ',']
# PRED 300: d Z I N g l , d
# PRED SCORE: -0.0016
#
# [2022-03-19 08:50:10,320 INFO]
# SENT 301: ['d', 'I', 'k', 'r', 'i', ':']
# PRED 301: d I k r i : d
# PRED SCORE: -0.0025
#
# [2022-03-19 08:50:10,320 INFO]
# SENT 302: ['b', 'r', 'O', 'I', 'l']
# PRED 302: b r O I l d
# PRED SCORE: -0.0024
#
# [2022-03-19 08:50:10,321 INFO]
# SENT 303: ['V', 'n', 'd', '@', 'v', '&', 'l', 'j', 'U']
# PRED 303: V n d @ v & l j U d
# PRED SCORE: -0.0270
#
# [2022-03-19 08:50:10,321 INFO]
# SENT 304: ['f', 'l', 'V', 's', 't', '@', 'r', '*']
# PRED 304: f l V s t @ d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:10,321 INFO]
# SENT 305: ['s', 'k', 'r', 'a', 'U', 'n', 'Z']
# PRED 305: s k r a U n Z d
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:10,321 INFO]
# SENT 306: ['b', '@', 't', '@', 'U', 'k', 'n', ',']
# PRED 306: b @ t @ U k n , d
# PRED SCORE: -0.0015
#
# [2022-03-19 08:50:10,321 INFO]
# SENT 307: ['b', '@', 'h', 'e', 'I', 'v']
# PRED 307: b @ h e I v d
# PRED SCORE: -0.4523
#
# [2022-03-19 08:50:10,322 INFO]
# SENT 308: ['s', 'V', 'l', 'k']
# PRED 308: s V l k t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,322 INFO]
# SENT 309: ['k', '@', 'n', 'f', 'E', 's']
# PRED 309: k @ n f E s t
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:10,322 INFO]
# SENT 310: ['T', 'I', 'N', 'k']
# PRED 310: T I N k t
# PRED SCORE: -0.0094
#
# [2022-03-19 08:50:10,322 INFO]
# SENT 311: ['&', 's', '@', 't', 'e', 'I', 'n']
# PRED 311: & s @ t e I n d
# PRED SCORE: -0.0010
#
# [2022-03-19 08:50:10,322 INFO]
# SENT 312: ['p', 'r', '@', 'U', 'g', 'r', '&', 'm']
# PRED 312: p r @ U g r & m d
# PRED SCORE: -0.0062
#
# [2022-03-19 08:50:10,323 INFO]
# SENT 313: ['k', 'w', 'E', 'S', 't', 'S', 'n', ',']
# PRED 313: k w E S t S n , d
# PRED SCORE: -0.0086
#
# [2022-03-19 08:50:10,323 INFO]
# SENT 314: ['d', 'I', 'b', 'e', 'I', 't']
# PRED 314: d I b e I t I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,323 INFO]
# SENT 315: ['d', 'r', 'O', ':']
# PRED 315: d r O : d
# PRED SCORE: -0.0054
#
# [2022-03-19 08:50:10,323 INFO]
# SENT 316: ['s', 'w', 'O', 'p']
# PRED 316: s w O p t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,324 INFO]
# SENT 317: ['f', 'I', 'l', 'I', 't']
# PRED 317: f I l I t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,324 INFO]
# SENT 318: ['m', 'V', 't', '@', 'r', '*']
# PRED 318: m V t @ d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,324 INFO]
# SENT 319: ['s', '@', 'k', 's', 'i', ':', 'd']
# PRED 319: s @ k s i : d I d
# PRED SCORE: -0.0034
#
# [2022-03-19 08:50:10,324 INFO]
# SENT 320: ['g', 'l', 'V', 't']
# PRED 320: g l V t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,324 INFO]
# SENT 321: ['h', 'w', 'i', ':', 'l']
# PRED 321: h w i : l d
# PRED SCORE: -0.0029
#
# [2022-03-19 08:50:10,325 INFO]
# SENT 322: ['p', '3', ':', 'f', '@', 'r', 'e', 'I', 't']
# PRED 322: p 3 : f @ r e I t I d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:10,325 INFO]
# SENT 323: ['d', 'w', 'O', ':', 'f']
# PRED 323: d w O : f t
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,325 INFO]
# SENT 324: ['m', 'I', 's', 'V', 'n', 'd', '@', 's', 't', '&', 'n', 'd']
# PRED 324: m I s V n d @ s t u : d
# PRED SCORE: -0.5866
#
# [2022-03-19 08:50:10,325 INFO]
# SENT 325: ['p', 'i', ':', 's']
# PRED 325: p i : s t
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,326 INFO]
# SENT 326: ['a', 'U', 't', 'g', 'r', '@', 'U']
# PRED 326: a U t g r @ U t g d
# PRED SCORE: -0.5086
#
# [2022-03-19 08:50:10,326 INFO]
# SENT 327: ['r', '@', 'k', 'l', 'a', 'I', 'n']
# PRED 327: r @ k l a I n d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,326 INFO]
# SENT 328: ['k', '@', 'r', '@', 'U', 'd']
# PRED 328: k @ r @ U d I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,326 INFO]
# SENT 329: ['a', 'I', 's']
# PRED 329: a I s t
# PRED SCORE: -0.0010
#
# [2022-03-19 08:50:10,326 INFO]
# SENT 330: ['p', 'O', 'm', 'l', ',']
# PRED 330: p O m l , d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,723 INFO]
# SENT 331: ['k', 'O', ':', 'n']
# PRED 331: k O : n d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,723 INFO]
# SENT 332: ['s', '@', 'f', 'a', 'I', 's']
# PRED 332: s @ f a I s t
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:10,723 INFO]
# SENT 333: ['v', 'O', ':', 'n', 't']
# PRED 333: v O : n t I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,723 INFO]
# SENT 334: ['@', 'f', 'I', 'S', 'I', 'e', 'I', 't']
# PRED 334: @ f I S I e I t I d
# PRED SCORE: -0.0023
#
# [2022-03-19 08:50:10,724 INFO]
# SENT 335: ['g', '@', 'U']
# PRED 335: g @ U d
# PRED SCORE: -0.0130
#
# [2022-03-19 08:50:10,724 INFO]
# SENT 336: ['g', 'I', 'g', 'l', ',']
# PRED 336: g I g l , d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:10,724 INFO]
# SENT 337: ['s', 'k', 'E', 'd', 'Z', 'l', ',']
# PRED 337: s k E d Z l , d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,724 INFO]
# SENT 338: ['h', 'V', 'd', 'l', ',']
# PRED 338: h V d l , d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,724 INFO]
# SENT 339: ['t', 'r', '&', 'k']
# PRED 339: t r & k t
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:10,725 INFO]
# SENT 340: ['s', '@', 'p', 'r', 'a', 'I', 'z']
# PRED 340: s @ p r a I z d
# PRED SCORE: -0.0022
#
# [2022-03-19 08:50:10,725 INFO]
# SENT 341: ['d', 'I', 'l', 'e', 'I', 't']
# PRED 341: d I l e I t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,725 INFO]
# SENT 342: ['I', 'm', '&', 'd', 'Z', 'n', ',']
# PRED 342: I m & d Z n , d
# PRED SCORE: -0.0011
#
# [2022-03-19 08:50:10,725 INFO]
# SENT 343: ['g', 'r', '@', 'U', 'n']
# PRED 343: g r @ U n d
# PRED SCORE: -0.0176
#
# [2022-03-19 08:50:10,726 INFO]
# SENT 344: ['d', 'r', 'i', ':', 'm']
# PRED 344: d r i : m d
# PRED SCORE: -0.0028
#
# [2022-03-19 08:50:10,726 INFO]
# SENT 345: ['I', 'm', 'p', '&', 'k', 't']
# PRED 345: I m p & k t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,726 INFO]
# SENT 346: ['k', 'A', ':', 't']
# PRED 346: k A : t I d
# PRED SCORE: -0.0019
#
# [2022-03-19 08:50:10,726 INFO]
# SENT 347: ['r', '@', 's', 'I', 'p', 'r', 'U', 'k', 'e', 'I', 't']
# PRED 347: r @ s I p r U k e I t I d
# PRED SCORE: -0.0022
#
# [2022-03-19 08:50:10,726 INFO]
# SENT 348: ['d', 'I', 'l', 'I', 'v', '@', 'r', '*']
# PRED 348: d I l I v @ d
# PRED SCORE: -0.0013
#
# [2022-03-19 08:50:10,727 INFO]
# SENT 349: ['d', 'I', 's', 'k', '@', 'n', 't', 'I', 'n', 'j', 'U']
# PRED 349: d I s k @ n t I n j U d
# PRED SCORE: -0.0037
#
# [2022-03-19 08:50:10,727 INFO]
# SENT 350: ['d', 'Z', 'A', ':', 'r', '*']
# PRED 350: d Z A : d
# PRED SCORE: -0.0018
#
# [2022-03-19 08:50:10,727 INFO]
# SENT 351: ['r', '@', 'p', 'E', 'n', 't']
# PRED 351: r @ p E n t I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,727 INFO]
# SENT 352: ['m', 'i', ':', 'd', 'I', 'e', 'I', 't']
# PRED 352: m i : d I e I t I d
# PRED SCORE: -0.0270
#
# [2022-03-19 08:50:10,727 INFO]
# SENT 353: ['p', 'r', 'a', 'I', 's']
# PRED 353: p r a I s t
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,728 INFO]
# SENT 354: ['k', 'V', 'l', 't', 'I', 'v', 'e', 'I', 't']
# PRED 354: k V l t I v e I t I d
# PRED SCORE: -0.1409
#
# [2022-03-19 08:50:10,728 INFO]
# SENT 355: ['d', 'I', 'k', 'l', 'E', '@', 'r', '*']
# PRED 355: d I k l E @ d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,728 INFO]
# SENT 356: ['s', 't', 'A', ':', 'f']
# PRED 356: s t A : f t
# PRED SCORE: -0.0032
#
# [2022-03-19 08:50:10,728 INFO]
# SENT 357: ['t', 'E', 'l', 'I', 's', 'k', '@', 'U', 'p']
# PRED 357: t E l I s k @ U p t
# PRED SCORE: -0.8989
#
# [2022-03-19 08:50:10,728 INFO]
# SENT 358: ['I', 'm', 'I', 't', 'e', 'I', 't']
# PRED 358: I m I t e I t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,729 INFO]
# SENT 359: ['f', 'r', 'V', 'n', 't']
# PRED 359: f r V n t I d
# PRED SCORE: -0.0035
#
# [2022-03-19 08:50:10,729 INFO]
# SENT 360: ['s', 'E', 'n', 's', '@', 't', 'a', 'I', 'z']
# PRED 360: s E n s @ t a I z d
# PRED SCORE: -0.0047
#
# [2022-03-19 08:50:10,847 INFO]
# SENT 361: ['d', 'I', 'm']
# PRED 361: d I m d
# PRED SCORE: -0.3761
#
# [2022-03-19 08:50:10,848 INFO]
# SENT 362: ['@', 'b', '&', 'S']
# PRED 362: @ b & S t
# PRED SCORE: -0.0019
#
# [2022-03-19 08:50:10,848 INFO]
# SENT 363: ['t', 'E', 'l']
# PRED 363: t E l d
# PRED SCORE: -0.0075
#
# [2022-03-19 08:50:10,848 INFO]
# SENT 364: ['p', 'l', 'i', ':', 't']
# PRED 364: p l i : t I d
# PRED SCORE: -0.0008
#
# [2022-03-19 08:50:10,848 INFO]
# SENT 365: ['r', '@', 'v', '@', 'U', 'k']
# PRED 365: r @ v @ U k t
# PRED SCORE: -0.0017
#
# [2022-03-19 08:50:10,849 INFO]
# SENT 366: ['d', 'I', 'p']
# PRED 366: d I p t
# PRED SCORE: -0.7241
#
# [2022-03-19 08:50:10,849 INFO]
# SENT 367: ['m', '@', 'U']
# PRED 367: m @ U d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:10,849 INFO]
# SENT 368: ['d', 'w', 'I', 'n', 'd', 'l', ',']
# PRED 368: d w I n d l , d
# PRED SCORE: -0.0004
#
# [2022-03-19 08:50:10,850 INFO]
# SENT 369: ['b', 'r', 'u', ':', 'd']
# PRED 369: b r u : d I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,850 INFO]
# SENT 370: ['d', 'r', 'a', 'I', 'v']
# PRED 370: d r a I v d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:10,850 INFO]
# SENT 371: ['d', 'O', ':', 'n']
# PRED 371: d O : n d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:10,850 INFO]
# SENT 372: ['t', 'r', 'e', 'I', 'n']
# PRED 372: t r e I n d
# PRED SCORE: -0.0000
#
# [2022-03-19 08:50:10,851 INFO]
# SENT 373: ['p', '&', 'n', 'd', '@', 'r', '*']
# PRED 373: p & n d @ d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,851 INFO]
# SENT 374: ['k', '@', 'n', 's', 'p', 'a', 'I', '@', 'r', '*']
# PRED 374: k @ n s p a I @ d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,851 INFO]
# SENT 375: ['s', '3', ':', 'k', '@', 'm', 's', 'k', 'r', 'a', 'I', 'b']
# PRED 375: s 3 : k @ m s k r a I b d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:10,851 INFO]
# SENT 376: ['t', 'S', 'e', 'I', 'f']
# PRED 376: t S e I f t
# PRED SCORE: -0.0054
#
# [2022-03-19 08:50:10,851 INFO]
# SENT 377: ['k', 'l', '&', 's', 'I', 'f', 'a', 'I']
# PRED 377: k l & s I f a I d
# PRED SCORE: -0.0060
#
# [2022-03-19 08:50:10,852 INFO]
# SENT 378: ['v', '&', 's', 'l', ',', 'e', 'I', 't']
# PRED 378: v & s l , e I t I d
# PRED SCORE: -0.0133
#
# [2022-03-19 08:50:10,852 INFO]
# SENT 379: ['s', 'm', 'a', 'I', 't']
# PRED 379: s m a I t I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,852 INFO]
# SENT 380: ['d', 'Z', '3', ':', 'm', 'I', 'n', 'e', 'I', 't']
# PRED 380: d Z 3 : m I n e I t I d
# PRED SCORE: -0.0163
#
# [2022-03-19 08:50:10,852 INFO]
# SENT 381: ['g', 'r', 'U', 'm']
# PRED 381: g r U m d
# PRED SCORE: -0.0231
#
# [2022-03-19 08:50:10,853 INFO]
# SENT 382: ['@', 's', 'u', ':', 'm']
# PRED 382: @ s u : m d
# PRED SCORE: -0.0032
#
# [2022-03-19 08:50:10,853 INFO]
# SENT 383: ['s', '@', 'p', 'l', 'A', ':', 'n', 't']
# PRED 383: s @ p l A : n t I d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,853 INFO]
# SENT 384: ['t', 'S', '&', 's', 't', 'a', 'I', 'z']
# PRED 384: t S & s t a I z d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:10,853 INFO]
# SENT 385: ['p', 'l', 'e', 'I', 't']
# PRED 385: p l e I t I d
# PRED SCORE: -0.0001
#
# [2022-03-19 08:50:10,853 INFO]
# SENT 386: ['h', '&', 'm', '@', 'r', '*']
# PRED 386: h & m @ d
# PRED SCORE: -0.0631
#
# [2022-03-19 08:50:10,854 INFO]
# SENT 387: ['h', 'V', 'v', '@', 'r', '*']
# PRED 387: h V v @ d
# PRED SCORE: -0.0009
#
# [2022-03-19 08:50:10,854 INFO]
# SENT 388: ['&', 'p', 'r', 'I', 'h', 'E', 'n', 'd']
# PRED 388: & p r I h E n d I d
# PRED SCORE: -0.0037
#
# [2022-03-19 08:50:10,854 INFO]
# SENT 389: ['d', 'I', 's', 'E', 'n', 't']
# PRED 389: d I s E n t I d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,854 INFO]
# SENT 390: ['I', 'n', 't', '@', 's', 'E', 'k', 't']
# PRED 390: I n t @ s E k t I d
# PRED SCORE: -0.0020
#
# [2022-03-19 08:50:10,925 INFO]
# SENT 391: ['s', 'k', '&', 'n', 'd', 'l', ',', 'a', 'I', 'z']
# PRED 391: s k & n d l , a I z d
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:10,925 INFO]
# SENT 392: ['S', 'a', 'I', 'n']
# PRED 392: S a I n d
# PRED SCORE: -0.0037
#
# [2022-03-19 08:50:10,926 INFO]
# SENT 393: ['p', 'I', 'N']
# PRED 393: p I N d
# PRED SCORE: -0.4257
#
# [2022-03-19 08:50:10,926 INFO]
# SENT 394: ['r', 'E', 'n', 'S']
# PRED 394: r E n S t
# PRED SCORE: -0.0012
#
# [2022-03-19 08:50:10,926 INFO]
# SENT 395: ['w', 'I', 'n', 'S']
# PRED 395: w I n S t
# PRED SCORE: -0.0086
#
# [2022-03-19 08:50:10,926 INFO]
# SENT 396: ['d', 'r', 'E', 'd', 'Z']
# PRED 396: d r E d Z d
# PRED SCORE: -0.0007
#
# [2022-03-19 08:50:10,927 INFO]
# SENT 397: ['f', 'V', 'd', 'Z']
# PRED 397: f V d Z d
# PRED SCORE: -0.0003
#
# [2022-03-19 08:50:10,927 INFO]
# SENT 398: ['l', 'A', ':', 's', 't']
# PRED 398: l A : s t I d
# PRED SCORE: -0.0006
#
# [2022-03-19 08:50:10,927 INFO]
# SENT 399: ['k', 'O', 'n', '@', 'U', 't']
# PRED 399: k O n @ U t I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,927 INFO]
# SENT 400: ['s', '3', ':', 't', 'I', 'f', 'a', 'I']
# PRED 400: s 3 : t I f a I d
# PRED SCORE: -0.0005
#
# [2022-03-19 08:50:10,927 INFO]
# SENT 401: ['p', '3', ':', 'p', 'E', 't', 'j', 'U', 'e', 'I', 't']
# PRED 401: p 3 : p E t j U e I t I d
# PRED SCORE: -0.0025
#
# [2022-03-19 08:50:10,928 INFO]
# SENT 402: ['d', '&', 'm', 'I', 'd', 'Z']
# PRED 402: d & m I d Z d
# PRED SCORE: -0.0082
#
# [2022-03-19 08:50:10,928 INFO]
# SENT 403: ['f', 'V', 'l', 'm', 'I', 'n', 'e', 'I', 't']
# PRED 403: f V l m I n e I t I d
# PRED SCORE: -0.0024
#
# [2022-03-19 08:50:10,928 INFO]
# SENT 404: ['d', 'I', 'n', '@', 'U', 't']
# PRED 404: d I n @ U t I d
# PRED SCORE: -0.0002
#
# [2022-03-19 08:50:10,928 INFO] PRED AVG SCORE: -0.0050, PRED PPL: 1.0050
