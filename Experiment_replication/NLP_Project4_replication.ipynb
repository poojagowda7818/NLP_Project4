# %%
# !pip install OpenNMT-py
# Out:
# Requirement already satisfied: OpenNMT-py in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (1.10.0+cu111)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (1.1.4)
# Requirement already satisfied: tensorboard>=2.3 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (3.13)
# Requirement already satisfied: torchtext==0.5.0 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (0.5.0)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (1.5.3)
# Requirement already satisfied: pyonmttok<2,>=1.23 in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (1.31.0)
# Requirement already satisfied: waitress in /usr/local/lib/python3.7/dist-packages (from OpenNMT-py) (2.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (1.21.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (0.1.96)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.5.0->OpenNMT-py) (4.63.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (57.4.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.37.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (3.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.3->OpenNMT-py) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.3->OpenNMT-py) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.3->OpenNMT-py) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.3->OpenNMT-py) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.3->OpenNMT-py) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.5.0->OpenNMT-py) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.3->OpenNMT-py) (3.2.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->OpenNMT-py) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->OpenNMT-py) (2.0.1)

# %% [markdown]
# # **EXPERIMENT1 REPLICATION**

# %%
#create new set of src,trg,valid

# -*- coding: utf-8 -*-

import codecs
import _pickle as cPickle
import random
from collections import defaultdict
import pandas as pd

#set up output file
fout_src_train = codecs.open('experiment_1/src_train.txt','wb','utf-8')
fout_tgt_train = codecs.open('experiment_1/tgt_train.txt','wb','utf-8')
fout_src_valid = codecs.open('experiment_1/src_valid.txt','wb','utf-8')
fout_tgt_valid = codecs.open('experiment_1/tgt_valid.txt','wb','utf-8')
fout_src_test = codecs.open('experiment_1/src_test.txt','wb','utf-8')
fout_tgt_test = codecs.open('experiment_1/tgt_test.txt','wb','utf-8')

#read in  data
fin = codecs.open('english_merged.txt','rb','utf-8')

sources = []
targets = []

for line in fin:
	parts = line.strip().split()
	lemma = parts[2]
	form = parts[3]
	sources.append(' '.join(lemma))
	targets.append(' '.join(form))
fin.close()

pairs = list(zip(sources,targets))
random.shuffle(pairs)

#split into train and test
train = pairs[:int(.8*len(pairs))]
valid = pairs[int(.8*len(pairs)):int(.9*len(pairs))]
test = pairs[int(.9*len(pairs)):]

#write the outputs
for s,t in train:
	fout_src_train.write(s + '\n')
	fout_tgt_train.write(t + '\n')

for s,t in valid:
	fout_src_valid.write(s + '\n')
	fout_tgt_valid.write(t + '\n')

for s,t in test:
	fout_src_test.write(s + '\n')
	fout_tgt_test.write(t + '\n')



fout_src_train.close()
fout_tgt_train.close()
fout_src_valid.close()
fout_tgt_valid.close()
fout_src_test.close()
fout_tgt_test.close()

# %%
# !onmt_build_vocab -config config-exp1.yaml -n_sample 10000

# %%
# !onmt_train -config config-exp1.yaml

# %%
# !onmt_translate -model experiment_1/run/model_step_1000.pt -src experiment_1/src_test.txt -output experiment_1/test-decoded.txt -gpu 0 -verbose -beam_size 12

# %% [markdown]
# ## ***Experiment_2 Replication***

# %%
# -*- coding: utf-8 -*-
"""Match train/test split from experiment 1, by lemma."""
import codecs
import _pickle as cPickle
import random
from collections import defaultdict
import pandas as pd

#set up output file
fout_src_train = codecs.open('src_train_tagged.txt','wb','utf-8')
fout_tgt_train = codecs.open('tgt_train_tagged.txt','wb','utf-8')
fout_src_valid = codecs.open('src_valid_tagged.txt','wb','utf-8')
fout_src_test = codecs.open('src_test_tagged.txt','wb','utf-8')

#modify every line in the current valid data
fin = codecs.open('experiment_1/src_valid.txt','rb','utf-8')
for line in fin:
	fout_src_valid.write('<V;PST> ' + line)
fin.close()
#modify every line in the current test data
fin = codecs.open('experiment_1/src_test.txt','rb','utf-8')
for line in fin:
	fout_src_test.write('<V;PST> ' + line)
fin.close()

#read in a set of valid lemmas from the current train data
ok_lemmas = set()
fin =  codecs.open('experiment_1/src_train.txt','rb','utf-8')
for line in fin:
	ok_lemmas.add(line.strip())
fin.close()

#read in  data
fin = codecs.open('experiment_2/english_merged.txt','rb','utf-8')

sources = []
targets = []

for line in fin:
	parts = line.strip().split()
	lemma = parts[3]
	form = parts[4]
	vec = '<' + parts[2] + '> '
	if vec != 'V;NFIN' and ' '.join(lemma) in ok_lemmas:
		sources.append(vec + ' '.join(lemma))
		targets.append(' '.join(form))	
fin.close()

pairs = list(zip(sources,targets))
random.shuffle(pairs)

#split into train and test
train = pairs

#write the outputs
for s,t in train:
	fout_src_train.write(s + '\n')
	fout_tgt_train.write(t + '\n')

fout_src_train.close()
fout_tgt_train.close()
fout_src_valid.close()
fout_src_test.close()

# %%
# !onmt_build_vocab -config config-exp2.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# path_tgt is None, it should be set unless the task is language modeling
# path_tgt is None, it should be set unless the task is language modeling
# Corpus test's weight should be given. We default it to 1 for you.
# [2022-03-22 12:33:06,636 INFO] Counter vocab from 10000 samples.
# [2022-03-22 12:33:06,636 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-03-22 12:33:06,645 INFO] corpus_1's transforms: TransformPipe()
# [2022-03-22 12:33:06,646 INFO] test's transforms: TransformPipe()
# [2022-03-22 12:33:06,751 INFO] Counters src:64
# [2022-03-22 12:33:06,751 INFO] Counters tgt:39

# %%
# !onmt_train -config config-exp2.yaml
# Out:
# [2022-03-22 12:33:13,043 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-03-22 12:33:13,043 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-03-22 12:33:13,044 INFO] Missing transforms field for valid data, set to default: [].
# [2022-03-22 12:33:13,044 WARNING] path_tgt is None, it should be set unless the task is language modeling
# [2022-03-22 12:33:13,044 INFO] Missing transforms field for test data, set to default: [].
# [2022-03-22 12:33:13,044 WARNING] path_tgt is None, it should be set unless the task is language modeling
# [2022-03-22 12:33:13,044 WARNING] Corpus test's weight should be given. We default it to 1 for you.
# [2022-03-22 12:33:13,044 INFO] Parsed 3 corpora from -data.
# [2022-03-22 12:33:13,044 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-03-22 12:33:13,044 INFO] Loading vocab from text file...
# [2022-03-22 12:33:13,044 INFO] Loading src vocabulary from experiment_2/run/example.vocab.src
# [2022-03-22 12:33:13,044 INFO] Loaded src vocab has 64 tokens.
# [2022-03-22 12:33:13,044 INFO] Loading tgt vocabulary from experiment_2/run/example.vocab.tgt
# [2022-03-22 12:33:13,045 INFO] Loaded tgt vocab has 39 tokens.
# [2022-03-22 12:33:13,045 INFO] Building fields with vocab in counters...
# [2022-03-22 12:33:13,045 INFO]  * tgt vocab size: 42.
# [2022-03-22 12:33:13,045 INFO]  * src vocab size: 67.
# [2022-03-22 12:33:13,045 INFO]  * src vocab size = 67
# [2022-03-22 12:33:13,045 INFO]  * tgt vocab size = 42
# [2022-03-22 12:33:13,046 INFO] Building model...
# [2022-03-22 12:33:16,918 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(67, 300, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(300, 50, num_layers=2, dropout=0.3, bidirectional=True)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(42, 300, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(400, 100)
#         (1): LSTMCell(100, 100)
#       )
#     )
#     (attn): GlobalAttention(
#       (linear_in): Linear(in_features=100, out_features=100, bias=False)
#       (linear_out): Linear(in_features=200, out_features=100, bias=False)
#     )
#   )
#   (generator): Sequential(
#     (0): Linear(in_features=100, out_features=42, bias=True)
#     (1): Cast()
#     (2): LogSoftmax(dim=-1)
#   )
# )
# [2022-03-22 12:33:16,918 INFO] encoder: 221700
# [2022-03-22 12:33:16,918 INFO] decoder: 328442
# [2022-03-22 12:33:16,918 INFO] * number of parameters: 550142
# [2022-03-22 12:33:16,919 INFO] Starting training on GPU: [0]
# [2022-03-22 12:33:16,919 INFO] Start training loop and validate every 500 steps...
# [2022-03-22 12:33:16,920 INFO] corpus_1's transforms: TransformPipe()
# [2022-03-22 12:33:16,920 INFO] test's transforms: TransformPipe()
# [2022-03-22 12:33:16,920 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2022-03-22 12:33:16,920 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# 			* test: 1
# [2022-03-22 12:33:16,920 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# 			* test: 1
# [2022-03-22 12:33:16,921 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# 			* test: 1
# [2022-03-22 12:33:16,921 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# 			* test: 1
# [2022-03-22 12:33:16,921 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# 			* test: 1
# [2022-03-22 12:33:16,921 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# 			* test: 1
# [2022-03-22 12:33:16,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 7
# 			* test: 1
# [2022-03-22 12:33:16,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 8
# 			* test: 1
# [2022-03-22 12:33:16,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9
# 			* test: 1
# [2022-03-22 12:33:16,923 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 10
# 			* test: 1
# [2022-03-22 12:33:16,923 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 11
# 			* test: 1
# [2022-03-22 12:33:16,923 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 12
# 			* test: 1
# [2022-03-22 12:33:16,924 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 13
# 			* test: 1
# [2022-03-22 12:33:16,924 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 14
# 			* test: 1
# [2022-03-22 12:33:16,924 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 15
# 			* test: 1
# [2022-03-22 12:33:16,924 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 16
# 			* test: 1
# [2022-03-22 12:33:16,925 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 17
# 			* test: 1
# [2022-03-22 12:33:16,925 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 17
# 			* test: 2
# [2022-03-22 12:33:16,925 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 18
# 			* test: 2
# [2022-03-22 12:33:16,925 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 19
# 			* test: 2
# [2022-03-22 12:33:16,926 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 20
# 			* test: 2
# [2022-03-22 12:33:16,926 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 21
# 			* test: 2
# [2022-03-22 12:33:16,926 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 22
# 			* test: 2
# [2022-03-22 12:33:16,927 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 23
# 			* test: 2
# [2022-03-22 12:33:16,927 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 24
# 			* test: 2
# [2022-03-22 12:33:16,927 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 25
# 			* test: 2
# [2022-03-22 12:33:16,928 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 26
# 			* test: 2
# [2022-03-22 12:33:16,928 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 27
# 			* test: 2
# [2022-03-22 12:33:16,928 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 28
# 			* test: 2
# [2022-03-22 12:33:16,928 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 29
# 			* test: 2
# [2022-03-22 12:33:16,929 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 30
# 			* test: 2
# [2022-03-22 12:33:16,929 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 31
# 			* test: 2
# [2022-03-22 12:33:16,929 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 32
# 			* test: 2
# [2022-03-22 12:33:16,930 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 33
# 			* test: 2
# [2022-03-22 12:33:16,930 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 33
# 			* test: 3
# [2022-03-22 12:33:16,930 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 34
# 			* test: 3
# [2022-03-22 12:33:16,930 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 35
# 			* test: 3
# [2022-03-22 12:33:16,931 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 36
# 			* test: 3
# [2022-03-22 12:33:16,931 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 37
# 			* test: 3
# [2022-03-22 12:33:16,931 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 38
# 			* test: 3
# [2022-03-22 12:33:16,931 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 39
# 			* test: 3
# [2022-03-22 12:33:16,932 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 40
# 			* test: 3
# [2022-03-22 12:33:16,933 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 41
# 			* test: 3
# [2022-03-22 12:33:17,804 INFO] Step 50/ 1000; acc:  20.75; ppl: 22.10; xent: 3.10; lr: 1.00000; 8063/6155 tok/s;      1 sec
# [2022-03-22 12:33:18,642 INFO] Step 100/ 1000; acc:  32.09; ppl: 12.70; xent: 2.54; lr: 1.00000; 8905/6784 tok/s;      2 sec
# [2022-03-22 12:33:18,697 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 42
# 			* test: 3
# [2022-03-22 12:33:18,697 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 43
# 			* test: 3
# [2022-03-22 12:33:18,698 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 44
# 			* test: 3
# [2022-03-22 12:33:18,698 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 45
# 			* test: 3
# [2022-03-22 12:33:18,698 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 46
# 			* test: 3
# [2022-03-22 12:33:18,699 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 47
# 			* test: 3
# [2022-03-22 12:33:18,699 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 48
# 			* test: 3
# [2022-03-22 12:33:18,699 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 49
# 			* test: 3
# [2022-03-22 12:33:18,699 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 49
# 			* test: 4
# [2022-03-22 12:33:18,700 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 50
# 			* test: 4
# [2022-03-22 12:33:18,701 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 51
# 			* test: 4
# [2022-03-22 12:33:18,701 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 52
# 			* test: 4
# [2022-03-22 12:33:18,701 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 53
# 			* test: 4
# [2022-03-22 12:33:18,702 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 54
# 			* test: 4
# [2022-03-22 12:33:18,702 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 55
# 			* test: 4
# [2022-03-22 12:33:18,703 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 56
# 			* test: 4
# [2022-03-22 12:33:18,703 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 57
# 			* test: 4
# [2022-03-22 12:33:18,703 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 58
# 			* test: 4
# [2022-03-22 12:33:18,703 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 59
# 			* test: 4
# [2022-03-22 12:33:18,704 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 60
# 			* test: 4
# [2022-03-22 12:33:18,704 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 61
# 			* test: 4
# [2022-03-22 12:33:18,704 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 62
# 			* test: 4
# [2022-03-22 12:33:18,705 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 63
# 			* test: 4
# [2022-03-22 12:33:18,705 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 64
# 			* test: 4
# [2022-03-22 12:33:18,705 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 65
# 			* test: 4
# [2022-03-22 12:33:18,706 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 65
# 			* test: 5
# [2022-03-22 12:33:18,706 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 66
# 			* test: 5
# [2022-03-22 12:33:18,706 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 67
# 			* test: 5
# [2022-03-22 12:33:18,706 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 68
# 			* test: 5
# [2022-03-22 12:33:18,707 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 69
# 			* test: 5
# [2022-03-22 12:33:18,707 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 70
# 			* test: 5
# [2022-03-22 12:33:18,707 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 71
# 			* test: 5
# [2022-03-22 12:33:18,708 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 72
# 			* test: 5
# [2022-03-22 12:33:18,708 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 73
# 			* test: 5
# [2022-03-22 12:33:18,708 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 74
# 			* test: 5
# [2022-03-22 12:33:18,709 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 75
# 			* test: 5
# [2022-03-22 12:33:18,709 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 76
# 			* test: 5
# [2022-03-22 12:33:18,709 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 77
# 			* test: 5
# [2022-03-22 12:33:18,710 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 78
# 			* test: 5
# [2022-03-22 12:33:18,710 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 79
# 			* test: 5
# [2022-03-22 12:33:18,710 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 80
# 			* test: 5
# [2022-03-22 12:33:18,710 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 81
# 			* test: 5
# [2022-03-22 12:33:18,711 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 81
# 			* test: 6
# [2022-03-22 12:33:18,711 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 82
# 			* test: 6
# [2022-03-22 12:33:19,527 INFO] Step 150/ 1000; acc:  48.20; ppl:  7.40; xent: 2.00; lr: 1.00000; 8094/6199 tok/s;      3 sec
# [2022-03-22 12:33:20,371 INFO] Step 200/ 1000; acc:  43.75; ppl:  8.33; xent: 2.12; lr: 1.00000; 8727/6562 tok/s;      3 sec
# [2022-03-22 12:33:20,488 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 83
# 			* test: 6
# [2022-03-22 12:33:20,489 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 84
# 			* test: 6
# [2022-03-22 12:33:20,489 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 85
# 			* test: 6
# [2022-03-22 12:33:20,489 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 86
# 			* test: 6
# [2022-03-22 12:33:20,489 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 87
# 			* test: 6
# [2022-03-22 12:33:20,490 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 88
# 			* test: 6
# [2022-03-22 12:33:20,490 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 89
# 			* test: 6
# [2022-03-22 12:33:20,490 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 90
# 			* test: 6
# [2022-03-22 12:33:20,491 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 91
# 			* test: 6
# [2022-03-22 12:33:20,491 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 92
# 			* test: 6
# [2022-03-22 12:33:20,491 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 93
# 			* test: 6
# [2022-03-22 12:33:20,492 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 94
# 			* test: 6
# [2022-03-22 12:33:20,492 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 95
# 			* test: 6
# [2022-03-22 12:33:20,492 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 96
# 			* test: 6
# [2022-03-22 12:33:20,492 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 97
# 			* test: 6
# [2022-03-22 12:33:20,493 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 97
# 			* test: 7
# [2022-03-22 12:33:20,493 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 98
# 			* test: 7
# [2022-03-22 12:33:20,493 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 99
# 			* test: 7
# [2022-03-22 12:33:20,493 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 100
# 			* test: 7
# [2022-03-22 12:33:20,494 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 101
# 			* test: 7
# [2022-03-22 12:33:20,494 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 102
# 			* test: 7
# [2022-03-22 12:33:20,494 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 103
# 			* test: 7
# [2022-03-22 12:33:20,494 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 104
# 			* test: 7
# [2022-03-22 12:33:20,495 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 105
# 			* test: 7
# [2022-03-22 12:33:20,495 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 106
# 			* test: 7
# [2022-03-22 12:33:20,495 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 107
# 			* test: 7
# [2022-03-22 12:33:20,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 108
# 			* test: 7
# [2022-03-22 12:33:20,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 109
# 			* test: 7
# [2022-03-22 12:33:20,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 110
# 			* test: 7
# [2022-03-22 12:33:20,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 111
# 			* test: 7
# [2022-03-22 12:33:20,497 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 112
# 			* test: 7
# [2022-03-22 12:33:20,497 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 113
# 			* test: 7
# [2022-03-22 12:33:20,497 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 114
# 			* test: 7
# [2022-03-22 12:33:20,497 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 114
# 			* test: 8
# [2022-03-22 12:33:20,498 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 115
# 			* test: 8
# [2022-03-22 12:33:20,498 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 116
# 			* test: 8
# [2022-03-22 12:33:20,498 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 117
# 			* test: 8
# [2022-03-22 12:33:20,499 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 118
# 			* test: 8
# [2022-03-22 12:33:20,499 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 119
# 			* test: 8
# [2022-03-22 12:33:20,499 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 120
# 			* test: 8
# [2022-03-22 12:33:20,499 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 121
# 			* test: 8
# [2022-03-22 12:33:20,500 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 122
# 			* test: 8
# [2022-03-22 12:33:20,500 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 123
# 			* test: 8
# [2022-03-22 12:33:21,319 INFO] Step 250/ 1000; acc:  46.13; ppl:  7.35; xent: 1.99; lr: 1.00000; 7707/6060 tok/s;      4 sec
# [2022-03-22 12:33:22,144 INFO] Step 300/ 1000; acc:  47.87; ppl:  6.89; xent: 1.93; lr: 1.00000; 8926/6667 tok/s;      5 sec
# [2022-03-22 12:33:22,296 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 124
# 			* test: 8
# [2022-03-22 12:33:22,297 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 125
# 			* test: 8
# [2022-03-22 12:33:22,297 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 126
# 			* test: 8
# [2022-03-22 12:33:22,297 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 127
# 			* test: 8
# [2022-03-22 12:33:22,298 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 128
# 			* test: 8
# [2022-03-22 12:33:22,298 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 129
# 			* test: 8
# [2022-03-22 12:33:22,298 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 130
# 			* test: 8
# [2022-03-22 12:33:22,299 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 130
# 			* test: 9
# [2022-03-22 12:33:22,299 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 131
# 			* test: 9
# [2022-03-22 12:33:22,299 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 132
# 			* test: 9
# [2022-03-22 12:33:22,299 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 133
# 			* test: 9
# [2022-03-22 12:33:22,300 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 134
# 			* test: 9
# [2022-03-22 12:33:22,300 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 135
# 			* test: 9
# [2022-03-22 12:33:22,300 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 136
# 			* test: 9
# [2022-03-22 12:33:22,301 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 137
# 			* test: 9
# [2022-03-22 12:33:22,301 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 138
# 			* test: 9
# [2022-03-22 12:33:22,301 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 139
# 			* test: 9
# [2022-03-22 12:33:22,301 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 140
# 			* test: 9
# [2022-03-22 12:33:22,302 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 141
# 			* test: 9
# [2022-03-22 12:33:22,302 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 142
# 			* test: 9
# [2022-03-22 12:33:22,302 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 143
# 			* test: 9
# [2022-03-22 12:33:22,303 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 144
# 			* test: 9
# [2022-03-22 12:33:22,303 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 145
# 			* test: 9
# [2022-03-22 12:33:22,303 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 146
# 			* test: 9
# [2022-03-22 12:33:22,303 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 146
# 			* test: 10
# [2022-03-22 12:33:22,304 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 147
# 			* test: 10
# [2022-03-22 12:33:22,304 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 148
# 			* test: 10
# [2022-03-22 12:33:22,304 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 149
# 			* test: 10
# [2022-03-22 12:33:22,305 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 150
# 			* test: 10
# [2022-03-22 12:33:22,306 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 151
# 			* test: 10
# [2022-03-22 12:33:22,306 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 152
# 			* test: 10
# [2022-03-22 12:33:22,306 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 153
# 			* test: 10
# [2022-03-22 12:33:22,306 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 154
# 			* test: 10
# [2022-03-22 12:33:22,307 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 155
# 			* test: 10
# [2022-03-22 12:33:22,307 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 156
# 			* test: 10
# [2022-03-22 12:33:22,307 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 157
# 			* test: 10
# [2022-03-22 12:33:22,308 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 158
# 			* test: 10
# [2022-03-22 12:33:22,308 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 159
# 			* test: 10
# [2022-03-22 12:33:22,308 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 160
# 			* test: 10
# [2022-03-22 12:33:22,308 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 161
# 			* test: 10
# [2022-03-22 12:33:22,309 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 162
# 			* test: 10
# [2022-03-22 12:33:22,309 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 162
# 			* test: 11
# [2022-03-22 12:33:22,309 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 163
# 			* test: 11
# [2022-03-22 12:33:22,309 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 164
# 			* test: 11
# [2022-03-22 12:33:23,019 INFO] Step 350/ 1000; acc:  49.74; ppl:  6.33; xent: 1.84; lr: 1.00000; 8373/6540 tok/s;      6 sec
# [2022-03-22 12:33:23,862 INFO] Step 400/ 1000; acc:  54.27; ppl:  5.12; xent: 1.63; lr: 1.00000; 8705/6524 tok/s;      7 sec
# [2022-03-22 12:33:24,070 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 165
# 			* test: 11
# [2022-03-22 12:33:24,070 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 166
# 			* test: 11
# [2022-03-22 12:33:24,071 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 167
# 			* test: 11
# [2022-03-22 12:33:24,071 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 168
# 			* test: 11
# [2022-03-22 12:33:24,071 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 169
# 			* test: 11
# [2022-03-22 12:33:24,071 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 170
# 			* test: 11
# [2022-03-22 12:33:24,072 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 171
# 			* test: 11
# [2022-03-22 12:33:24,072 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 172
# 			* test: 11
# [2022-03-22 12:33:24,072 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 173
# 			* test: 11
# [2022-03-22 12:33:24,073 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 174
# 			* test: 11
# [2022-03-22 12:33:24,073 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 175
# 			* test: 11
# [2022-03-22 12:33:24,073 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 176
# 			* test: 11
# [2022-03-22 12:33:24,074 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 177
# 			* test: 11
# [2022-03-22 12:33:24,074 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 178
# 			* test: 11
# [2022-03-22 12:33:24,074 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 178
# 			* test: 12
# [2022-03-22 12:33:24,074 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 179
# 			* test: 12
# [2022-03-22 12:33:24,076 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 180
# 			* test: 12
# [2022-03-22 12:33:24,076 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 181
# 			* test: 12
# [2022-03-22 12:33:24,077 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 182
# 			* test: 12
# [2022-03-22 12:33:24,077 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 183
# 			* test: 12
# [2022-03-22 12:33:24,077 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 184
# 			* test: 12
# [2022-03-22 12:33:24,077 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 185
# 			* test: 12
# [2022-03-22 12:33:24,078 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 186
# 			* test: 12
# [2022-03-22 12:33:24,078 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 187
# 			* test: 12
# [2022-03-22 12:33:24,078 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 188
# 			* test: 12
# [2022-03-22 12:33:24,079 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 189
# 			* test: 12
# [2022-03-22 12:33:24,079 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 190
# 			* test: 12
# [2022-03-22 12:33:24,079 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 191
# 			* test: 12
# [2022-03-22 12:33:24,080 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 192
# 			* test: 12
# [2022-03-22 12:33:24,080 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 193
# 			* test: 12
# [2022-03-22 12:33:24,080 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 194
# 			* test: 12
# [2022-03-22 12:33:24,081 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 194
# 			* test: 13
# [2022-03-22 12:33:24,081 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 195
# 			* test: 13
# [2022-03-22 12:33:24,081 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 196
# 			* test: 13
# [2022-03-22 12:33:24,081 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 197
# 			* test: 13
# [2022-03-22 12:33:24,082 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 198
# 			* test: 13
# [2022-03-22 12:33:24,082 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 199
# 			* test: 13
# [2022-03-22 12:33:24,083 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 200
# 			* test: 13
# [2022-03-22 12:33:24,083 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 201
# 			* test: 13
# [2022-03-22 12:33:24,083 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 202
# 			* test: 13
# [2022-03-22 12:33:24,083 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 203
# 			* test: 13
# [2022-03-22 12:33:24,084 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 204
# 			* test: 13
# [2022-03-22 12:33:24,084 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 205
# 			* test: 13
# [2022-03-22 12:33:24,764 INFO] Step 450/ 1000; acc:  56.34; ppl:  4.63; xent: 1.53; lr: 1.00000; 8058/6220 tok/s;      8 sec
# [2022-03-22 12:33:25,613 INFO] Step 500/ 1000; acc:  61.38; ppl:  3.87; xent: 1.35; lr: 1.00000; 8594/6488 tok/s;      9 sec
# [2022-03-22 12:33:25,613 INFO] valid's transforms: TransformPipe()
# [2022-03-22 12:33:25,749 INFO] Validation perplexity: 7.00421
# [2022-03-22 12:33:25,749 INFO] Validation accuracy: 44.2769
# [2022-03-22 12:33:25,750 INFO] Saving checkpoint experiment_2/run/model_step_500.pt
# [2022-03-22 12:33:26,032 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 206
# 			* test: 13
# [2022-03-22 12:33:26,033 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 207
# 			* test: 13
# [2022-03-22 12:33:26,033 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 208
# 			* test: 13
# [2022-03-22 12:33:26,033 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 209
# 			* test: 13
# [2022-03-22 12:33:26,033 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 210
# 			* test: 13
# [2022-03-22 12:33:26,034 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 211
# 			* test: 13
# [2022-03-22 12:33:26,034 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 211
# 			* test: 14
# [2022-03-22 12:33:26,034 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 212
# 			* test: 14
# [2022-03-22 12:33:26,035 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 213
# 			* test: 14
# [2022-03-22 12:33:26,035 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 214
# 			* test: 14
# [2022-03-22 12:33:26,035 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 215
# 			* test: 14
# [2022-03-22 12:33:26,035 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 216
# 			* test: 14
# [2022-03-22 12:33:26,036 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 217
# 			* test: 14
# [2022-03-22 12:33:26,036 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 218
# 			* test: 14
# [2022-03-22 12:33:26,037 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 219
# 			* test: 14
# [2022-03-22 12:33:26,037 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 220
# 			* test: 14
# [2022-03-22 12:33:26,037 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 221
# 			* test: 14
# [2022-03-22 12:33:26,038 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 222
# 			* test: 14
# [2022-03-22 12:33:26,038 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 223
# 			* test: 14
# [2022-03-22 12:33:26,038 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 224
# 			* test: 14
# [2022-03-22 12:33:26,039 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 225
# 			* test: 14
# [2022-03-22 12:33:26,039 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 226
# 			* test: 14
# [2022-03-22 12:33:26,039 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 227
# 			* test: 14
# [2022-03-22 12:33:26,039 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 227
# 			* test: 15
# [2022-03-22 12:33:26,040 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 228
# 			* test: 15
# [2022-03-22 12:33:26,040 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 229
# 			* test: 15
# [2022-03-22 12:33:26,040 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 230
# 			* test: 15
# [2022-03-22 12:33:26,041 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 231
# 			* test: 15
# [2022-03-22 12:33:26,041 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 232
# 			* test: 15
# [2022-03-22 12:33:26,041 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 233
# 			* test: 15
# [2022-03-22 12:33:26,042 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 234
# 			* test: 15
# [2022-03-22 12:33:26,042 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 235
# 			* test: 15
# [2022-03-22 12:33:26,042 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 236
# 			* test: 15
# [2022-03-22 12:33:26,043 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 237
# 			* test: 15
# [2022-03-22 12:33:26,043 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 238
# 			* test: 15
# [2022-03-22 12:33:26,043 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 239
# 			* test: 15
# [2022-03-22 12:33:26,043 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 240
# 			* test: 15
# [2022-03-22 12:33:26,044 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 241
# 			* test: 15
# [2022-03-22 12:33:26,044 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 242
# 			* test: 15
# [2022-03-22 12:33:26,044 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 243
# 			* test: 15
# [2022-03-22 12:33:26,045 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 243
# 			* test: 16
# [2022-03-22 12:33:26,045 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 244
# 			* test: 16
# [2022-03-22 12:33:26,045 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 245
# 			* test: 16
# [2022-03-22 12:33:26,045 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 246
# 			* test: 16
# [2022-03-22 12:33:26,661 INFO] Step 550/ 1000; acc:  64.04; ppl:  3.52; xent: 1.26; lr: 1.00000; 6900/5236 tok/s;     10 sec
# [2022-03-22 12:33:27,511 INFO] Step 600/ 1000; acc:  63.87; ppl:  3.37; xent: 1.22; lr: 1.00000; 8684/6683 tok/s;     11 sec
# [2022-03-22 12:33:27,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 247
# 			* test: 16
# [2022-03-22 12:33:27,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 248
# 			* test: 16
# [2022-03-22 12:33:27,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 249
# 			* test: 16
# [2022-03-22 12:33:27,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 250
# 			* test: 16
# [2022-03-22 12:33:27,830 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 251
# 			* test: 16
# [2022-03-22 12:33:27,830 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 252
# 			* test: 16
# [2022-03-22 12:33:27,831 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 253
# 			* test: 16
# [2022-03-22 12:33:27,831 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 254
# 			* test: 16
# [2022-03-22 12:33:27,831 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 255
# 			* test: 16
# [2022-03-22 12:33:27,831 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 256
# 			* test: 16
# [2022-03-22 12:33:27,832 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 257
# 			* test: 16
# [2022-03-22 12:33:27,832 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 258
# 			* test: 16
# [2022-03-22 12:33:27,832 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 259
# 			* test: 16
# [2022-03-22 12:33:27,833 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 259
# 			* test: 17
# [2022-03-22 12:33:27,833 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 260
# 			* test: 17
# [2022-03-22 12:33:27,833 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 261
# 			* test: 17
# [2022-03-22 12:33:27,833 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 262
# 			* test: 17
# [2022-03-22 12:33:27,834 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 263
# 			* test: 17
# [2022-03-22 12:33:27,834 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 264
# 			* test: 17
# [2022-03-22 12:33:27,834 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 265
# 			* test: 17
# [2022-03-22 12:33:27,834 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 266
# 			* test: 17
# [2022-03-22 12:33:27,835 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 267
# 			* test: 17
# [2022-03-22 12:33:27,835 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 268
# 			* test: 17
# [2022-03-22 12:33:27,835 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 269
# 			* test: 17
# [2022-03-22 12:33:27,836 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 270
# 			* test: 17
# [2022-03-22 12:33:27,836 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 271
# 			* test: 17
# [2022-03-22 12:33:27,836 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 272
# 			* test: 17
# [2022-03-22 12:33:27,837 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 273
# 			* test: 17
# [2022-03-22 12:33:27,837 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 274
# 			* test: 17
# [2022-03-22 12:33:27,837 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 275
# 			* test: 17
# [2022-03-22 12:33:27,837 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 275
# 			* test: 18
# [2022-03-22 12:33:27,838 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 276
# 			* test: 18
# [2022-03-22 12:33:27,838 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 277
# 			* test: 18
# [2022-03-22 12:33:27,838 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 278
# 			* test: 18
# [2022-03-22 12:33:27,838 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 279
# 			* test: 18
# [2022-03-22 12:33:27,839 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 280
# 			* test: 18
# [2022-03-22 12:33:27,839 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 281
# 			* test: 18
# [2022-03-22 12:33:27,839 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 282
# 			* test: 18
# [2022-03-22 12:33:27,839 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 283
# 			* test: 18
# [2022-03-22 12:33:27,840 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 284
# 			* test: 18
# [2022-03-22 12:33:27,842 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 285
# 			* test: 18
# [2022-03-22 12:33:27,842 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 286
# 			* test: 18
# [2022-03-22 12:33:27,842 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 287
# 			* test: 18
# [2022-03-22 12:33:28,398 INFO] Step 650/ 1000; acc:  70.42; ppl:  2.74; xent: 1.01; lr: 1.00000; 8167/6227 tok/s;     11 sec
# [2022-03-22 12:33:29,213 INFO] Step 700/ 1000; acc:  73.39; ppl:  2.45; xent: 0.90; lr: 1.00000; 9030/6842 tok/s;     12 sec
# [2022-03-22 12:33:29,573 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 288
# 			* test: 18
# [2022-03-22 12:33:29,573 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 289
# 			* test: 18
# [2022-03-22 12:33:29,574 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 290
# 			* test: 18
# [2022-03-22 12:33:29,574 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 291
# 			* test: 18
# [2022-03-22 12:33:29,574 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 291
# 			* test: 19
# [2022-03-22 12:33:29,574 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 292
# 			* test: 19
# [2022-03-22 12:33:29,575 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 293
# 			* test: 19
# [2022-03-22 12:33:29,575 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 294
# 			* test: 19
# [2022-03-22 12:33:29,576 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 295
# 			* test: 19
# [2022-03-22 12:33:29,576 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 296
# 			* test: 19
# [2022-03-22 12:33:29,576 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 297
# 			* test: 19
# [2022-03-22 12:33:29,576 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 298
# 			* test: 19
# [2022-03-22 12:33:29,577 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 299
# 			* test: 19
# [2022-03-22 12:33:29,577 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 300
# 			* test: 19
# [2022-03-22 12:33:29,577 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 301
# 			* test: 19
# [2022-03-22 12:33:29,578 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 302
# 			* test: 19
# [2022-03-22 12:33:29,578 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 303
# 			* test: 19
# [2022-03-22 12:33:29,578 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 304
# 			* test: 19
# [2022-03-22 12:33:29,579 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 305
# 			* test: 19
# [2022-03-22 12:33:29,579 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 306
# 			* test: 19
# [2022-03-22 12:33:29,579 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 307
# 			* test: 19
# [2022-03-22 12:33:29,580 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 308
# 			* test: 19
# [2022-03-22 12:33:29,580 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 308
# 			* test: 20
# [2022-03-22 12:33:29,580 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 309
# 			* test: 20
# [2022-03-22 12:33:29,580 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 310
# 			* test: 20
# [2022-03-22 12:33:29,580 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 311
# 			* test: 20
# [2022-03-22 12:33:29,581 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 312
# 			* test: 20
# [2022-03-22 12:33:29,581 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 313
# 			* test: 20
# [2022-03-22 12:33:29,581 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 314
# 			* test: 20
# [2022-03-22 12:33:29,582 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 315
# 			* test: 20
# [2022-03-22 12:33:29,582 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 316
# 			* test: 20
# [2022-03-22 12:33:29,582 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 317
# 			* test: 20
# [2022-03-22 12:33:29,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 318
# 			* test: 20
# [2022-03-22 12:33:29,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 319
# 			* test: 20
# [2022-03-22 12:33:29,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 320
# 			* test: 20
# [2022-03-22 12:33:29,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 321
# 			* test: 20
# [2022-03-22 12:33:29,585 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 322
# 			* test: 20
# [2022-03-22 12:33:29,585 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 323
# 			* test: 20
# [2022-03-22 12:33:29,586 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 324
# 			* test: 20
# [2022-03-22 12:33:29,586 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 324
# 			* test: 21
# [2022-03-22 12:33:29,586 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 325
# 			* test: 21
# [2022-03-22 12:33:29,586 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 326
# 			* test: 21
# [2022-03-22 12:33:29,618 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 327
# 			* test: 21
# [2022-03-22 12:33:29,619 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 328
# 			* test: 21
# [2022-03-22 12:33:30,151 INFO] Step 750/ 1000; acc:  78.67; ppl:  2.15; xent: 0.76; lr: 1.00000; 7705/5968 tok/s;     13 sec
# [2022-03-22 12:33:30,981 INFO] Step 800/ 1000; acc:  82.03; ppl:  1.93; xent: 0.66; lr: 1.00000; 8967/6714 tok/s;     14 sec
# [2022-03-22 12:33:31,407 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 329
# 			* test: 21
# [2022-03-22 12:33:31,407 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 330
# 			* test: 21
# [2022-03-22 12:33:31,408 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 331
# 			* test: 21
# [2022-03-22 12:33:31,408 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 332
# 			* test: 21
# [2022-03-22 12:33:31,408 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 333
# 			* test: 21
# [2022-03-22 12:33:31,409 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 334
# 			* test: 21
# [2022-03-22 12:33:31,409 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 335
# 			* test: 21
# [2022-03-22 12:33:31,409 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 336
# 			* test: 21
# [2022-03-22 12:33:31,410 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 337
# 			* test: 21
# [2022-03-22 12:33:31,410 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 338
# 			* test: 21
# [2022-03-22 12:33:31,410 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 339
# 			* test: 21
# [2022-03-22 12:33:31,410 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 340
# 			* test: 21
# [2022-03-22 12:33:31,411 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 340
# 			* test: 22
# [2022-03-22 12:33:31,411 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 341
# 			* test: 22
# [2022-03-22 12:33:31,411 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 342
# 			* test: 22
# [2022-03-22 12:33:31,411 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 343
# 			* test: 22
# [2022-03-22 12:33:31,412 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 344
# 			* test: 22
# [2022-03-22 12:33:31,412 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 345
# 			* test: 22
# [2022-03-22 12:33:31,412 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 346
# 			* test: 22
# [2022-03-22 12:33:31,413 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 347
# 			* test: 22
# [2022-03-22 12:33:31,413 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 348
# 			* test: 22
# [2022-03-22 12:33:31,414 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 349
# 			* test: 22
# [2022-03-22 12:33:31,415 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 350
# 			* test: 22
# [2022-03-22 12:33:31,415 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 351
# 			* test: 22
# [2022-03-22 12:33:31,415 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 352
# 			* test: 22
# [2022-03-22 12:33:31,416 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 353
# 			* test: 22
# [2022-03-22 12:33:31,416 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 354
# 			* test: 22
# [2022-03-22 12:33:31,416 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 355
# 			* test: 22
# [2022-03-22 12:33:31,416 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 356
# 			* test: 22
# [2022-03-22 12:33:31,417 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 356
# 			* test: 23
# [2022-03-22 12:33:31,417 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 357
# 			* test: 23
# [2022-03-22 12:33:31,417 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 358
# 			* test: 23
# [2022-03-22 12:33:31,417 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 359
# 			* test: 23
# [2022-03-22 12:33:31,418 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 360
# 			* test: 23
# [2022-03-22 12:33:31,418 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 361
# 			* test: 23
# [2022-03-22 12:33:31,418 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 362
# 			* test: 23
# [2022-03-22 12:33:31,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 363
# 			* test: 23
# [2022-03-22 12:33:31,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 364
# 			* test: 23
# [2022-03-22 12:33:31,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 365
# 			* test: 23
# [2022-03-22 12:33:31,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 366
# 			* test: 23
# [2022-03-22 12:33:31,420 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 367
# 			* test: 23
# [2022-03-22 12:33:31,420 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 368
# 			* test: 23
# [2022-03-22 12:33:31,420 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 369
# 			* test: 23
# [2022-03-22 12:33:31,897 INFO] Step 850/ 1000; acc:  86.96; ppl:  1.69; xent: 0.53; lr: 1.00000; 7822/6080 tok/s;     15 sec
# [2022-03-22 12:33:32,738 INFO] Step 900/ 1000; acc:  87.78; ppl:  1.64; xent: 0.49; lr: 1.00000; 8806/6534 tok/s;     16 sec
# [2022-03-22 12:33:33,221 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 370
# 			* test: 23
# [2022-03-22 12:33:33,221 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 371
# 			* test: 23
# [2022-03-22 12:33:33,221 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 372
# 			* test: 23
# [2022-03-22 12:33:33,222 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 372
# 			* test: 24
# [2022-03-22 12:33:33,222 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 373
# 			* test: 24
# [2022-03-22 12:33:33,222 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 374
# 			* test: 24
# [2022-03-22 12:33:33,222 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 375
# 			* test: 24
# [2022-03-22 12:33:33,223 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 376
# 			* test: 24
# [2022-03-22 12:33:33,223 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 377
# 			* test: 24
# [2022-03-22 12:33:33,223 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 378
# 			* test: 24
# [2022-03-22 12:33:33,224 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 379
# 			* test: 24
# [2022-03-22 12:33:33,224 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 380
# 			* test: 24
# [2022-03-22 12:33:33,224 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 381
# 			* test: 24
# [2022-03-22 12:33:33,225 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 382
# 			* test: 24
# [2022-03-22 12:33:33,225 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 383
# 			* test: 24
# [2022-03-22 12:33:33,225 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 384
# 			* test: 24
# [2022-03-22 12:33:33,227 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 385
# 			* test: 24
# [2022-03-22 12:33:33,227 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 386
# 			* test: 24
# [2022-03-22 12:33:33,227 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 387
# 			* test: 24
# [2022-03-22 12:33:33,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 388
# 			* test: 24
# [2022-03-22 12:33:33,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 388
# 			* test: 25
# [2022-03-22 12:33:33,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 389
# 			* test: 25
# [2022-03-22 12:33:33,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 390
# 			* test: 25
# [2022-03-22 12:33:33,229 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 391
# 			* test: 25
# [2022-03-22 12:33:33,229 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 392
# 			* test: 25
# [2022-03-22 12:33:33,229 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 393
# 			* test: 25
# [2022-03-22 12:33:33,230 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 394
# 			* test: 25
# [2022-03-22 12:33:33,230 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 395
# 			* test: 25
# [2022-03-22 12:33:33,230 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 396
# 			* test: 25
# [2022-03-22 12:33:33,230 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 397
# 			* test: 25
# [2022-03-22 12:33:33,231 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 398
# 			* test: 25
# [2022-03-22 12:33:33,231 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 399
# 			* test: 25
# [2022-03-22 12:33:33,231 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 400
# 			* test: 25
# [2022-03-22 12:33:33,231 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 401
# 			* test: 25
# [2022-03-22 12:33:33,232 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 402
# 			* test: 25
# [2022-03-22 12:33:33,232 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 403
# 			* test: 25
# [2022-03-22 12:33:33,232 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 404
# 			* test: 25
# [2022-03-22 12:33:33,233 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 405
# 			* test: 25
# [2022-03-22 12:33:33,233 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 405
# 			* test: 26
# [2022-03-22 12:33:33,233 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 406
# 			* test: 26
# [2022-03-22 12:33:33,233 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 407
# 			* test: 26
# [2022-03-22 12:33:33,234 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 408
# 			* test: 26
# [2022-03-22 12:33:33,234 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 409
# 			* test: 26
# [2022-03-22 12:33:33,234 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 410
# 			* test: 26
# [2022-03-22 12:33:33,621 INFO] Step 950/ 1000; acc:  91.13; ppl:  1.46; xent: 0.38; lr: 1.00000; 8311/6489 tok/s;     17 sec
# [2022-03-22 12:33:34,503 INFO] Step 1000/ 1000; acc:  92.65; ppl:  1.42; xent: 0.35; lr: 1.00000; 8200/6094 tok/s;     18 sec
# [2022-03-22 12:33:34,659 INFO] Validation perplexity: 1.51273
# [2022-03-22 12:33:34,659 INFO] Validation accuracy: 91.9123
# [2022-03-22 12:33:34,660 INFO] Saving checkpoint experiment_2/run/model_step_1000.pt

# %%
# !onmt_translate -model experiment_2/run/model_step_1000.pt -src experiment_2/src_test_tagged.txt -output experiment_2/test-decoded.txt -gpu 0 -verbose -beam_size 12
# Out:
# [2022-03-22 12:34:02,774 INFO] Translating shard 0.
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:282: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   self._batch_index = self.topk_ids // vocab_size
# [2022-03-22 12:34:02,827 INFO]
# SENT 1: ['<V;PST>', 'k', 'l', 'O', 'z', 'I', 't']
# PRED 1: k l O z I t
# PRED SCORE: -1.9059
#
# [2022-03-22 12:34:02,827 INFO]
# SENT 2: ['<V;PST>', 'p', '@', 'U', 's', 't']
# PRED 2: r r e g
# PRED SCORE: -0.1182
#
# [2022-03-22 12:34:02,827 INFO]
# SENT 3: ['<V;PST>', 'v', '&', 'l', 'j', 'U']
# PRED 3: O d l u :
# PRED SCORE: -4.2385
#
# [2022-03-22 12:34:02,827 INFO]
# SENT 4: ['<V;PST>', 'I', 'N', 'k', 'A', ':', 's', '@', 'r', 'e', 'I', 't']
# PRED 4: I m k A : s @ r e I t
# PRED SCORE: -2.7431
#
# [2022-03-22 12:34:02,827 INFO]
# SENT 5: ['<V;PST>', 'f', 'I', 'd', 'Z', 'I', 't']
# PRED 5: a e I m t
# PRED SCORE: -2.1309
#
# [2022-03-22 12:34:02,827 INFO]
# SENT 6: ['<V;PST>', 'm', '@', 'U', 't', '@', 'r', 'a', 'I', 'z']
# PRED 6: V @ U t @ r a I z
# PRED SCORE: -1.8716
#
# [2022-03-22 12:34:02,827 INFO]
# SENT 7: ['<V;PST>', 'v', 'E', 'd', 'Z', '@', 't', 'e', 'I', 't']
# PRED 7: O E d Z @ t e I t
# PRED SCORE: -1.8761
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 8: ['<V;PST>', 'm', 'e', 'I', 'm']
# PRED 8: a e g
# PRED SCORE: -1.0975
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 9: ['<V;PST>', 't', 'i', ':', 'z']
# PRED 9: r e g
# PRED SCORE: -0.6040
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 10: ['<V;PST>', 'I', 'N', 'k', '@', 'n', 'v', 'i', ':', 'n', 'I', '@', 'n', 's']
# PRED 10: e I S @ n n i : n d
# PRED SCORE: -5.2067
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 11: ['<V;PST>', '@', 'p', 'E', 'n', 'd']
# PRED 11: r r e g
# PRED SCORE: -0.5548
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 12: ['<V;PST>', 't', 'r', 'I', 'g', '@', 'r', '*']
# PRED 12: t r I g @ r *
# PRED SCORE: -1.7059
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 13: ['<V;PST>', '@', 'b', 'z', 't', 'r', 'V', 'k', 't']
# PRED 13: r r e g
# PRED SCORE: -0.3649
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 14: ['<V;PST>', 'k', 'a', 'U', 'n', 's', 'l', ',']
# PRED 14: k a U n s l ,
# PRED SCORE: -1.6576
#
# [2022-03-22 12:34:02,828 INFO]
# SENT 15: ['<V;PST>', 'd', 'I', 's', 'O', 'r', 'I', '@', 'n', 't']
# PRED 15: d I s O r I n t
# PRED SCORE: -2.0968
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 16: ['<V;PST>', 'S', 'E', 'l', 'v']
# PRED 16: V t l ,
# PRED SCORE: -2.1421
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 17: ['<V;PST>', 's', 't', 'I', 'l']
# PRED 17: E t I l
# PRED SCORE: -0.5790
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 18: ['<V;PST>', '@', 'd', 'Z', 'V', 's', 't']
# PRED 18: r e g s t
# PRED SCORE: -1.1294
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 19: ['<V;PST>', 'r', '@', 'z', '3', ':', 'v']
# PRED 19: r r e g
# PRED SCORE: -0.0060
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 20: ['<V;PST>', 'n', '&', 'g']
# PRED 20: @ n I
# PRED SCORE: -2.1067
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 21: ['<V;PST>', 'p', '@', 't', 'I', 'k', 'j', '@', 'l', '@', 'r', 'a', 'I', 'z']
# PRED 21: r r e g
# PRED SCORE: -0.2167
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 22: ['<V;PST>', 'w', 'O', ':', 't', '@', 'r', '*']
# PRED 22: w O : t @ r *
# PRED SCORE: -2.8509
#
# [2022-03-22 12:34:02,829 INFO]
# SENT 23: ['<V;PST>', 'h', 'V', 'N', 'g', '@', 'r', '*']
# PRED 23: h V m g @ r *
# PRED SCORE: -2.2175
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 24: ['<V;PST>', 't', 'S', '3', ':', 'n']
# PRED 24: t O : v
# PRED SCORE: -2.4656
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 25: ['<V;PST>', 't', 'I', 'p']
# PRED 25: e I
# PRED SCORE: -0.3735
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 26: ['<V;PST>', 'b', 'r', '&', 'n', 'd', 'I', 'S']
# PRED 26: b r e I l
# PRED SCORE: -1.9656
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 27: ['<V;PST>', 'k', 'e', 'I', 'd', 'Z']
# PRED 27: k e I d
# PRED SCORE: -1.2223
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 28: ['<V;PST>', 'E', 'g', 'z', '&', 'k', 't']
# PRED 28: E g z & k t
# PRED SCORE: -1.2131
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 29: ['<V;PST>', 'k', 'r', 'a', 'U', 'n']
# PRED 29: E r a U n
# PRED SCORE: -1.6647
#
# [2022-03-22 12:34:02,830 INFO]
# SENT 30: ['<V;PST>', 'd', 'I', 'f', 'O', 'l', 't']
# PRED 30: d I f O l t
# PRED SCORE: -1.1831
#
# [2022-03-22 12:34:02,877 INFO]
# SENT 31: ['<V;PST>', 'I', 'k', 'w', 'I', 'v', 'U', 'k', 'e', 'I', 't']
# PRED 31: I k w I v i U k e I t
# PRED SCORE: -4.6883
#
# [2022-03-22 12:34:02,877 INFO]
# SENT 32: ['<V;PST>', 's', 'I', 'g', 'n', 'I', 'f', 'a', 'I']
# PRED 32: E I g n I f a I
# PRED SCORE: -1.5944
#
# [2022-03-22 12:34:02,877 INFO]
# SENT 33: ['<V;PST>', 'w', 'U', 'l', 'f']
# PRED 33: w r e g
# PRED SCORE: -1.5290
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 34: ['<V;PST>', 's', '@', 'r', 'a', 'U', 'n', 'd']
# PRED 34: E @ r a U n d
# PRED SCORE: -1.2836
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 35: ['<V;PST>', 's', 'l', 'e', 'I', 't']
# PRED 35: E l e I t
# PRED SCORE: -0.8931
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 36: ['<V;PST>', 'm', 'E', 'm', 'r', 'a', 'I', 'z']
# PRED 36: m E m r a I z
# PRED SCORE: -2.3340
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 37: ['<V;PST>', 'r', 'a', 'I', 'D']
# PRED 37: r e g
# PRED SCORE: -0.0080
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 38: ['<V;PST>', '@', 'p', 'r', 'a', 'I', 'z']
# PRED 38: r r e g
# PRED SCORE: -1.0461
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 39: ['<V;PST>', 'l', 'I', 'k']
# PRED 39: l I l
# PRED SCORE: -1.1005
#
# [2022-03-22 12:34:02,878 INFO]
# SENT 40: ['<V;PST>', 'r', '@', 'z', 'a', 'I', 'n']
# PRED 40: r r e g
# PRED SCORE: -0.0139
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 41: ['<V;PST>', 'h', 'V', 'm']
# PRED 41: u V m
# PRED SCORE: -1.8647
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 42: ['<V;PST>', 'd', 'r', 'e', 'I', 'p']
# PRED 42: I r e I p
# PRED SCORE: -1.3495
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 43: ['<V;PST>', '&', 'n', '@', 't', 'e', 'I', 't']
# PRED 43: & n @ t e I t
# PRED SCORE: -0.9743
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 44: ['<V;PST>', 'S', '&', 'd', '@', 'U']
# PRED 44: V l d @ U
# PRED SCORE: -2.0216
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 45: ['<V;PST>', 'E', 'k', 's', 'I', 'l', '@', 'r', 'e', 'I', 't']
# PRED 45: E k s I l @ r e I t
# PRED SCORE: -1.2641
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 46: ['<V;PST>', 'f', 'O', ':', 'S', '&', 'd', '@', 'U']
# PRED 46: a r e g
# PRED SCORE: -1.4747
#
# [2022-03-22 12:34:02,879 INFO]
# SENT 47: ['<V;PST>', 's', 'I', 'N', 'k']
# PRED 47: E I N k
# PRED SCORE: -2.8628
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 48: ['<V;PST>', 'r', 'i', ':', 't', 'S', 'A', ':', 'd', 'Z']
# PRED 48: r r e g
# PRED SCORE: -0.0036
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 49: ['<V;PST>', 'k', '@', 'n', 'd', 'E', 'm']
# PRED 49: k @ n d E s
# PRED SCORE: -2.2172
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 50: ['<V;PST>', 'd', 'I', 't', 'E', 's', 't']
# PRED 50: d I t E s t
# PRED SCORE: -0.5380
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 51: ['<V;PST>', 'k', '&', 'p']
# PRED 51: k I p
# PRED SCORE: -1.7413
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 52: ['<V;PST>', 'd', 'Z', 'O', 'I', 'n']
# PRED 52: d I v I n
# PRED SCORE: -2.3071
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 53: ['<V;PST>', 'E', 'k', 's', 'p', 'E', 'r', 'I', 'm', '@', 'n', 't']
# PRED 53: E k k E p E r I n t
# PRED SCORE: -3.5698
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 54: ['<V;PST>', 'p', 'E', 's', 't', '@', 'r', '*']
# PRED 54: r r e g
# PRED SCORE: -0.2313
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 55: ['<V;PST>', 's', 't', '&', 'b']
# PRED 55: E t & z
# PRED SCORE: -2.1859
#
# [2022-03-22 12:34:02,880 INFO]
# SENT 56: ['<V;PST>', 't', 'S', 'i', ':', 'k']
# PRED 56: t O i : k
# PRED SCORE: -2.0438
#
# [2022-03-22 12:34:02,881 INFO]
# SENT 57: ['<V;PST>', 'v', 'E', 'n', 'd']
# PRED 57: O E n d
# PRED SCORE: -0.9954
#
# [2022-03-22 12:34:02,881 INFO]
# SENT 58: ['<V;PST>', 's', '&', 'N', 'S', 'n', ',']
# PRED 58: s & N S n ,
# PRED SCORE: -3.0342
#
# [2022-03-22 12:34:02,881 INFO]
# SENT 59: ['<V;PST>', 's', 'p', 'O', ':', 'n']
# PRED 59: s r O : n
# PRED SCORE: -1.8120
#
# [2022-03-22 12:34:02,881 INFO]
# SENT 60: ['<V;PST>', 'g', 'r', 'V', 'd', 'Z']
# PRED 60: e e g
# PRED SCORE: -1.4463
#
# [2022-03-22 12:34:02,929 INFO]
# SENT 61: ['<V;PST>', 't', 'r', 'V', 'n', 'd', 'l', ',']
# PRED 61: t r V n d l ,
# PRED SCORE: -0.8173
#
# [2022-03-22 12:34:02,929 INFO]
# SENT 62: ['<V;PST>', 'l', 'u', ':', 't']
# PRED 62: l u : t
# PRED SCORE: -1.3934
#
# [2022-03-22 12:34:02,929 INFO]
# SENT 63: ['<V;PST>', 'd', 'a', 'I', 'n']
# PRED 63: I f I n
# PRED SCORE: -1.3816
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 64: ['<V;PST>', 's', 'k', 'V', 'l', 'p', 't']
# PRED 64: E k V l p t
# PRED SCORE: -1.9068
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 65: ['<V;PST>', 'g', 'r', '&', 't', 'I', 'f', 'a', 'I']
# PRED 65: e r e g
# PRED SCORE: -1.1106
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 66: ['<V;PST>', 'f', 'I', 'g', '@', 'r', '*']
# PRED 66: a e g r *
# PRED SCORE: -1.8826
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 67: ['<V;PST>', 'I', 'N', 'k', 'w', 'a', 'I', '@', 'r', '*']
# PRED 67: e I k w a I @ r *
# PRED SCORE: -3.2181
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 68: ['<V;PST>', 'p', 'r', 'i', ':', 'n']
# PRED 68: r r e g
# PRED SCORE: -0.0909
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 69: ['<V;PST>', 'm', '@', 'n', 'I', 'p', 'j', '@', 'l', 'e', 'I', 't']
# PRED 69: V @ n I p a U l e I t
# PRED SCORE: -4.5128
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 70: ['<V;PST>', 'r', 'E', 'm', 'I', 'd', 'I']
# PRED 70: r r e g
# PRED SCORE: -0.0519
#
# [2022-03-22 12:34:02,930 INFO]
# SENT 71: ['<V;PST>', 'f', 'l', 'I', 'p']
# PRED 71: a e g
# PRED SCORE: -0.6790
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 72: ['<V;PST>', 'k', 'w', 'E', 's', 't']
# PRED 72: k w E s t
# PRED SCORE: -1.3730
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 73: ['<V;PST>', 'd', 'E', 'd', 'I', 'k', 'e', 'I', 't']
# PRED 73: d E d I k e I t
# PRED SCORE: -0.9136
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 74: ['<V;PST>', 'b', '@', 'g', 'r', 'V', 'd', 'Z']
# PRED 74: b r e g d Z
# PRED SCORE: -2.0832
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 75: ['<V;PST>', 'e', 'I', 'd']
# PRED 75: e g
# PRED SCORE: -0.0264
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 76: ['<V;PST>', 's', '@', 'l', 'I', 's', 'I', 't']
# PRED 76: E @ l I s I t
# PRED SCORE: -1.3203
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 77: ['<V;PST>', 'k', '&', 't', 'S']
# PRED 77: k & t S
# PRED SCORE: -0.9125
#
# [2022-03-22 12:34:02,931 INFO]
# SENT 78: ['<V;PST>', 's', 'I', 'l', 'U', 'E', 't']
# PRED 78: E I l U E t
# PRED SCORE: -3.3121
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 79: ['<V;PST>', 'l', 'e', 'I', 'd', 'l', ',']
# PRED 79: l e I l l ,
# PRED SCORE: -1.4152
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 80: ['<V;PST>', 'I', 'n', 'f', 'I', 'l', 't', 'r', 'e', 'I', 't']
# PRED 80: e I n I l r e I t
# PRED SCORE: -2.8688
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 81: ['<V;PST>', 'd', 'r', 'A', ':', 'f', 't']
# PRED 81: d r a a I t
# PRED SCORE: -2.3902
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 82: ['<V;PST>', 'k', 'O', ':', 'd']
# PRED 82: k O : d
# PRED SCORE: -0.9527
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 83: ['<V;PST>', 's', 'k', 'r', '&', 'm', 'b', 'l', ',']
# PRED 83: E k r & m m l ,
# PRED SCORE: -2.5074
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 84: ['<V;PST>', 'E', 'n', 'k', '&', 'm', 'p']
# PRED 84: E n k & m p
# PRED SCORE: -1.7474
#
# [2022-03-22 12:34:02,932 INFO]
# SENT 85: ['<V;PST>', '@', 'p', 'r', 'E', 's']
# PRED 85: r r e g
# PRED SCORE: -0.8551
#
# [2022-03-22 12:34:02,933 INFO]
# SENT 86: ['<V;PST>', 'r', 'I', 'p', 'e', 'I', 'n', 't']
# PRED 86: r r e g
# PRED SCORE: -0.0394
#
# [2022-03-22 12:34:02,933 INFO]
# SENT 87: ['<V;PST>', 'w', 'i', ':', 'l', 'd']
# PRED 87: b i : l d
# PRED SCORE: -1.7134
#
# [2022-03-22 12:34:02,933 INFO]
# SENT 88: ['<V;PST>', 'd', 'I', 'p', 'r', 'e', 'I', 'v']
# PRED 88: d I p r e I v
# PRED SCORE: -1.2434
#
# [2022-03-22 12:34:02,933 INFO]
# SENT 89: ['<V;PST>', 'd', 'u', ':', 'd', 'l', ',']
# PRED 89: d u : d l ,
# PRED SCORE: -2.0931
#
# [2022-03-22 12:34:02,933 INFO]
# SENT 90: ['<V;PST>', '@', 'U', 'v', '@', 'p', 'e', 'I']
# PRED 90: r r e g
# PRED SCORE: -0.9201
#
# [2022-03-22 12:34:02,980 INFO]
# SENT 91: ['<V;PST>', 'a', 'U', 't', 'w', 'I', 't']
# PRED 91: r e g
# PRED SCORE: -0.7710
#
# [2022-03-22 12:34:02,980 INFO]
# SENT 92: ['<V;PST>', 'm', 'V', 'k']
# PRED 92: V m
# PRED SCORE: -0.8410
#
# [2022-03-22 12:34:02,980 INFO]
# SENT 93: ['<V;PST>', 's', 'w', 'i', ':', 't', 'n', ',']
# PRED 93: E b i : t n ,
# PRED SCORE: -2.2713
#
# [2022-03-22 12:34:02,980 INFO]
# SENT 94: ['<V;PST>', 'E', 'n', 't', 'r', '&', 'p']
# PRED 94: E n t r & s
# PRED SCORE: -1.1326
#
# [2022-03-22 12:34:02,980 INFO]
# SENT 95: ['<V;PST>', 'r', 'E', 'k', 'l', ',', 'E', 'k', 't']
# PRED 95: r r e g
# PRED SCORE: -0.0057
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 96: ['<V;PST>', 'E', 'k', 's', 'p', 'E', 'n', 'd']
# PRED 96: E k s p E n d
# PRED SCORE: -1.2629
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 97: ['<V;PST>', 'b', '@', 'g', 'E', 't']
# PRED 97: b r e I t
# PRED SCORE: -1.2812
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 98: ['<V;PST>', 'k', '@', 'd', 'Z', '@', 'U', 'l']
# PRED 98: k @ d Z @ U l
# PRED SCORE: -1.4967
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 99: ['<V;PST>', 's', 'k', '&', 'v', 'n', ',', 'd', 'Z']
# PRED 99: E k & v n n l Z
# PRED SCORE: -4.9673
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 100: ['<V;PST>', 'i', ':', 'z']
# PRED 100: i : p
# PRED SCORE: -2.1280
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 101: ['<V;PST>', 'n', '@', 'U']
# PRED 101: @ @ U
# PRED SCORE: -1.7159
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 102: ['<V;PST>', 'b', '&', 'k', 'f', 'a', 'I', '@', 'r', '*']
# PRED 102: b & k f a I @ r *
# PRED SCORE: -2.0808
#
# [2022-03-22 12:34:02,981 INFO]
# SENT 103: ['<V;PST>', 'k', '@', 'r', 'i', ':', 'n']
# PRED 103: k @ r i : n
# PRED SCORE: -0.7286
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 104: ['<V;PST>', 'g', '3', ':', 'd', 'l', ',']
# PRED 104: r e g
# PRED SCORE: -0.4116
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 105: ['<V;PST>', 'k', 'l', '&', 'r', 'I', 'f', 'a', 'I']
# PRED 105: k l & r I f a I
# PRED SCORE: -1.2279
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 106: ['<V;PST>', 'r', '&', 'p']
# PRED 106: r e g
# PRED SCORE: -0.0089
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 107: ['<V;PST>', 'd', 'Z', 'E', 's', 't', 'I', 'k', 'j', 'U', 'l', 'e', 'I', 't']
# PRED 107: I m E s s t & v e I t
# PRED SCORE: -5.4436
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 108: ['<V;PST>', 'k', '@', 'n', 'v', 'i', ':', 'n']
# PRED 108: k @ n v i : n
# PRED SCORE: -2.0014
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 109: ['<V;PST>', 'r', '@', 'l', 'i', ':', 's']
# PRED 109: r r e g
# PRED SCORE: -0.0070
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 110: ['<V;PST>', 'f', 'O', ':', 's', 'f', 'i', ':', 'd']
# PRED 110: a r e g
# PRED SCORE: -0.8663
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 111: ['<V;PST>', 't', 'S', 'E', '@', 'r', '*']
# PRED 111: t & s @ r *
# PRED SCORE: -2.1228
#
# [2022-03-22 12:34:02,982 INFO]
# SENT 112: ['<V;PST>', 'd', 'I', 'f', 'r', 'O', ':', 'd']
# PRED 112: d I f r O : d
# PRED SCORE: -1.2101
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 113: ['<V;PST>', '&', 'd', 'Z', 'I', 't', 'e', 'I', 't']
# PRED 113: & d Z I t e I t
# PRED SCORE: -1.1138
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 114: ['<V;PST>', 'k', '@', 'n', 's', 'I', 'd', '@', 'r', '*']
# PRED 114: k @ n n & d @ r *
# PRED SCORE: -2.5948
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 115: ['<V;PST>', 'd', 'i', ':', 'k', '&', 'p', 'I', 't', 'e', 'I', 't']
# PRED 115: I i : k l a I t
# PRED SCORE: -3.7094
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 116: ['<V;PST>', 's', 'n', 'I', '@', 'r', '*']
# PRED 116: E n I @ r *
# PRED SCORE: -1.1232
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 117: ['<V;PST>', 'g', '@', 'f', 'O', ':']
# PRED 117: r e g
# PRED SCORE: -1.0095
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 118: ['<V;PST>', 'b', 'V', 'm', 'p']
# PRED 118: b V m
# PRED SCORE: -1.8456
#
# [2022-03-22 12:34:02,983 INFO]
# SENT 119: ['<V;PST>', 't', 'r', 'A', ':', 'n', 's', 'm', 'j', 'u', ':', 't']
# PRED 119: r r e g
# PRED SCORE: -3.1156
#
# [2022-03-22 12:34:02,984 INFO]
# SENT 120: ['<V;PST>', 'p', 'V', 't']
# PRED 120: r e g
# PRED SCORE: -0.2409
#
# [2022-03-22 12:34:03,033 INFO]
# SENT 121: ['<V;PST>', 'O', ':', 'T', 'E', 'n', 't', 'I', 'k', 'e', 'I', 't']
# PRED 121: i i : v E n t I k e I t
# PRED SCORE: -4.7191
#
# [2022-03-22 12:34:03,033 INFO]
# SENT 122: ['<V;PST>', 'V', 'n', 'n', '3', ':', 'v']
# PRED 122: V n n 3 : v
# PRED SCORE: -1.1873
#
# [2022-03-22 12:34:03,033 INFO]
# SENT 123: ['<V;PST>', 'd', 'I', 's', 'E', 'k', 't']
# PRED 123: d I s E k t
# PRED SCORE: -0.6179
#
# [2022-03-22 12:34:03,033 INFO]
# SENT 124: ['<V;PST>', 's', 'l', 'O', 't']
# PRED 124: E l O t
# PRED SCORE: -1.7009
#
# [2022-03-22 12:34:03,033 INFO]
# SENT 125: ['<V;PST>', 'b', 'V', 'g', '@', 'r', '*']
# PRED 125: b V g @ r *
# PRED SCORE: -1.0893
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 126: ['<V;PST>', 'd', 'I', 's', '@', 'U', 'n']
# PRED 126: d I s @ U n
# PRED SCORE: -0.7163
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 127: ['<V;PST>', 'b', 'O', ':', 'l']
# PRED 127: b i : l
# PRED SCORE: -1.7517
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 128: ['<V;PST>', 's', 'm', '@', 'U', 'l', 'd', '@', 'r', '*']
# PRED 128: E m @ U l d @ r *
# PRED SCORE: -1.6741
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 129: ['<V;PST>', 'V', 'n', 's', 'i', ':', 't']
# PRED 129: V n s i : t
# PRED SCORE: -0.6414
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 130: ['<V;PST>', 'b', 'l', 'E', '@', 'r', '*']
# PRED 130: b l E @ r *
# PRED SCORE: -2.0257
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 131: ['<V;PST>', 'b', 'r', 'E', 'k', 'f', '@', 's', 't']
# PRED 131: r r e g
# PRED SCORE: -1.9309
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 132: ['<V;PST>', 'd', 'I', 'p', 'r', 'E', 's']
# PRED 132: d I p r E s
# PRED SCORE: -0.8018
#
# [2022-03-22 12:34:03,034 INFO]
# SENT 133: ['<V;PST>', 't', 'I', 'p', 't', '@', 'U']
# PRED 133: t I p t @ U
# PRED SCORE: -0.9607
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 134: ['<V;PST>', 'I', 'm', 'p', 'r', 'E', 'g', 'n', 'e', 'I', 't']
# PRED 134: I m p r E s t
# PRED SCORE: -3.3935
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 135: ['<V;PST>', 'I', 'n', 'O', 'k', 'j', 'U', 'l', 'e', 'I', 't']
# PRED 135: I n v O k j U d e I t
# PRED SCORE: -4.2249
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 136: ['<V;PST>', 'S', 'O', 'k']
# PRED 136: V k
# PRED SCORE: -1.4433
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 137: ['<V;PST>', 'S', 'V', 't', 'l', ',']
# PRED 137: V m t l ,
# PRED SCORE: -1.5327
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 138: ['<V;PST>', 'w', 'O', 'n', 'd', '@', 'r', '*']
# PRED 138: w O n d @ r *
# PRED SCORE: -1.5038
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 139: ['<V;PST>', 'E', 'g', 'z', 'E', 'm', 't']
# PRED 139: E g z E m t
# PRED SCORE: -1.4320
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 140: ['<V;PST>', 'I', 'n', 's', '3', ':', 't']
# PRED 140: I n s 3 : t
# PRED SCORE: -1.1899
#
# [2022-03-22 12:34:03,035 INFO]
# SENT 141: ['<V;PST>', 'k', '@', 'n', 's', 't', 'r', 'I', 'k', 't']
# PRED 141: k @ n n E t r I t
# PRED SCORE: -2.3891
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 142: ['<V;PST>', 'a', 'U', 't', 'f', 'l', '&', 'N', 'k']
# PRED 142: a r e g
# PRED SCORE: -1.9258
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 143: ['<V;PST>', 'p', 'E', 't']
# PRED 143: r e g
# PRED SCORE: -0.1628
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 144: ['<V;PST>', 'm', 'E', 'n', 'S', 'n', ',']
# PRED 144: V E n S n ,
# PRED SCORE: -1.9818
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 145: ['<V;PST>', '@', 'U', 'v', '@', 'E', 'k', 's', 'p', '@', 'U', 'z']
# PRED 145: r r e g
# PRED SCORE: -0.6521
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 146: ['<V;PST>', 't', 'S', 'e', 'I', 'n', 's', 'm', '@', 'U', 'k']
# PRED 146: t t e I n s v @ U k
# PRED SCORE: -4.4312
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 147: ['<V;PST>', 'I', 'n', 'Z', '@', 'r', '*']
# PRED 147: I n Z @ r *
# PRED SCORE: -1.0280
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 148: ['<V;PST>', 'E', 'n', 'k', 'V', 'r', 'I', 'd', 'Z']
# PRED 148: E n k S r I d Z
# PRED SCORE: -3.3326
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 149: ['<V;PST>', '3', ':', 'k']
# PRED 149: u : k
# PRED SCORE: -1.1817
#
# [2022-03-22 12:34:03,036 INFO]
# SENT 150: ['<V;PST>', 's', 'i', ':', 'd']
# PRED 150: s i : d
# PRED SCORE: -2.0243
#
# [2022-03-22 12:34:03,080 INFO]
# SENT 151: ['<V;PST>', 'd', 'I', 's', 'i', ':', 'v']
# PRED 151: d I s i : v
# PRED SCORE: -0.9996
#
# [2022-03-22 12:34:03,080 INFO]
# SENT 152: ['<V;PST>', 'p', '@', 'f', 'O', ':', 'm']
# PRED 152: r r e g
# PRED SCORE: -0.1050
#
# [2022-03-22 12:34:03,080 INFO]
# SENT 153: ['<V;PST>', 'm', '@', 'U', 't', '@', 'r', '*']
# PRED 153: V @ U t @ r *
# PRED SCORE: -1.6882
#
# [2022-03-22 12:34:03,081 INFO]
# SENT 154: ['<V;PST>', 's', '@', 'd', 'Z', 'E', 's', 't']
# PRED 154: E @ d Z E s t
# PRED SCORE: -1.7178
#
# [2022-03-22 12:34:03,081 INFO]
# SENT 155: ['<V;PST>', '@', 'U', 'v', '@', 'f', 'l', '@', 'U']
# PRED 155: r r e g
# PRED SCORE: -0.8591
#
# [2022-03-22 12:34:03,081 INFO]
# SENT 156: ['<V;PST>', 'r', '@', 't', 'A', ':', 'd']
# PRED 156: r r e g
# PRED SCORE: -0.0068
#
# [2022-03-22 12:34:03,081 INFO]
# SENT 157: ['<V;PST>', 'r', 'E', 'p', 'l', 'I', 'k', 'e', 'I', 't']
# PRED 157: r r e g
# PRED SCORE: -0.0074
#
# [2022-03-22 12:34:03,082 INFO]
# SENT 158: ['<V;PST>', 't', 'e', 'I', 'l', '@', 'r', '*']
# PRED 158: t e I l @ r *
# PRED SCORE: -0.5317
#
# [2022-03-22 12:34:03,082 INFO]
# SENT 159: ['<V;PST>', '@', 't', '&', 't', 'S']
# PRED 159: @ t & t S
# PRED SCORE: -1.1177
#
# [2022-03-22 12:34:03,082 INFO]
# SENT 160: ['<V;PST>', '@', 'p', 'O', ':', 'S', 'n', ',']
# PRED 160: r r e g
# PRED SCORE: -1.6595
#
# [2022-03-22 12:34:03,083 INFO]
# SENT 161: ['<V;PST>', 'f', 'r', 'I', 's', 'k']
# PRED 161: a r e
# PRED SCORE: -0.7812
#
# [2022-03-22 12:34:03,083 INFO]
# SENT 162: ['<V;PST>', 't', 'j', 'u', ':', 't', '@', 'r', '*']
# PRED 162: r e g t @ r *
# PRED SCORE: -1.7742
#
# [2022-03-22 12:34:03,083 INFO]
# SENT 163: ['<V;PST>', 'n', '@', 'U', 't']
# PRED 163: @ @ U t
# PRED SCORE: -0.7175
#
# [2022-03-22 12:34:03,083 INFO]
# SENT 164: ['<V;PST>', '@', 'd', 'Z', '3', ':', 'n']
# PRED 164: r e g v
# PRED SCORE: -1.4439
#
# [2022-03-22 12:34:03,083 INFO]
# SENT 165: ['<V;PST>', 'S', '&', 'k', 'l', ',']
# PRED 165: V m k l ,
# PRED SCORE: -1.7449
#
# [2022-03-22 12:34:03,083 INFO]
# SENT 166: ['<V;PST>', 'd', 'I', 's', 'O', 'r', 'I', 'E', 'n', 't', 'e', 'I', 't']
# PRED 166: d I s O r I n e I t
# PRED SCORE: -2.6885
#
# [2022-03-22 12:34:03,084 INFO]
# SENT 167: ['<V;PST>', 't', 'i', ':']
# PRED 167: t @ :
# PRED SCORE: -1.5717
#
# [2022-03-22 12:34:03,084 INFO]
# SENT 168: ['<V;PST>', 'd', 'I', 's', 'r', 'V', 'p', 't']
# PRED 168: d I s r V p t
# PRED SCORE: -1.1892
#
# [2022-03-22 12:34:03,084 INFO]
# SENT 169: ['<V;PST>', 'p', 'I', 't', 'I']
# PRED 169: r e g
# PRED SCORE: -0.1170
#
# [2022-03-22 12:34:03,084 INFO]
# SENT 170: ['<V;PST>', 'p', '3', ':', 's', 'O', 'n', 'I', 'f', 'a', 'I']
# PRED 170: r r e g
# PRED SCORE: -0.0733
#
# [2022-03-22 12:34:03,084 INFO]
# SENT 171: ['<V;PST>', 'l', 'O', 'g']
# PRED 171: l I l
# PRED SCORE: -1.5050
#
# [2022-03-22 12:34:03,085 INFO]
# SENT 172: ['<V;PST>', '@', 'b', 'z', 'O', 'l', 'v']
# PRED 172: r r e g
# PRED SCORE: -0.4631
#
# [2022-03-22 12:34:03,085 INFO]
# SENT 173: ['<V;PST>', 'm', 'V', 'd', 'I']
# PRED 173: V m d I
# PRED SCORE: -1.1832
#
# [2022-03-22 12:34:03,085 INFO]
# SENT 174: ['<V;PST>', 'E', 'n', 'f', 'O', ':', 's']
# PRED 174: E n f O : s
# PRED SCORE: -1.6938
#
# [2022-03-22 12:34:03,085 INFO]
# SENT 175: ['<V;PST>', '@', 'n', 'V', 'l']
# PRED 175: @ n V l
# PRED SCORE: -1.4365
#
# [2022-03-22 12:34:03,085 INFO]
# SENT 176: ['<V;PST>', 'p', 'r', 'O', 'f', 'I', 't']
# PRED 176: r r e g
# PRED SCORE: -0.1103
#
# [2022-03-22 12:34:03,086 INFO]
# SENT 177: ['<V;PST>', 'V', 'n', 's', 'k', 'r', 'u', ':']
# PRED 177: V n s k r *
# PRED SCORE: -1.9175
#
# [2022-03-22 12:34:03,086 INFO]
# SENT 178: ['<V;PST>', 'd', 'I', 's', 'l', 'a', 'I', 'k']
# PRED 178: d I s l a I k
# PRED SCORE: -0.6877
#
# [2022-03-22 12:34:03,086 INFO]
# SENT 179: ['<V;PST>', 'h', 'I', 'n', 'Z']
# PRED 179: V I n
# PRED SCORE: -1.4448
#
# [2022-03-22 12:34:03,086 INFO]
# SENT 180: ['<V;PST>', 'z', 'I', 'g', 'z', '&', 'g']
# PRED 180: r e g
# PRED SCORE: -0.9406
#
# [2022-03-22 12:34:03,132 INFO]
# SENT 181: ['<V;PST>', 'd', 'Z', 'O', 'g', 'l', ',']
# PRED 181: d Z O g l ,
# PRED SCORE: -2.0823
#
# [2022-03-22 12:34:03,132 INFO]
# SENT 182: ['<V;PST>', 'h', 'I', 'p', 'n', '@', 't', 'a', 'I', 'z']
# PRED 182: V I p n @ t a I z
# PRED SCORE: -2.1416
#
# [2022-03-22 12:34:03,132 INFO]
# SENT 183: ['<V;PST>', 'f', 'r', 'V', 's', 't', 'r', 'e', 'I', 't']
# PRED 183: a r e g
# PRED SCORE: -0.4073
#
# [2022-03-22 12:34:03,132 INFO]
# SENT 184: ['<V;PST>', 'k', '@', 'n', 't', 'r', 'a', 'I', 'v']
# PRED 184: k @ n t r a I v
# PRED SCORE: -2.5349
#
# [2022-03-22 12:34:03,132 INFO]
# SENT 185: ['<V;PST>', 'b', 'A', ':', 'r', '*']
# PRED 185: b A : r *
# PRED SCORE: -2.4737
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 186: ['<V;PST>', 'm', 'I', 's', 'I', 'n', 't', '3', ':', 'p', 'r', 'I', 't']
# PRED 186: V I s I n t 3 : r I t
# PRED SCORE: -2.9934
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 187: ['<V;PST>', 'm', 'V', 'l', 't', 'I', 'p', 'l', 'a', 'I']
# PRED 187: m V l t I p Z
# PRED SCORE: -3.2550
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 188: ['<V;PST>', 'i', ':', 't']
# PRED 188: i : t
# PRED SCORE: -0.7276
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 189: ['<V;PST>', 'k', 'r', 'i', ':', 'p']
# PRED 189: k r i : p
# PRED SCORE: -2.0684
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 190: ['<V;PST>', 'p', 'i', ':', 'p', 'l', ',']
# PRED 190: r r e g
# PRED SCORE: -0.1259
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 191: ['<V;PST>', 'k', 'l', 'V', 'k']
# PRED 191: k l V k
# PRED SCORE: -1.1752
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 192: ['<V;PST>', 'l', 'O', 'b']
# PRED 192: l I l
# PRED SCORE: -1.6211
#
# [2022-03-22 12:34:03,133 INFO]
# SENT 193: ['<V;PST>', 's', 'l', 'a', 'I', 'd']
# PRED 193: E l a I d
# PRED SCORE: -1.3715
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 194: ['<V;PST>', 's', 'k', 'I', 'm', 'p']
# PRED 194: E k I m p
# PRED SCORE: -1.4071
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 195: ['<V;PST>', 'r', 'i', ':', 'l', '@', 'U', 'k', 'e', 'I', 't']
# PRED 195: r r e g
# PRED SCORE: -0.0072
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 196: ['<V;PST>', 'm', '&', 'r', 'I']
# PRED 196: V d r I
# PRED SCORE: -1.2203
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 197: ['<V;PST>', 'k', '@', 'm', 'p', 'i', ':', 't']
# PRED 197: k @ m p i : t
# PRED SCORE: -1.2895
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 198: ['<V;PST>', 'k', '&', 'n', 't', '@', 'r', '*']
# PRED 198: k & n t @ r *
# PRED SCORE: -0.6207
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 199: ['<V;PST>', 'h', 'O', 'I', 's', 't']
# PRED 199: V v I s t
# PRED SCORE: -1.7448
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 200: ['<V;PST>', 'h', 'j', 'u', ':']
# PRED 200: h a g
# PRED SCORE: -3.5319
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 201: ['<V;PST>', 'I', 'r', '&', 'd', 'I', 'k', 'e', 'I', 't']
# PRED 201: I r & d I k e I t
# PRED SCORE: -1.8121
#
# [2022-03-22 12:34:03,134 INFO]
# SENT 202: ['<V;PST>', 'r', 'V', 'f']
# PRED 202: r e g
# PRED SCORE: -0.0157
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 203: ['<V;PST>', 'h', '&', 'n', 'd', 'I', 'k', '&', 'p']
# PRED 203: V & n d I k
# PRED SCORE: -2.7132
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 204: ['<V;PST>', 'm', '@', 'r', 'O', ':', 'd']
# PRED 204: V @ r O : d
# PRED SCORE: -1.6569
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 205: ['<V;PST>', 's', 'k', 'O', 't', 'S']
# PRED 205: E k O t S
# PRED SCORE: -1.8198
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 206: ['<V;PST>', 's', '&', 'b', '@', 't', 'A', ':', 'd', 'Z']
# PRED 206: s & b @ t A : d
# PRED SCORE: -4.8267
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 207: ['<V;PST>', 's', 't', 'E', '@', 'r', '*']
# PRED 207: E t E @ r *
# PRED SCORE: -1.2133
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 208: ['<V;PST>', 's', 'I', 'z', 'l', ',']
# PRED 208: E I z l ,
# PRED SCORE: -1.9215
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 209: ['<V;PST>', 's', 'w', 'O', 'b']
# PRED 209: s w O z
# PRED SCORE: -3.6100
#
# [2022-03-22 12:34:03,135 INFO]
# SENT 210: ['<V;PST>', 'I', 'n', 'v', 'O', 'l', 'v']
# PRED 210: I n v O v S
# PRED SCORE: -3.3914
#
# [2022-03-22 12:34:03,180 INFO]
# SENT 211: ['<V;PST>', 'r', '@', 'p', 'E', 'l']
# PRED 211: r r e g
# PRED SCORE: -0.0332
#
# [2022-03-22 12:34:03,180 INFO]
# SENT 212: ['<V;PST>', 'r', 'V', 'b']
# PRED 212: r e g
# PRED SCORE: -0.0127
#
# [2022-03-22 12:34:03,180 INFO]
# SENT 213: ['<V;PST>', 'E', 'n', 'd', 'Z', 'E', 'n', 'd', '@', 'r', '*']
# PRED 213: E n n d & n d @ r *
# PRED SCORE: -3.2782
#
# [2022-03-22 12:34:03,180 INFO]
# SENT 214: ['<V;PST>', '@', 'l', 'E', 'd', 'Z']
# PRED 214: r r e g
# PRED SCORE: -1.5506
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 215: ['<V;PST>', '@', 'U', 'v', '@', 'I', 'n', 'd', 'V', 'l', 'd', 'Z']
# PRED 215: r r e g
# PRED SCORE: -1.0165
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 216: ['<V;PST>', 'k', '@', 'l', 'E', 'k', 't', 'I', 'v', 'a', 'I', 'z']
# PRED 216: k @ n l E k t
# PRED SCORE: -3.3156
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 217: ['<V;PST>', 'm', 'V', 'n', 'S']
# PRED 217: V m n S
# PRED SCORE: -2.4299
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 218: ['<V;PST>', 'j', '&', 'N', 'k']
# PRED 218: w e I
# PRED SCORE: -2.5133
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 219: ['<V;PST>', '&', 't', 'r', 'U', 'f', 'I']
# PRED 219: & t r U f I
# PRED SCORE: -0.8767
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 220: ['<V;PST>', 's', 'm', '3', ':', 'k']
# PRED 220: E m 3 : k
# PRED SCORE: -1.8424
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 221: ['<V;PST>', 'V', 'n', 'p', '&', 'k']
# PRED 221: V n p & k
# PRED SCORE: -0.7555
#
# [2022-03-22 12:34:03,181 INFO]
# SENT 222: ['<V;PST>', 's', 'p', 'r', 'e', 'I']
# PRED 222: E p r e I
# PRED SCORE: -1.1025
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 223: ['<V;PST>', 'f', '3', ':', 'm', 'E', 'n', 't']
# PRED 223: r e e g
# PRED SCORE: -2.5983
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 224: ['<V;PST>', 'd', 'I', 'v', '3', ':', 'd', 'Z']
# PRED 224: d I v 3 : d Z
# PRED SCORE: -1.8225
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 225: ['<V;PST>', 'O', 'b', 'l', 'I', 'g', 'e', 'I', 't']
# PRED 225: O b l I g e I t
# PRED SCORE: -1.9990
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 226: ['<V;PST>', 'b', 'O', ':', 'l', 'k']
# PRED 226: b O : l k
# PRED SCORE: -1.5970
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 227: ['<V;PST>', 's', 'a', 'I', 'k', 'l', ',']
# PRED 227: s a I k l ,
# PRED SCORE: -1.8189
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 228: ['<V;PST>', 'I', 'n', 't', '3', ':', 'r', '*']
# PRED 228: I n t 3 : r *
# PRED SCORE: -1.0751
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 229: ['<V;PST>', 'b', 'r', 'e', 'I', 's']
# PRED 229: b r e g
# PRED SCORE: -1.4408
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 230: ['<V;PST>', 'p', '3', ':', 't', 'S', '@', 's']
# PRED 230: r r e g
# PRED SCORE: -0.1008
#
# [2022-03-22 12:34:03,182 INFO]
# SENT 231: ['<V;PST>', 'd', 'I', 'z', '3', ':', 'n']
# PRED 231: d I z 3 : n
# PRED SCORE: -1.6221
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 232: ['<V;PST>', 'r', 'i', ':', 'v', 'a', 'I', 't', 'l', ',', 'a', 'I', 'z']
# PRED 232: r r e g
# PRED SCORE: -0.0044
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 233: ['<V;PST>', 'k', '@', 'm', '3', ':', 'S', 'l', ',', 'a', 'I', 'z']
# PRED 233: k @ m Z 3 : l a I z
# PRED SCORE: -3.6237
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 234: ['<V;PST>', 'e', 'I', 'l', 'I', '@', 'n', 'e', 'I', 't']
# PRED 234: e e I d @ n e I t
# PRED SCORE: -1.2394
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 235: ['<V;PST>', 'd', 'E', 'k', '@', 'r', 'e', 'I', 't']
# PRED 235: d E k @ r e I t
# PRED SCORE: -1.1955
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 236: ['<V;PST>', 'd', 'I', 'k', 'e', 'I']
# PRED 236: d I k e I
# PRED SCORE: -0.5853
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 237: ['<V;PST>', 's', 'k', '&', 'm', 'p', '@', 'r', '*']
# PRED 237: E k & m p @ r *
# PRED SCORE: -2.5290
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 238: ['<V;PST>', 'E', 'n', 'd', 'j', 'O', ':', 'r', '*']
# PRED 238: E n d w 3 : r *
# PRED SCORE: -3.5567
#
# [2022-03-22 12:34:03,183 INFO]
# SENT 239: ['<V;PST>', 'h', 'I', 'n', 'd', '@', 'r', '*']
# PRED 239: V I n d @ r *
# PRED SCORE: -0.8473
#
# [2022-03-22 12:34:03,184 INFO]
# SENT 240: ['<V;PST>', '@', 'U', 'v', '@', 't', 'e', 'I', 'k']
# PRED 240: r r e g
# PRED SCORE: -0.7463
#
# [2022-03-22 12:34:03,226 INFO]
# SENT 241: ['<V;PST>', 'r', 'I', 'b', 'V', 'f']
# PRED 241: r e g
# PRED SCORE: -0.2914
#
# [2022-03-22 12:34:03,226 INFO]
# SENT 242: ['<V;PST>', 's', 'V', 'l', 'I']
# PRED 242: E m l I
# PRED SCORE: -2.0063
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 243: ['<V;PST>', 't', 'r', 'O', 't']
# PRED 243: t r O t
# PRED SCORE: -0.8747
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 244: ['<V;PST>', 'V', 'p', 'E', 'n', 'd']
# PRED 244: V p E n d
# PRED SCORE: -0.4500
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 245: ['<V;PST>', 'E', 'g', 'z', 'E', 'm', 'p', 'l', 'I', 'f', 'a', 'I']
# PRED 245: E g z U s f Z Z
# PRED SCORE: -6.0173
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 246: ['<V;PST>', 'l', 'I', 'm', 'p']
# PRED 246: l e g
# PRED SCORE: -1.0659
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 247: ['<V;PST>', 'g', 'r', '@', 'U']
# PRED 247: e e g
# PRED SCORE: -0.7286
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 248: ['<V;PST>', 'E', 's', 't', 'r', 'e', 'I', 'n', 'Z']
# PRED 248: E s t r e I n
# PRED SCORE: -0.9212
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 249: ['<V;PST>', '@', 'b', 'a', 'U', 'n', 'd']
# PRED 249: r r e g
# PRED SCORE: -0.3933
#
# [2022-03-22 12:34:03,227 INFO]
# SENT 250: ['<V;PST>', 't', 'e', 'I', 'k']
# PRED 250: t e I k
# PRED SCORE: -0.8814
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 251: ['<V;PST>', 'd', 'V', 'm', 'f', 'a', 'U', 'n', 'd']
# PRED 251: d V m f a U n d
# PRED SCORE: -2.7364
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 252: ['<V;PST>', '&', 'k', 's', 'E', 'l', '@', 'r', 'e', 'I', 't']
# PRED 252: & k s E d @ r e I t
# PRED SCORE: -2.7234
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 253: ['<V;PST>', 'k', 'O', 'N', 'k', '@', 'r', '*']
# PRED 253: k O N k @ r *
# PRED SCORE: -2.2790
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 254: ['<V;PST>', 'm', 'O', 'l', 'I', 'f', 'a', 'I']
# PRED 254: V v l I f a I
# PRED SCORE: -2.0844
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 255: ['<V;PST>', 'p', 'a', 'U', '@', 'r', '*']
# PRED 255: r r e g
# PRED SCORE: -0.5314
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 256: ['<V;PST>', 'S', 'I', 'p', 'r', 'E', 'k']
# PRED 256: V I p r E k
# PRED SCORE: -0.9026
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 257: ['<V;PST>', 's', 'V', 'd', 'Z', '@', 'n']
# PRED 257: s V d Z @ n
# PRED SCORE: -2.1560
#
# [2022-03-22 12:34:03,228 INFO]
# SENT 258: ['<V;PST>', 't', 'V', 'n', 'l', ',']
# PRED 258: t V n l ,
# PRED SCORE: -0.8619
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 259: ['<V;PST>', 'f', 'a', 'I', 'n', '&', 'n', 's']
# PRED 259: a r e g
# PRED SCORE: -1.4245
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 260: ['<V;PST>', 'r', 'i', ':', 's', 'E', 't', 'l', ',']
# PRED 260: r r e g
# PRED SCORE: -0.0051
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 261: ['<V;PST>', 'h', 'V', 'f']
# PRED 261: u V f
# PRED SCORE: -2.3026
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 262: ['<V;PST>', 'd', 'I', 'g', 'r', 'e', 'I', 'd']
# PRED 262: d I g r e I d
# PRED SCORE: -0.9926
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 263: ['<V;PST>', 'I', 'n', 'v', '&', 'l', 'I', 'd', 'e', 'I', 't']
# PRED 263: e I v & l I d e I t
# PRED SCORE: -3.1948
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 264: ['<V;PST>', 'p', '3', ':', 'v', 'e', 'I', 'd']
# PRED 264: r r e g
# PRED SCORE: -0.1966
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 265: ['<V;PST>', 't', '&', 'k', 'l', ',']
# PRED 265: t & k l ,
# PRED SCORE: -0.9196
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 266: ['<V;PST>', 'r', '@', 's', 't', 'O', ':', 'r', '*']
# PRED 266: r r e g
# PRED SCORE: -0.0044
#
# [2022-03-22 12:34:03,229 INFO]
# SENT 267: ['<V;PST>', 'p', 'r', 'a', 'I', 'z']
# PRED 267: r r e g
# PRED SCORE: -0.5454
#
# [2022-03-22 12:34:03,230 INFO]
# SENT 268: ['<V;PST>', 'h', 'O', 'N', 'k']
# PRED 268: V v V k
# PRED SCORE: -2.6368
#
# [2022-03-22 12:34:03,230 INFO]
# SENT 269: ['<V;PST>', 'd', '&', 'p', 'l', ',']
# PRED 269: d & p l ,
# PRED SCORE: -1.2579
#
# [2022-03-22 12:34:03,230 INFO]
# SENT 270: ['<V;PST>', 'd', 'I', 's', 'p', 'r', 'u', ':', 'v']
# PRED 270: d I s p r u : v
# PRED SCORE: -2.0793
#
# [2022-03-22 12:34:03,273 INFO]
# SENT 271: ['<V;PST>', 'r', '@', 'z', 'I', 's', 't']
# PRED 271: r r e g
# PRED SCORE: -0.0108
#
# [2022-03-22 12:34:03,273 INFO]
# SENT 272: ['<V;PST>', 'k', '@', 'm', 'A', ':', 'n', 'd']
# PRED 272: k @ m A : n d
# PRED SCORE: -2.6790
#
# [2022-03-22 12:34:03,273 INFO]
# SENT 273: ['<V;PST>', 's', '@', 'U', 'k']
# PRED 273: E @ U k
# PRED SCORE: -1.1478
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 274: ['<V;PST>', 'd', 'r', '&', 't']
# PRED 274: I r & t
# PRED SCORE: -1.1175
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 275: ['<V;PST>', 'k', 'O', 'n', 'v', '@', 'l', 'E', 's']
# PRED 275: k O n n O n d
# PRED SCORE: -3.0982
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 276: ['<V;PST>', 'I', 'l', 'E', 'k', 't', 'r', 'I', 'f', 'a', 'I']
# PRED 276: I l E k t r I f a I
# PRED SCORE: -1.8489
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 277: ['<V;PST>', 'p', 'r', 'I', 'v', '&', 'r', 'I', 'k', 'e', 'I', 't']
# PRED 277: r r e g
# PRED SCORE: -0.1225
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 278: ['<V;PST>', 'b', 'u', ':', 'm']
# PRED 278: r e g
# PRED SCORE: -1.8703
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 279: ['<V;PST>', 'm', 'j', 'u', ':', 't']
# PRED 279: m a u : t
# PRED SCORE: -2.7960
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 280: ['<V;PST>', 'b', 'r', 'I', 'N']
# PRED 280: r e g
# PRED SCORE: -1.4075
#
# [2022-03-22 12:34:03,274 INFO]
# SENT 281: ['<V;PST>', 'I', 'n', 's', 'I', 'n', '@', 'r', 'e', 'I', 't']
# PRED 281: I n s I n @ r e I t
# PRED SCORE: -1.1237
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 282: ['<V;PST>', 'd', 'I', 'k', 'r', 'a', 'I']
# PRED 282: d I k r a I
# PRED SCORE: -0.5358
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 283: ['<V;PST>', 'm', 'E', 'd', 'l', ',']
# PRED 283: V E d l ,
# PRED SCORE: -1.2917
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 284: ['<V;PST>', 's', 'k', 'w', 'i', ':', 'k']
# PRED 284: E k w i : k
# PRED SCORE: -2.7904
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 285: ['<V;PST>', 's', 'm', 'E', 'l', 't']
# PRED 285: E m E l t
# PRED SCORE: -1.5252
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 286: ['<V;PST>', 'm', 'I', 's', 't', 'e', 'I', 'k']
# PRED 286: m I s t e I k
# PRED SCORE: -1.5727
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 287: ['<V;PST>', 'r', 'i', ':', 's', 't', 'e', 'I', 't']
# PRED 287: r r e g
# PRED SCORE: -0.0042
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 288: ['<V;PST>', 'E', 'p', 'I', 't', '@', 'm', 'a', 'I', 'z']
# PRED 288: E p I t @ s a I z
# PRED SCORE: -2.2590
#
# [2022-03-22 12:34:03,275 INFO]
# SENT 289: ['<V;PST>', 'm', 'I', 's', 'l', 'i', ':', 'd']
# PRED 289: V I s l i : d
# PRED SCORE: -1.3504
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 290: ['<V;PST>', 'f', 'O', ':', 'k']
# PRED 290: a a I
# PRED SCORE: -2.2106
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 291: ['<V;PST>', 'V', 'n', 'f', '@', 'U', 'l', 'd']
# PRED 291: V n f @ U l d
# PRED SCORE: -1.0159
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 292: ['<V;PST>', 'g', 'e', 'I', 'd', 'Z']
# PRED 292: e e g
# PRED SCORE: -0.7606
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 293: ['<V;PST>', 'r', '@', 'p', 'r', '@', 'U', 't', 'S']
# PRED 293: r r e g
# PRED SCORE: -0.0039
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 294: ['<V;PST>', 'g', 'I', 'v']
# PRED 294: e g
# PRED SCORE: -0.0262
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 295: ['<V;PST>', 'i', ':', 'v', '&', 'k', 'j', 'U', 'e', 'I', 't']
# PRED 295: i i : v & k a I t
# PRED SCORE: -3.4249
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 296: ['<V;PST>', 'E', 'n', 'r', '@', 'U', 'l']
# PRED 296: E n r @ U l
# PRED SCORE: -1.0242
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 297: ['<V;PST>', 's', 'E', 'g', 'r', 'I', 'g', 'e', 'I', 't']
# PRED 297: E E g r I g e I t
# PRED SCORE: -2.0149
#
# [2022-03-22 12:34:03,276 INFO]
# SENT 298: ['<V;PST>', 'l', 'e', 'I']
# PRED 298: l e g
# PRED SCORE: -0.8684
#
# [2022-03-22 12:34:03,277 INFO]
# SENT 299: ['<V;PST>', 'p', 'V', 'l', 'v', '@', 'r', 'a', 'I', 'z']
# PRED 299: r r e g
# PRED SCORE: -0.0810
#
# [2022-03-22 12:34:03,277 INFO]
# SENT 300: ['<V;PST>', 'd', 'Z', 'I', 'N', 'g', 'l', ',']
# PRED 300: I m I N g l ,
# PRED SCORE: -2.6653
#
# [2022-03-22 12:34:03,322 INFO]
# SENT 301: ['<V;PST>', 'd', 'I', 'k', 'r', 'i', ':']
# PRED 301: d I k r i :
# PRED SCORE: -1.0540
#
# [2022-03-22 12:34:03,322 INFO]
# SENT 302: ['<V;PST>', 'b', 'r', 'O', 'I', 'l']
# PRED 302: b r e I
# PRED SCORE: -1.8997
#
# [2022-03-22 12:34:03,322 INFO]
# SENT 303: ['<V;PST>', 'V', 'n', 'd', '@', 'v', '&', 'l', 'j', 'U']
# PRED 303: V n d @ : m l
# PRED SCORE: -3.5348
#
# [2022-03-22 12:34:03,322 INFO]
# SENT 304: ['<V;PST>', 'f', 'l', 'V', 's', 't', '@', 'r', '*']
# PRED 304: a a I s t @ r *
# PRED SCORE: -1.5142
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 305: ['<V;PST>', 's', 'k', 'r', 'a', 'U', 'n', 'Z']
# PRED 305: E k r a U n d
# PRED SCORE: -1.6237
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 306: ['<V;PST>', 'b', '@', 't', '@', 'U', 'k', 'n', ',']
# PRED 306: b @ t @ U k n ,
# PRED SCORE: -2.0857
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 307: ['<V;PST>', 'b', '@', 'h', 'e', 'I', 'v']
# PRED 307: r r e g
# PRED SCORE: -1.9078
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 308: ['<V;PST>', 's', 'V', 'l', 'k']
# PRED 308: E m l k
# PRED SCORE: -2.6058
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 309: ['<V;PST>', 'k', '@', 'n', 'f', 'E', 's']
# PRED 309: k @ n p E s
# PRED SCORE: -2.2019
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 310: ['<V;PST>', 'T', 'I', 'N', 'k']
# PRED 310: e I
# PRED SCORE: -1.1431
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 311: ['<V;PST>', '&', 's', '@', 't', 'e', 'I', 'n']
# PRED 311: & s @ t e I n
# PRED SCORE: -0.7248
#
# [2022-03-22 12:34:03,323 INFO]
# SENT 312: ['<V;PST>', 'p', 'r', '@', 'U', 'g', 'r', '&', 'm']
# PRED 312: r r e g
# PRED SCORE: -0.0750
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 313: ['<V;PST>', 'k', 'w', 'E', 'S', 't', 'S', 'n', ',']
# PRED 313: k w E v t S n ,
# PRED SCORE: -3.1524
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 314: ['<V;PST>', 'd', 'I', 'b', 'e', 'I', 't']
# PRED 314: d I b e I t
# PRED SCORE: -1.3705
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 315: ['<V;PST>', 'd', 'r', 'O', ':']
# PRED 315: I r O :
# PRED SCORE: -1.4852
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 316: ['<V;PST>', 's', 'w', 'O', 'p']
# PRED 316: s w O p
# PRED SCORE: -2.7955
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 317: ['<V;PST>', 'f', 'I', 'l', 'I', 't']
# PRED 317: a e I t
# PRED SCORE: -1.0239
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 318: ['<V;PST>', 'm', 'V', 't', '@', 'r', '*']
# PRED 318: m V t @ r *
# PRED SCORE: -1.3375
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 319: ['<V;PST>', 's', '@', 'k', 's', 'i', ':', 'd']
# PRED 319: E @ k s i : d
# PRED SCORE: -1.8949
#
# [2022-03-22 12:34:03,324 INFO]
# SENT 320: ['<V;PST>', 'g', 'l', 'V', 't']
# PRED 320: e e g
# PRED SCORE: -1.2486
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 321: ['<V;PST>', 'h', 'w', 'i', ':', 'l']
# PRED 321: V b i : l
# PRED SCORE: -2.8179
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 322: ['<V;PST>', 'p', '3', ':', 'f', '@', 'r', 'e', 'I', 't']
# PRED 322: r r e g
# PRED SCORE: -0.1339
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 323: ['<V;PST>', 'd', 'w', 'O', ':', 'f']
# PRED 323: d w O : f
# PRED SCORE: -2.5142
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 324: ['<V;PST>', 'm', 'I', 's', 'V', 'n', 'd', '@', 's', 't', '&', 'n', 'd']
# PRED 324: V I s V n d @ n d
# PRED SCORE: -3.8242
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 325: ['<V;PST>', 'p', 'i', ':', 's']
# PRED 325: r e g
# PRED SCORE: -0.1292
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 326: ['<V;PST>', 'a', 'U', 't', 'g', 'r', '@', 'U']
# PRED 326: r e g
# PRED SCORE: -0.8198
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 327: ['<V;PST>', 'r', '@', 'k', 'l', 'a', 'I', 'n']
# PRED 327: r r e g
# PRED SCORE: -0.0076
#
# [2022-03-22 12:34:03,325 INFO]
# SENT 328: ['<V;PST>', 'k', '@', 'r', '@', 'U', 'd']
# PRED 328: k @ r @ U d
# PRED SCORE: -0.9050
#
# [2022-03-22 12:34:03,326 INFO]
# SENT 329: ['<V;PST>', 'a', 'I', 's']
# PRED 329: e g
# PRED SCORE: -0.1880
#
# [2022-03-22 12:34:03,326 INFO]
# SENT 330: ['<V;PST>', 'p', 'O', 'm', 'l', ',']
# PRED 330: r r e g
# PRED SCORE: -0.4420
#
# [2022-03-22 12:34:03,369 INFO]
# SENT 331: ['<V;PST>', 'k', 'O', ':', 'n']
# PRED 331: k O : n
# PRED SCORE: -0.8536
#
# [2022-03-22 12:34:03,369 INFO]
# SENT 332: ['<V;PST>', 's', '@', 'f', 'a', 'I', 's']
# PRED 332: E @ f a I s
# PRED SCORE: -1.3077
#
# [2022-03-22 12:34:03,369 INFO]
# SENT 333: ['<V;PST>', 'v', 'O', ':', 'n', 't']
# PRED 333: O i : n t
# PRED SCORE: -1.5998
#
# [2022-03-22 12:34:03,369 INFO]
# SENT 334: ['<V;PST>', '@', 'f', 'I', 'S', 'I', 'e', 'I', 't']
# PRED 334: r r e g
# PRED SCORE: -0.3409
#
# [2022-03-22 12:34:03,369 INFO]
# SENT 335: ['<V;PST>', 'g', '@', 'U']
# PRED 335: e g
# PRED SCORE: -0.1243
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 336: ['<V;PST>', 'g', 'I', 'g', 'l', ',']
# PRED 336: e e
# PRED SCORE: -1.5642
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 337: ['<V;PST>', 's', 'k', 'E', 'd', 'Z', 'l', ',']
# PRED 337: E k E d Z l ,
# PRED SCORE: -1.5607
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 338: ['<V;PST>', 'h', 'V', 'd', 'l', ',']
# PRED 338: V d l l ,
# PRED SCORE: -1.9138
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 339: ['<V;PST>', 't', 'r', '&', 'k']
# PRED 339: t r I k
# PRED SCORE: -0.7838
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 340: ['<V;PST>', 's', '@', 'p', 'r', 'a', 'I', 'z']
# PRED 340: E @ p r a I z
# PRED SCORE: -1.1930
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 341: ['<V;PST>', 'd', 'I', 'l', 'e', 'I', 't']
# PRED 341: d I l e I t
# PRED SCORE: -0.3744
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 342: ['<V;PST>', 'I', 'm', '&', 'd', 'Z', 'n', ',']
# PRED 342: I m & d Z n ,
# PRED SCORE: -1.9672
#
# [2022-03-22 12:34:03,370 INFO]
# SENT 343: ['<V;PST>', 'g', 'r', '@', 'U', 'n']
# PRED 343: e e g
# PRED SCORE: -1.1726
#
# [2022-03-22 12:34:03,371 INFO]
# SENT 344: ['<V;PST>', 'd', 'r', 'i', ':', 'm']
# PRED 344: I r i : m
# PRED SCORE: -1.3995
#
# [2022-03-22 12:34:03,371 INFO]
# SENT 345: ['<V;PST>', 'I', 'm', 'p', '&', 'k', 't']
# PRED 345: I m p & k t
# PRED SCORE: -1.2390
#
# [2022-03-22 12:34:03,371 INFO]
# SENT 346: ['<V;PST>', 'k', 'A', ':', 't']
# PRED 346: k A : t
# PRED SCORE: -1.6707
#
# [2022-03-22 12:34:03,371 INFO]
# SENT 347: ['<V;PST>', 'r', '@', 's', 'I', 'p', 'r', 'U', 'k', 'e', 'I', 't']
# PRED 347: r r e g
# PRED SCORE: -0.0091
#
# [2022-03-22 12:34:03,371 INFO]
# SENT 348: ['<V;PST>', 'd', 'I', 'l', 'I', 'v', '@', 'r', '*']
# PRED 348: d I l I v @ r *
# PRED SCORE: -0.7879
#
# [2022-03-22 12:34:03,372 INFO]
# SENT 349: ['<V;PST>', 'd', 'I', 's', 'k', '@', 'n', 't', 'I', 'n', 'j', 'U']
# PRED 349: d I s k @ n t
# PRED SCORE: -1.5879
#
# [2022-03-22 12:34:03,372 INFO]
# SENT 350: ['<V;PST>', 'd', 'Z', 'A', ':', 'r', '*']
# PRED 350: d Z A : r *
# PRED SCORE: -2.4205
#
# [2022-03-22 12:34:03,372 INFO]
# SENT 351: ['<V;PST>', 'r', '@', 'p', 'E', 'n', 't']
# PRED 351: r r e g
# PRED SCORE: -0.0067
#
# [2022-03-22 12:34:03,372 INFO]
# SENT 352: ['<V;PST>', 'm', 'i', ':', 'd', 'I', 'e', 'I', 't']
# PRED 352: w i i : d I e I t
# PRED SCORE: -3.2715
#
# [2022-03-22 12:34:03,372 INFO]
# SENT 353: ['<V;PST>', 'p', 'r', 'a', 'I', 's']
# PRED 353: r r e g
# PRED SCORE: -0.5128
#
# [2022-03-22 12:34:03,373 INFO]
# SENT 354: ['<V;PST>', 'k', 'V', 'l', 't', 'I', 'v', 'e', 'I', 't']
# PRED 354: k V l t I v e I t
# PRED SCORE: -0.9082
#
# [2022-03-22 12:34:03,373 INFO]
# SENT 355: ['<V;PST>', 'd', 'I', 'k', 'l', 'E', '@', 'r', '*']
# PRED 355: d I k l E @ r *
# PRED SCORE: -0.9972
#
# [2022-03-22 12:34:03,373 INFO]
# SENT 356: ['<V;PST>', 's', 't', 'A', ':', 'f']
# PRED 356: s t A : f
# PRED SCORE: -2.0712
#
# [2022-03-22 12:34:03,373 INFO]
# SENT 357: ['<V;PST>', 't', 'E', 'l', 'I', 's', 'k', '@', 'U', 'p']
# PRED 357: t t E l d @ U p
# PRED SCORE: -4.0582
#
# [2022-03-22 12:34:03,373 INFO]
# SENT 358: ['<V;PST>', 'I', 'm', 'I', 't', 'e', 'I', 't']
# PRED 358: e I m t e I t
# PRED SCORE: -1.2079
#
# [2022-03-22 12:34:03,374 INFO]
# SENT 359: ['<V;PST>', 'f', 'r', 'V', 'n', 't']
# PRED 359: a r e g
# PRED SCORE: -0.4133
#
# [2022-03-22 12:34:03,374 INFO]
# SENT 360: ['<V;PST>', 's', 'E', 'n', 's', '@', 't', 'a', 'I', 'z']
# PRED 360: E E n s @ t a I z
# PRED SCORE: -2.6724
#
# [2022-03-22 12:34:03,425 INFO]
# SENT 361: ['<V;PST>', 'd', 'I', 'm']
# PRED 361: I d Z
# PRED SCORE: -0.8550
#
# [2022-03-22 12:34:03,425 INFO]
# SENT 362: ['<V;PST>', '@', 'b', '&', 'S']
# PRED 362: r r e g
# PRED SCORE: -1.1216
#
# [2022-03-22 12:34:03,425 INFO]
# SENT 363: ['<V;PST>', 't', 'E', 'l']
# PRED 363: e I
# PRED SCORE: -1.4868
#
# [2022-03-22 12:34:03,425 INFO]
# SENT 364: ['<V;PST>', 'p', 'l', 'i', ':', 't']
# PRED 364: r e g
# PRED SCORE: -0.5020
#
# [2022-03-22 12:34:03,425 INFO]
# SENT 365: ['<V;PST>', 'r', '@', 'v', '@', 'U', 'k']
# PRED 365: r r e g
# PRED SCORE: -0.0066
#
# [2022-03-22 12:34:03,425 INFO]
# SENT 366: ['<V;PST>', 'd', 'I', 'p']
# PRED 366: I d
# PRED SCORE: -0.5060
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 367: ['<V;PST>', 'm', '@', 'U']
# PRED 367: V m
# PRED SCORE: -1.4641
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 368: ['<V;PST>', 'd', 'w', 'I', 'n', 'd', 'l', ',']
# PRED 368: d a I n d l ,
# PRED SCORE: -2.3335
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 369: ['<V;PST>', 'b', 'r', 'u', ':', 'd']
# PRED 369: r e g
# PRED SCORE: -1.8350
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 370: ['<V;PST>', 'd', 'r', 'a', 'I', 'v']
# PRED 370: I r a I v
# PRED SCORE: -1.2968
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 371: ['<V;PST>', 'd', 'O', ':', 'n']
# PRED 371: d O : n
# PRED SCORE: -1.5715
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 372: ['<V;PST>', 't', 'r', 'e', 'I', 'n']
# PRED 372: t r e I n
# PRED SCORE: -0.4054
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 373: ['<V;PST>', 'p', '&', 'n', 'd', '@', 'r', '*']
# PRED 373: r r e g
# PRED SCORE: -0.1568
#
# [2022-03-22 12:34:03,426 INFO]
# SENT 374: ['<V;PST>', 'k', '@', 'n', 's', 'p', 'a', 'I', '@', 'r', '*']
# PRED 374: k @ @ n s p a I r
# PRED SCORE: -3.4681
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 375: ['<V;PST>', 's', '3', ':', 'k', '@', 'm', 's', 'k', 'r', 'a', 'I', 'b']
# PRED 375: E b 3 : k @ s r a I z
# PRED SCORE: -5.8697
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 376: ['<V;PST>', 't', 'S', 'e', 'I', 'f']
# PRED 376: t E g I f
# PRED SCORE: -1.6500
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 377: ['<V;PST>', 'k', 'l', '&', 's', 'I', 'f', 'a', 'I']
# PRED 377: k l & s I f a I
# PRED SCORE: -1.7052
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 378: ['<V;PST>', 'v', '&', 's', 'l', ',', 'e', 'I', 't']
# PRED 378: O & s l l e I t
# PRED SCORE: -3.0342
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 379: ['<V;PST>', 's', 'm', 'a', 'I', 't']
# PRED 379: E m a I t
# PRED SCORE: -1.4509
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 380: ['<V;PST>', 'd', 'Z', '3', ':', 'm', 'I', 'n', 'e', 'I', 't']
# PRED 380: d Z 3 : m I n e I t
# PRED SCORE: -3.0001
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 381: ['<V;PST>', 'g', 'r', 'U', 'm']
# PRED 381: e e g
# PRED SCORE: -0.4834
#
# [2022-03-22 12:34:03,427 INFO]
# SENT 382: ['<V;PST>', '@', 's', 'u', ':', 'm']
# PRED 382: r r e g
# PRED SCORE: -2.1681
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 383: ['<V;PST>', 's', '@', 'p', 'l', 'A', ':', 'n', 't']
# PRED 383: E @ p l A : n t
# PRED SCORE: -2.2186
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 384: ['<V;PST>', 't', 'S', '&', 's', 't', 'a', 'I', 'z']
# PRED 384: t t & s t a I z
# PRED SCORE: -2.7869
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 385: ['<V;PST>', 'p', 'l', 'e', 'I', 't']
# PRED 385: r e g
# PRED SCORE: -0.1115
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 386: ['<V;PST>', 'h', '&', 'm', '@', 'r', '*']
# PRED 386: h & m @ r *
# PRED SCORE: -1.9089
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 387: ['<V;PST>', 'h', 'V', 'v', '@', 'r', '*']
# PRED 387: h V v @ r *
# PRED SCORE: -1.6311
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 388: ['<V;PST>', '&', 'p', 'r', 'I', 'h', 'E', 'n', 'd']
# PRED 388: & p r I h E n d
# PRED SCORE: -1.9011
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 389: ['<V;PST>', 'd', 'I', 's', 'E', 'n', 't']
# PRED 389: d I s E n t
# PRED SCORE: -0.5976
#
# [2022-03-22 12:34:03,428 INFO]
# SENT 390: ['<V;PST>', 'I', 'n', 't', '@', 's', 'E', 'k', 't']
# PRED 390: e I t @ s E k t
# PRED SCORE: -2.7614
#
# [2022-03-22 12:34:03,460 INFO]
# SENT 391: ['<V;PST>', 's', 'k', '&', 'n', 'd', 'l', ',', 'a', 'I', 'z']
# PRED 391: E k & n d l , I z
# PRED SCORE: -3.6084
#
# [2022-03-22 12:34:03,460 INFO]
# SENT 392: ['<V;PST>', 'S', 'a', 'I', 'n']
# PRED 392: V g I n
# PRED SCORE: -1.0109
#
# [2022-03-22 12:34:03,460 INFO]
# SENT 393: ['<V;PST>', 'p', 'I', 'N']
# PRED 393: e g
# PRED SCORE: -0.3639
#
# [2022-03-22 12:34:03,460 INFO]
# SENT 394: ['<V;PST>', 'r', 'E', 'n', 'S']
# PRED 394: r r e g
# PRED SCORE: -0.6175
#
# [2022-03-22 12:34:03,460 INFO]
# SENT 395: ['<V;PST>', 'w', 'I', 'n', 'S']
# PRED 395: a e g
# PRED SCORE: -0.7447
#
# [2022-03-22 12:34:03,461 INFO]
# SENT 396: ['<V;PST>', 'd', 'r', 'E', 'd', 'Z']
# PRED 396: I r E d Z
# PRED SCORE: -1.7146
#
# [2022-03-22 12:34:03,461 INFO]
# SENT 397: ['<V;PST>', 'f', 'V', 'd', 'Z']
# PRED 397: a a g
# PRED SCORE: -1.0798
#
# [2022-03-22 12:34:03,461 INFO]
# SENT 398: ['<V;PST>', 'l', 'A', ':', 's', 't']
# PRED 398: l A : s t
# PRED SCORE: -1.9989
#
# [2022-03-22 12:34:03,461 INFO]
# SENT 399: ['<V;PST>', 'k', 'O', 'n', '@', 'U', 't']
# PRED 399: k O n @ U t
# PRED SCORE: -0.7610
#
# [2022-03-22 12:34:03,461 INFO]
# SENT 400: ['<V;PST>', 's', '3', ':', 't', 'I', 'f', 'a', 'I']
# PRED 400: E 3 : t I f a I
# PRED SCORE: -3.4027
#
# [2022-03-22 12:34:03,461 INFO]
# SENT 401: ['<V;PST>', 'p', '3', ':', 'p', 'E', 't', 'j', 'U', 'e', 'I', 't']
# PRED 401: r r e g
# PRED SCORE: -0.1055
#
# [2022-03-22 12:34:03,462 INFO]
# SENT 402: ['<V;PST>', 'd', '&', 'm', 'I', 'd', 'Z']
# PRED 402: d & m I d Z
# PRED SCORE: -1.5737
#
# [2022-03-22 12:34:03,462 INFO]
# SENT 403: ['<V;PST>', 'f', 'V', 'l', 'm', 'I', 'n', 'e', 'I', 't']
# PRED 403: a a I m I n e I t
# PRED SCORE: -1.4541
#
# [2022-03-22 12:34:03,462 INFO]
# SENT 404: ['<V;PST>', 'd', 'I', 'n', '@', 'U', 't']
# PRED 404: d I n @ U t
# PRED SCORE: -0.4660
#
# [2022-03-22 12:34:03,462 INFO] PRED AVG SCORE: -0.2811, PRED PPL: 1.3246

# %%
# !onmt_translate -model experiment_2/run/model_step_1000.pt -src experiment_1_wugs/CELEXmod.txt -output experiment_1_wugs/output1.txt -gpu 0 -verbose -beam_size 12
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 3255: ['m«lÈYn', 'm«lÈYnd', '26', 'malign', 'maligned', 'reg']
# PRED 3255: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,151 INFO]
# SENT 3256: ['m«rÈun', 'm«rÈund', '26', 'maroon', 'marooned', 'reg']
# PRED 3256: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3257: ['mÈartÕ', 'mÈartÕd', '26', 'martyr', 'martyred', 'reg']
# PRED 3257: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3258: ['mÈEn«s', 'mÈEn«st', '26', 'menace', 'menaced', 'reg']
# PRED 3258: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3259: ['mÈEnstruet', 'mÈEnstruet«d', '26', 'menstruate', 'menstruated', 'reg']
# PRED 3259: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3260: ['mIsrÈid', 'mIsrÈEd', '26', 'misread', 'irreg']
# PRED 3260: r r e g
# PRED SCORE: -0.3676
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3261: ['mÈÃSrum', 'mÈÃSrumd', '26', 'mushroom', 'mushroomed', 'reg']
# PRED 3261: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3262: ['nÈIknem', 'nÈIknemd', '26', 'nickname', 'nicknamed', 'reg']
# PRED 3262: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3263: ['ovÕrÈul', 'ovÕrÈuld', '26', 'overrule', 'overruled', 'reg']
# PRED 3263: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,152 INFO]
# SENT 3264: ['pÈis', 'pÈist', '26', 'piece', 'pieced', 'reg']
# PRED 3264: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,153 INFO]
# SENT 3265: ['pÈatÕ', 'pÈatÕd', '26', 'potter', 'pottered', 'reg']
# PRED 3265: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,153 INFO]
# SENT 3266: ['priÈEmpt', 'priÈEmpt«d', '26', 'pre-empt', 'pre-empted', 'reg']
# PRED 3266: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,153 INFO]
# SENT 3267: ['kwÈori', 'kwÈorid', '26', 'quarry', 'quarried', 'reg']
# PRED 3267: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,153 INFO]
# SENT 3268: ['rIlÈEnt', 'rIlÈEnt«d', '26', 'relent', 'relented', 'reg']
# PRED 3268: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,153 INFO]
# SENT 3269: ['rÈuZ', 'rÈuZd', '26', 'rouge', 'rouged', 'reg']
# PRED 3269: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,153 INFO]
# SENT 3270: ['sÈim', 'sÈimd', '26', 'seam', 'seamed', 'reg']
# PRED 3270: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,182 INFO]
# SENT 3271: ['stÈIgm«tYz', 'stÈIgm«tYzd', '26', 'stigmatize', 'stigmatized', 'reg']
# PRED 3271: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3272: ['stÈÃltIfY', 'stÈÃltIfYd', '26', 'stultify', 'stultified', 'reg']
# PRED 3272: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3273: ['s«fjÈuz', 's«fjÈuzd', '26', 'suffuse', 'suffused', 'reg']
# PRED 3273: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3274: ['swÈun', 'swÈund', '26', 'swoon', 'swooned', 'reg']
# PRED 3274: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3275: ['tÈi', 'tÈid', '26', 'tee', 'teed', 'reg']
# PRED 3275: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3276: ['trQnskrÈYb', 'trQnskrÈYbd', '26', 'transcribe', 'transcribed', 'reg']
# PRED 3276: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3277: ['trÈÃmpIt', 'trÈÃmpIt«d', '26', 'trumpet', 'trumpeted', 'reg']
# PRED 3277: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,183 INFO]
# SENT 3278: ['ÃndÕpÈe', 'ÃndÕpÈed', '26', 'underpay', 'underpaid', 'reg']
# PRED 3278: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3279: ['vÈarnIS', 'vÈarnISt', '26', 'varnish', 'varnished', 'reg']
# PRED 3279: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3280: ['vÈEntIlet', 'vÈEntIlet«d', '26', 'ventilate', 'ventilated', 'reg']
# PRED 3280: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3281: ['wÈev', 'wÈevd', '26', 'waive', 'waived', 'reg']
# PRED 3281: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3282: ['wÈUlf', 'wÈUlft', '26', 'wolf', 'wolfed', 'reg']
# PRED 3282: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3283: ['ÈQJItet', 'ÈQJItet«d', '25', 'agitate', 'agitated', 'reg']
# PRED 3283: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3284: ['Èer', 'Èerd', '25', 'air', 'aired', 'reg']
# PRED 3284: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3285: ['bÈQJÕ', 'bÈQJÕd', '25', 'badger', 'badgered', 'reg']
# PRED 3285: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,184 INFO]
# SENT 3286: ['bÈartÕ', 'bÈartÕd', '25', 'barter', 'bartered', 'reg']
# PRED 3286: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3287: ['bIdÈEv«l', 'bIdÈEv«ld', '25', 'bedevil', 'bedevilled', 'reg']
# PRED 3287: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3288: ['bIlÈigÕ', 'bIlÈigÕd', '25', 'beleaguer', 'beleaguered', 'reg']
# PRED 3288: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3289: ['bÈUldoz', 'bÈUldozd', '25', 'bulldoze', 'bulldozed', 'reg']
# PRED 3289: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3290: ['k«vÈort', 'k«vÈort«d', '25', 'cavort', 'cavorted', 'reg']
# PRED 3290: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3291: ['CÈQp', 'CÈQpt', '25', 'chap', 'chapped', 'reg']
# PRED 3291: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3292: ['CÈes«n', 'CÈes«nd', '25', 'chasten', 'chastened', 'reg']
# PRED 3292: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3293: ['sÈÕk«mskrYb', 'sÈÕk«mskrYbd', '25', 'circumscribe', 'circumscribed', 'reg']
# PRED 3293: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,185 INFO]
# SENT 3294: ['klÈÃk', 'klÈÃkt', '25', 'cluck', 'clucked', 'reg']
# PRED 3294: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,186 INFO]
# SENT 3295: ['kÈost', 'kÈost«d', '25', 'coast', 'coasted', 'reg']
# PRED 3295: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,186 INFO]
# SENT 3296: ['k«lÈEktIvYz', 'k«lÈEktIvYzd', '25', 'collectivize', 'collectivized', 'reg']
# PRED 3296: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,186 INFO]
# SENT 3297: ['k«nskrÈIpt', 'k«nskrÈIpt«d', '25', 'conscript', 'conscripted', 'reg']
# PRED 3297: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,186 INFO]
# SENT 3298: ['kantr«vÈin', 'kantr«vÈind', '25', 'contravene', 'contravened', 'reg']
# PRED 3298: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,186 INFO]
# SENT 3299: ['dIlÈIniet', 'dIlÈIniet«d', '25', 'delineate', 'delineated', 'reg']
# PRED 3299: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,186 INFO]
# SENT 3300: ['dirÈYd', 'dirÈYd«d', '25', 'deride', 'derided', 'reg']
# PRED 3300: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,215 INFO]
# SENT 3301: ['dIsIntÈQNg«l', 'dIsIntÈQNg«ld', '25', 'disentangle', 'disentangled', 'reg']
# PRED 3301: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3302: ['dIshÈart«n', 'dIshÈart«nd', '25', 'dishearten', 'disheartened', 'reg']
# PRED 3302: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3303: ['drÈ\x8dl', 'drÈ\x8dld', '25', 'drawl', 'drawled', 'reg']
# PRED 3303: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3304: ['ÈEdi', 'ÈEdid', '25', 'eddy', 'eddied', 'reg']
# PRED 3304: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3305: ['ImÈeSiet', 'ImÈeSiet«d', '25', 'emaciate', 'emaciated', 'reg']
# PRED 3305: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3306: ['ImbÈ\x8ds', 'ImbÈ\x8dst', '25', 'emboss', 'embossed', 'reg']
# PRED 3306: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3307: ['InfÈold', 'InfÈold«d', '25', 'enfold', 'enfolded', 'reg']
# PRED 3307: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,216 INFO]
# SENT 3308: ['InskÈans', 'InskÈanst', '25', 'ensconce', 'ensconced', 'reg']
# PRED 3308: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3309: ['frÈik', 'frÈikt', '25', 'freak', 'freaked', 'reg']
# PRED 3309: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3310: ['IntÈÕn«lYz', 'IntÈÕn«lYzd', '25', 'internalize', 'internalized', 'reg']
# PRED 3310: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3311: ['lÈEvÕ', 'lÈEvÕd', '25', 'lever', 'levered', 'reg']
# PRED 3311: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3312: ['lÈab', 'lÈabd', '25', 'lob', 'lobbed', 'reg']
# PRED 3312: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3313: ['mIstrÈÃst', 'mIstrÈÃst«d', '25', 'mistrust', 'mistrusted', 'reg']
# PRED 3313: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3314: ['nÈQvIget', 'nÈQvIget«d', '25', 'navigate', 'navigated', 'reg']
# PRED 3314: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3315: ['ovÕstÈet', 'ovÕstÈet«d', '25', 'overstate', 'overstated', 'reg']
# PRED 3315: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,217 INFO]
# SENT 3316: ['pÈepÕ', 'pÈepÕd', '25', 'paper', 'papered', 'reg']
# PRED 3316: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3317: ['pÈEd«l', 'pÈEd«ld', '25', 'peddle', 'peddled', 'reg']
# PRED 3317: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3318: ['pjUrÈe', 'pjUrÈed', '25', 'puree', 'pureed', 'reg']
# PRED 3318: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3319: ['kwÈevÕ', 'kwÈevÕd', '25', 'quaver', 'quavered', 'reg']
# PRED 3319: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3320: ['kwÈEnC', 'kwÈEnCt', '25', 'quench', 'quenched', 'reg']
# PRED 3320: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3321: ['kwÈEst', 'kwÈEst«d', '25', 'quest', 'quested', 'reg']
# PRED 3321: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3322: ['riprÈInt', 'riprÈInt«d', '25', 'reprint', 'reprinted', 'reg']
# PRED 3322: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3323: ['rÈuf', 'rÈuft', '25', 'roof', 'roofed', 'reg']
# PRED 3323: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,218 INFO]
# SENT 3324: ['skrÈWnJ', 'skrÈWnJd', '25', 'scrounge', 'scrounged', 'reg']
# PRED 3324: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,219 INFO]
# SENT 3325: ['skÈÃd', 'skÈÃd«d', '25', 'scud', 'scudded', 'reg']
# PRED 3325: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,219 INFO]
# SENT 3326: ['sÈid', 'sÈid«d', '25', 'seed', 'seeded', 'reg']
# PRED 3326: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,219 INFO]
# SENT 3327: ['SÈEpÕd', 'SÈEpÕd«d', '25', 'shepherd', 'shepherded', 'reg']
# PRED 3327: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,219 INFO]
# SENT 3328: ['SÈUS', 'SÈUSt', '25', 'shush', 'shushed', 'reg']
# PRED 3328: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,219 INFO]
# SENT 3329: ['snÈYp', 'snÈYpt', '25', 'snipe', 'sniped', 'reg']
# PRED 3329: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,219 INFO]
# SENT 3330: ['sprEdÈig«l', 'sprEdÈig«ld', '25', 'spreadeagle', 'spreadeagled', 'reg']
# PRED 3330: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,248 INFO]
# SENT 3331: ['ÃndÕrÈYt', 'ÃndÕrÈot', '25', 'underwrite', 'underwrote', 'irreg']
# PRED 3331: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,248 INFO]
# SENT 3332: ['vÈWCsef', 'vÈWCseft', '25', 'vouchsafe', 'vouchsafed', 'reg']
# PRED 3332: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,248 INFO]
# SENT 3333: ['CÈamp', 'CÈampt', '24', 'chomp', 'chomped', 'reg']
# PRED 3333: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,248 INFO]
# SENT 3334: ['kÈasIt', 'kÈasIt«d', '24', 'cosset', 'cosseted', 'reg']
# PRED 3334: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,248 INFO]
# SENT 3335: ['kÈÕtsi', 'kÈÕtsid', '24', 'curtsy', 'curtsied', 'reg']
# PRED 3335: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3336: ['dIzÈIst', 'dIzÈIst«d', '24', 'desist', 'desisted', 'reg']
# PRED 3336: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3337: ['dIsklÈem', 'dIsklÈemd', '24', 'disclaim', 'disclaimed', 'reg']
# PRED 3337: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3338: ['dÈIC', 'dÈICt', '24', 'ditch', 'ditched', 'reg']
# PRED 3338: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3339: ['dÈaktÕ', 'dÈaktÕd', '24', 'doctor', 'doctored', 'reg']
# PRED 3339: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3340: ['dÈud«l', 'dÈud«ld', '24', 'doodle', 'doodled', 'reg']
# PRED 3340: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3341: ['drÈEJ', 'drÈEJd', '24', 'dredge', 'dredged', 'reg']
# PRED 3341: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,249 INFO]
# SENT 3342: ['dÈu«l', 'dÈu«ld', '24', 'duel', 'duelled', 'reg']
# PRED 3342: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3343: ['InÈum«ret', 'InÈum«ret«d', '24', 'enumerate', 'enumerated', 'reg']
# PRED 3343: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3344: ['IkstÈÕn«lYz', 'IkstÈÕn«lYzd', '24', 'externalize', 'externalized', 'reg']
# PRED 3344: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3345: ['fÈQbrIket', 'fÈQbrIket«d', '24', 'fabricate', 'fabricated', 'reg']
# PRED 3345: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3346: ['flÈWt', 'flÈWt«d', '24', 'flout', 'flouted', 'reg']
# PRED 3346: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3347: ['fÈÕDÕ', 'fÈÕDÕd', '24', 'further', 'furthered', 'reg']
# PRED 3347: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3348: ['JÈÕm«net', 'JÈÕm«net«d', '24', 'germinate', 'germinated', 'reg']
# PRED 3348: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3349: ['glÈ\x8ds', 'glÈ\x8dst', '24', 'gloss', 'glossed', 'reg']
# PRED 3349: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,250 INFO]
# SENT 3350: ['hÈÃmb«l', 'hÈÃmb«ld', '24', 'humble', 'humbled', 'reg']
# PRED 3350: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3351: ['InvÈQlIdet', 'InvÈQlIdet«d', '24', 'invalidate', 'invalidated', 'reg']
# PRED 3351: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3352: ['mÈQnIkjUr', 'mÈQnIkjUrd', '24', 'manicure', 'manicured', 'reg']
# PRED 3352: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3353: ['mÈES', 'mÈESt', '24', 'mesh', 'meshed', 'reg']
# PRED 3353: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3354: ['mÈÃl', 'mÈÃld', '24', 'mull', 'mulled', 'reg']
# PRED 3354: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3355: ['ovÕlÈe', 'ovÕlÈed', '24', 'overlay', 'overlaid', 'reg']
# PRED 3355: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3356: ['pÈYn', 'pÈYnd', '24', 'pine', 'pined', 'reg']
# PRED 3356: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3357: ['pÈIv«t', 'pÈIv«t«d', '24', 'pivot', 'pivoted', 'reg']
# PRED 3357: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,251 INFO]
# SENT 3358: ['plÈit', 'plÈit«d', '24', 'pleat', 'pleated', 'reg']
# PRED 3358: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,252 INFO]
# SENT 3359: ['rÈibWnd', 'rÈibWnd«d', '24', 'rebound', 'rebounded', 'reg']
# PRED 3359: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,252 INFO]
# SENT 3360: ['rIgrÈEs', 'rIgrÈEst', '24', 'regress', 'regressed', 'reg']
# PRED 3360: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,280 INFO]
# SENT 3361: ['rIlÈQps', 'rIlÈQpst', '24', 'relapse', 'relapsed', 'reg']
# PRED 3361: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,280 INFO]
# SENT 3362: ['rÈYf«l', 'rÈYf«ld', '24', 'rifle', 'rifled', 'reg']
# PRED 3362: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3363: ['rÈIvIt', 'rÈIvIt«d', '24', 'rivet', 'riveted', 'reg']
# PRED 3363: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3364: ['SrÈIl', 'SrÈIld', '24', 'shrill', 'shrilled', 'reg']
# PRED 3364: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3365: ['snÈIv«l', 'snÈIv«ld', '24', 'snivel', 'snivelled', 'reg']
# PRED 3365: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3366: ['sÈad', 'sÈad«d', '24', 'sod', 'reg']
# PRED 3366: r r e g
# PRED SCORE: -0.3676
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3367: ['spÈe', 'spÈed', '24', 'spay', 'spayed', 'reg']
# PRED 3367: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3368: ['stÈIl', 'stÈIld', '24', 'still', 'stilled', 'reg']
# PRED 3368: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3369: ['sÈINkr«nYz', 'sÈINkr«nYzd', '24', 'synchronize', 'synchronized', 'reg']
# PRED 3369: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,281 INFO]
# SENT 3370: ['tÈÃf«n', 'tÈÃf«nd', '24', 'toughen', 'toughened', 'reg']
# PRED 3370: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3371: ['trQnsfÈIgjÕ', 'trQnsfÈIgjÕd', '24', 'transfigure', 'transfigured', 'reg']
# PRED 3371: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3372: ['trQnspÈoz', 'trQnspÈozd', '24', 'transpose', 'transposed', 'reg']
# PRED 3372: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3373: ['tÈÃn«l', 'tÈÃn«ld', '24', 'tunnel', 'tunnelled', 'reg']
# PRED 3373: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3374: ['twÈQN', 'twÈQNd', '24', 'twang', 'twanged', 'reg']
# PRED 3374: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3375: ['ÃnmÈQsk', 'ÃnmÈQskt', '24', 'unmask', 'unmasked', 'reg']
# PRED 3375: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3376: ['wÈiri', 'wÈirid', '24', 'weary', 'wearied', 'reg']
# PRED 3376: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,282 INFO]
# SENT 3377: ['wÈIg«l', 'wÈIg«ld', '24', 'wiggle', 'wiggled', 'reg']
# PRED 3377: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3378: ['rÈik', 'rÈikt', '24', 'wreak', 'wreaked', 'reg']
# PRED 3378: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3379: ['QbsÈEnt', 'QbsÈEnt«d', '23', 'absent', 'absented', 'reg']
# PRED 3379: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3380: ['QbstrÈQkt', 'QbstrÈQkt«d', '23', 'abstract', 'abstracted', 'reg']
# PRED 3380: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3381: ['«kÈÃst«m', '«kÈÃst«md', '23', 'accustom', 'accustomed', 'reg']
# PRED 3381: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3382: ['bÈQndi', 'bÈQndid', '23', 'bandy', 'bandied', 'reg']
# PRED 3382: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3383: ['bIgÈYl', 'bIgÈYld', '23', 'beguile', 'beguiled', 'reg']
# PRED 3383: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3384: ['bÈIkÕ', 'bÈIkÕd', '23', 'bicker', 'bickered', 'reg']
# PRED 3384: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,283 INFO]
# SENT 3385: ['bÈot', 'bÈot«d', '23', 'boat', 'boated', 'reg']
# PRED 3385: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,284 INFO]
# SENT 3386: ['bÈod', 'bÈod«d', '23', 'bode', 'boded', 'reg']
# PRED 3386: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,284 INFO]
# SENT 3387: ['bÈaC', 'bÈaCt', '23', 'botch', 'botched', 'reg']
# PRED 3387: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,284 INFO]
# SENT 3388: ['kÈQnt', 'kÈQnt«d', '23', 'cant', 'canted', 'reg']
# PRED 3388: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,284 INFO]
# SENT 3389: ['kÈepÕ', 'kÈepÕd', '23', 'caper', 'capered', 'reg']
# PRED 3389: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,284 INFO]
# SENT 3390: ['klÈak', 'klÈakt', '23', 'clock', 'clocked', 'reg']
# PRED 3390: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,316 INFO]
# SENT 3391: ['koÈapt', 'koÈapt«d', '23', 'co-opt', 'co-opted', 'reg']
# PRED 3391: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,316 INFO]
# SENT 3392: ['kam«ndÈir', 'kam«ndÈird', '23', 'commandeer', 'commandeered', 'reg']
# PRED 3392: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,317 INFO]
# SENT 3393: ['kroSÈe', 'kroSÈed', '23', 'crochet', 'crocheted', 'reg']
# PRED 3393: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,317 INFO]
# SENT 3394: ['krusÈed', 'krusÈed«d', '23', 'crusade', 'crusaded', 'reg']
# PRED 3394: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,317 INFO]
# SENT 3395: ['dÈen', 'dÈend', '23', 'deign', 'deigned', 'reg']
# PRED 3395: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,317 INFO]
# SENT 3396: ['dimÈot', 'dimÈot«d', '23', 'demote', 'demoted', 'reg']
# PRED 3396: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,317 INFO]
# SENT 3397: ['dÈEsIkret', 'dÈEsIkret«d', '23', 'desecrate', 'desecrated', 'reg']
# PRED 3397: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,317 INFO]
# SENT 3398: ['dÈIsloket', 'dÈIsloket«d', '23', 'dislocate', 'dislocated', 'reg']
# PRED 3398: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3399: ['dIsÈori«nt', 'dIsÈori«nt«d', '23', 'disorient', 'disoriented', 'reg']
# PRED 3399: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3400: ['InTrÈ\x8dl', 'InTrÈ\x8dld', '23', 'enthral', 'enthralled', 'reg']
# PRED 3400: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3401: ['InvÈIZ«n', 'InvÈIZ«nd', '23', 'envision', 'envisioned', 'reg']
# PRED 3401: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3402: ['IgzÈan«ret', 'IgzÈan«ret«d', '23', 'exonerate', 'exonerated', 'reg']
# PRED 3402: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3403: ['flÈÃdlYt', 'flÈÃdlYt«d', '23', 'floodlight', 'floodlighted', 'reg']
# PRED 3403: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3404: ['forSÈQdo', 'forSÈQdod', '23', 'foreshadow', 'foreshadowed', 'reg']
# PRED 3404: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,318 INFO]
# SENT 3405: ['hÈer', 'hÈerd', '23', 'hare', 'hared', 'reg']
# PRED 3405: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3406: ['IntÕmÈINg«l', 'IntÕmÈINg«ld', '23', 'intermingle', 'intermingled', 'reg']
# PRED 3406: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3407: ['WtflÈQNk', 'WtflÈQNkt', '23', 'outflank', 'outflanked', 'reg']
# PRED 3407: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3408: ['ovÕrÈet', 'ovÕrÈet«d', '23', 'overrate', 'overrated', 'reg']
# PRED 3408: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3409: ['priÈakjUpY', 'priÈakjUpYd', '23', 'preoccupy', 'preoccupied', 'reg']
# PRED 3409: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3410: ['prÈES«rYz', 'prÈES«rYzd', '23', 'pressurize', 'pressurized', 'reg']
# PRED 3410: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3411: ['prÈIk«l', 'prÈIk«ld', '23', 'prickle', 'prickled', 'reg']
# PRED 3411: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3412: ['rEk«nÈOtÕ', 'rEk«nÈOtÕd', '23', 'reconnoitre', 'reconnoitred', 'reg']
# PRED 3412: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,319 INFO]
# SENT 3413: ['rIkÈup', 'rIkÈupt', '23', 'recoup', 'recouped', 'reg']
# PRED 3413: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,320 INFO]
# SENT 3414: ['rÈIm', 'rÈImd', '23', 'rim', 'rimmed', 'reg']
# PRED 3414: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,320 INFO]
# SENT 3415: ['skÈim', 'skÈimd', '23', 'scheme', 'schemed', 'reg']
# PRED 3415: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,320 INFO]
# SENT 3416: ['skÈul', 'skÈuld', '23', 'school', 'schooled', 'reg']
# PRED 3416: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,320 INFO]
# SENT 3417: ['skÈut', 'skÈut«d', '23', 'scoot', 'scooted', 'reg']
# PRED 3417: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,320 INFO]
# SENT 3418: ['skÈY', 'skÈYd', '23', 'sky', 'skied', 'reg']
# PRED 3418: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,320 INFO]
# SENT 3419: ['splÈe', 'splÈed', '23', 'splay', 'splayed', 'reg']
# PRED 3419: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,321 INFO]
# SENT 3420: ['skwÈElC', 'skwÈElCt', '23', 'squelch', 'squelched', 'reg']
# PRED 3420: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3421: ['stÈQS', 'stÈQSt', '23', 'stash', 'stashed', 'reg']
# PRED 3421: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3422: ['s«bsÈum', 's«bsÈumd', '23', 'subsume', 'subsumed', 'reg']
# PRED 3422: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3423: ['tÈIl', 'tÈIld', '23', 'till', 'tilled', 'reg']
# PRED 3423: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3424: ['tÈad«l', 'tÈad«ld', '23', 'toddle', 'toddled', 'reg']
# PRED 3424: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3425: ['tÈon', 'tÈond', '23', 'tone', 'toned', 'reg']
# PRED 3425: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3426: ['torpÈido', 'torpÈidod', '23', 'torpedo', 'torpedoed', 'reg']
# PRED 3426: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,350 INFO]
# SENT 3427: ['ÃndÕvÈQlju', 'ÃndÕvÈQljud', '23', 'undervalue', 'undervalued', 'reg']
# PRED 3427: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3428: ['ÃnfÈÕl', 'ÃnfÈÕld', '23', 'unfurl', 'unfurled', 'reg']
# PRED 3428: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3429: ['ÃnhÈUk', 'ÃnhÈUkt', '23', 'unhook', 'unhooked', 'reg']
# PRED 3429: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3430: ['vÈEst', 'vÈEst«d', '23', 'vest', 'vested', 'reg']
# PRED 3430: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3431: ['wÈIni', 'wÈInid', '23', 'whinny', 'whinnied', 'reg']
# PRED 3431: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3432: ['«klÈYm«tYz', '«klÈYm«tYzd', '22', 'acclimatize', 'acclimatized', 'reg']
# PRED 3432: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3433: ['Èep', 'Èept', '22', 'ape', 'aped', 'reg']
# PRED 3433: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3434: ['blÈÃbÕ', 'blÈÃbÕd', '22', 'blubber', 'blubbered', 'reg']
# PRED 3434: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,351 INFO]
# SENT 3435: ['kÈQntÕ', 'kÈQntÕd', '22', 'canter', 'cantered', 'reg']
# PRED 3435: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3436: ['CÈ\x8dk', 'CÈ\x8dkt', '22', 'chalk', 'chalked', 'reg']
# PRED 3436: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3437: ['krÈanIk«l', 'krÈanIk«ld', '22', 'chronicle', 'chronicled', 'reg']
# PRED 3437: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3438: ['klÈWn', 'klÈWnd', '22', 'clown', 'clowned', 'reg']
# PRED 3438: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3439: ['dIkÈQpItet', 'dIkÈQpItet«d', '22', 'decapitate', 'decapitated', 'reg']
# PRED 3439: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3440: ['dÈEsImet', 'dÈEsImet«d', '22', 'decimate', 'decimated', 'reg']
# PRED 3440: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3441: ['IstrÈenJ', 'IstrÈenJd', '22', 'estrange', 'estranged', 'reg']
# PRED 3441: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3442: ['IgzÈ\x8dlt', 'IgzÈ\x8dlt«d', '22', 'exalt', 'exalted', 'reg']
# PRED 3442: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,352 INFO]
# SENT 3443: ['gÈarb«l', 'gÈarb«ld', '22', 'garble', 'garbled', 'reg']
# PRED 3443: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3444: ['hÈQzÕd', 'hÈQzÕd«d', '22', 'hazard', 'hazarded', 'reg']
# PRED 3444: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3445: ['hÈÃNgÕ', 'hÈÃNgÕd', '22', 'hunger', 'hungered', 'reg']
# PRED 3445: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3446: ['ImpÈÕs«net', 'ImpÈÕs«net«d', '22', 'impersonate', 'impersonated', 'reg']
# PRED 3446: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3447: ['ImpÈWnd', 'ImpÈWnd«d', '22', 'impound', 'impounded', 'reg']
# PRED 3447: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3448: ['InfrÈInJ', 'InfrÈInJd', '22', 'infringe', 'infringed', 'reg']
# PRED 3448: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3449: ['mIsfÈYÕ', 'mIsfÈYÕd', '22', 'misfire', 'misfired', 'reg']
# PRED 3449: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,353 INFO]
# SENT 3450: ['mÈortIfY', 'mÈortIfYd', '22', 'mortify', 'mortified', 'reg']
# PRED 3450: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,382 INFO]
# SENT 3451: ['È\x8dstr«sYz', 'È\x8dstr«sYzd', '22', 'ostracize', 'ostracized', 'reg']
# PRED 3451: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,382 INFO]
# SENT 3452: ['kwÈaS', 'kwÈaSt', '22', 'quash', 'quashed', 'reg']
# PRED 3452: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,382 INFO]
# SENT 3453: ['rÈQvIS', 'rÈQvISt', '22', 'ravish', 'ravished', 'reg']
# PRED 3453: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,382 INFO]
# SENT 3454: ['rikÈInd«l', 'rikÈInd«ld', '22', 'rekindle', 'rekindled', 'reg']
# PRED 3454: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,382 INFO]
# SENT 3455: ['rIpÈÃls', 'rIpÈÃlst', '22', 'repulse', 'repulsed', 'reg']
# PRED 3455: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3456: ['slÈag', 'slÈagd', '22', 'slog', 'slogged', 'reg']
# PRED 3456: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3457: ['smÈElt', 'smÈElt«d', '22', 'smelt', 'smelted', 'reg']
# PRED 3457: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3458: ['sÈoJÕn', 'sÈoJÕnd', '22', 'sojourn', 'sojourned', 'reg']
# PRED 3458: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3459: ['sÈadÕ', 'sÈadÕd', '22', 'solder', 'soldered', 'reg']
# PRED 3459: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3460: ['spÈirhEd', 'spÈirhEd«d', '22', 'spearhead', 'spearheaded', 'reg']
# PRED 3460: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3461: ['sprÈen', 'sprÈend', '22', 'sprain', 'sprained', 'reg']
# PRED 3461: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,383 INFO]
# SENT 3462: ['stÈakpYl', 'stÈakpYld', '22', 'stockpile', 'stockpiled', 'reg']
# PRED 3462: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3463: ['sÈÃblImet', 'sÈÃblImet«d', '22', 'sublimate', 'sublimated', 'reg']
# PRED 3463: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3464: ['sÈÃp', 'sÈÃpt', '22', 'sup', 'supped', 'reg']
# PRED 3464: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3465: ['«tÈEnjuet', '«tÈEnjuet«d', '21', 'attenuate', 'attenuated', 'reg']
# PRED 3465: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3466: ['bÈIC', 'bÈICt', '21', 'bitch', 'bitched', 'reg']
# PRED 3466: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3467: ['blÈYndfold', 'blÈYndfold«d', '21', 'blindfold', 'blindfolded', 'reg']
# PRED 3467: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3468: ['bÈat«lfid', 'bÈat«lfEd', '21', 'bottle-feed', 'bottle-fed', 'irreg']
# PRED 3468: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3469: ['brÈYd«l', 'brÈYd«ld', '21', 'bridle', 'bridled', 'reg']
# PRED 3469: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,384 INFO]
# SENT 3470: ['bÈÃNg«l', 'bÈÃNg«ld', '21', 'bungle', 'bungled', 'reg']
# PRED 3470: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3471: ['bÈÕnIS', 'bÈÕnISt', '21', 'burnish', 'burnished', 'reg']
# PRED 3471: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3472: ['bÈÃs', 'bÈÃst', '21', 'bus', 'bused', 'reg']
# PRED 3472: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3473: ['dIpÈoz', 'dIpÈozd', '21', 'depose', 'deposed', 'reg']
# PRED 3473: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3474: ['dIsÈEnt', 'dIsÈEnt«d', '21', 'dissent', 'dissented', 'reg']
# PRED 3474: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3475: ['dÈIzi', 'dÈIzid', '21', 'dizzy', 'dizzied', 'reg']
# PRED 3475: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3476: ['ImbÈam', 'ImbÈamd', '21', 'embalm', 'embalmed', 'reg']
# PRED 3476: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3477: ['IkstrÈud', 'IkstrÈud«d', '21', 'extrude', 'extruded', 'reg']
# PRED 3477: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,385 INFO]
# SENT 3478: ['fÈerIt', 'fÈerIt«d', '21', 'ferret', 'ferreted', 'reg']
# PRED 3478: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,386 INFO]
# SENT 3479: ['fÈYn«lYz', 'fÈYn«lYzd', '21', 'finalize', 'finalized', 'reg']
# PRED 3479: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,386 INFO]
# SENT 3480: ['flÈEk', 'flÈEkt', '21', 'fleck', 'flecked', 'reg']
# PRED 3480: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,415 INFO]
# SENT 3481: ['frÈES«n', 'frÈES«nd', '21', 'freshen', 'freshened', 'reg']
# PRED 3481: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,415 INFO]
# SENT 3482: ['grÈav«l', 'grÈav«ld', '21', 'grovel', 'grovelled', 'reg']
# PRED 3482: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,415 INFO]
# SENT 3483: ['ÈYd«lYz', 'ÈYd«lYzd', '21', 'idolize', 'idolized', 'reg']
# PRED 3483: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,415 INFO]
# SENT 3484: ['IntÕpÈoz', 'IntÕpÈozd', '21', 'interpose', 'interposed', 'reg']
# PRED 3484: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3485: ['ÈÕk', 'ÈÕkt', '21', 'irk', 'irked', 'reg']
# PRED 3485: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3486: ['JÈIg«l', 'JÈIg«ld', '21', 'jiggle', 'jiggled', 'reg']
# PRED 3486: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3487: ['mÈ\x8dlt', 'mÈ\x8dlt«d', '21', 'malt', 'malted', 'reg']
# PRED 3487: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3488: ['mÈÃg', 'mÈÃgd', '21', 'mug', 'mugged', 'reg']
# PRED 3488: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3489: ['nÈQp', 'nÈQpt', '21', 'nap', 'napped', 'reg']
# PRED 3489: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3490: ['WtrÈÃn', 'WtrÈQn', '21', 'outrun', 'outran', 'irreg']
# PRED 3490: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3491: ['pÈ\x8dl', 'pÈ\x8dld', '21', 'pall', 'palled', 'reg']
# PRED 3491: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,416 INFO]
# SENT 3492: ['pÈQlpItet', 'pÈQlpItet«d', '21', 'palpitate', 'palpitated', 'reg']
# PRED 3492: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3493: ['pÈQt«nt', 'pÈQt«nt«d', '21', 'patent', 'patented', 'reg']
# PRED 3493: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3494: ['pÈik', 'pÈikt', '21', 'peak', 'peaked', 'reg']
# PRED 3494: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3495: ['pÈÕk«let', 'pÈÕk«let«d', '21', 'percolate', 'percolated', 'reg']
# PRED 3495: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3496: ['pridIspÈoz', 'pridIspÈozd', '21', 'predispose', 'predisposed', 'reg']
# PRED 3496: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3497: ['pÈÃlv«rYz', 'pÈÃlv«rYzd', '21', 'pulverize', 'pulverized', 'reg']
# PRED 3497: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3498: ['rIfrÈIJ«ret', 'rIfrÈIJ«ret«d', '21', 'refrigerate', 'refrigerated', 'reg']
# PRED 3498: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3499: ['rÈEz«net', 'rÈEz«net«d', '21', 'resonate', 'resonated', 'reg']
# PRED 3499: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,417 INFO]
# SENT 3500: ['rÈIk«Se', 'rÈIk«Sed', '21', 'ricochet', 'ricochetted', 'reg']
# PRED 3500: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3501: ['rÈYt', 'rÈYt«d', '21', 'right', 'righted', 'reg']
# PRED 3501: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3502: ['rÈamp', 'rÈampt', '21', 'romp', 'romped', 'reg']
# PRED 3502: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3503: ['skrÈYb', 'skrÈYbd', '21', 'scribe', 'scribed', 'reg']
# PRED 3503: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3504: ['skÈÃlpt', 'skÈÃlpt«d', '21', 'sculpt', 'sculpted', 'reg']
# PRED 3504: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3505: ['SÈu', 'SÈud', '21', 'shoo', 'shooed', 'reg']
# PRED 3505: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3506: ['SÈor', 'SÈord', '21', 'shore', 'shored', 'reg']
# PRED 3506: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,418 INFO]
# SENT 3507: ['sÈIlvÕ', 'sÈIlvÕd', '21', 'silver', 'silvered', 'reg']
# PRED 3507: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,419 INFO]
# SENT 3508: ['spÈQNg«l', 'spÈQNg«ld', '21', 'spangle', 'spangled', 'reg']
# PRED 3508: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,419 INFO]
# SENT 3509: ['swÈQgÕ', 'swÈQgÕd', '21', 'swagger', 'swaggered', 'reg']
# PRED 3509: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,419 INFO]
# SENT 3510: ['swÈIg', 'swÈIgd', '21', 'swig', 'swigged', 'reg']
# PRED 3510: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,452 INFO]
# SENT 3511: ['tÈItÕ', 'tÈItÕd', '21', 'titter', 'tittered', 'reg']
# PRED 3511: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,452 INFO]
# SENT 3512: ['trÈÃs', 'trÈÃst', '21', 'truss', 'trussed', 'reg']
# PRED 3512: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3513: ['ÃpstÈeJ', 'ÃpstÈeJd', '21', 'upstage', 'upstaged', 'reg']
# PRED 3513: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3514: ['wÈEt', 'wÈEt«d', '21', 'whet', 'whetted', 'reg']
# PRED 3514: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3515: ['rÈ\x8dN', 'rÈ\x8dNd', '21', 'wrong', 'wronged', 'reg']
# PRED 3515: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3516: ['jÈElp', 'jÈElpt', '21', 'yelp', 'yelped', 'reg']
# PRED 3516: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3517: ['«nÈEsT«tYz', '«nÈEsT«tYzd', '20', 'anaesthetize', 'anaesthetized', 'reg']
# PRED 3517: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3518: ['QntÈQg«nYz', 'QntÈQg«nYzd', '20', 'antagonize', 'antagonized', 'reg']
# PRED 3518: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,453 INFO]
# SENT 3519: ['bIgrÈÃJ', 'bIgrÈÃJd', '20', 'begrudge', 'begrudged', 'reg']
# PRED 3519: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3520: ['bÈuz', 'bÈuzd', '20', 'booze', 'boozed', 'reg']
# PRED 3520: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3521: ['brÈanz', 'brÈanzd', '20', 'bronze', 'bronzed', 'reg']
# PRED 3521: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3522: ['kÈor«s', 'kÈor«st', '20', 'chorus', 'chorused', 'reg']
# PRED 3522: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3523: ['klÈOstÕ', 'klÈOstÕd', '20', 'cloister', 'cloistered', 'reg']
# PRED 3523: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3524: ['kÈans«met', 'kÈans«met«d', '20', 'consummate', 'consummated', 'reg']
# PRED 3524: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3525: ['dik«mpÈoz', 'dik«mpÈozd', '20', 'decompose', 'decomposed', 'reg']
# PRED 3525: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3526: ['dÈImp«l', 'dÈImp«ld', '20', 'dimple', 'dimpled', 'reg']
# PRED 3526: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,454 INFO]
# SENT 3527: ['dIsÈeb«l', 'dIsÈeb«ld', '20', 'disable', 'disabled', 'reg']
# PRED 3527: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,455 INFO]
# SENT 3528: ['dIsgÈorJ', 'dIsgÈorJd', '20', 'disgorge', 'disgorged', 'reg']
# PRED 3528: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,455 INFO]
# SENT 3529: ['dIsInhÈerIt', 'dIsInhÈerIt«d', '20', 'disinherit', 'disinherited', 'reg']
# PRED 3529: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,455 INFO]
# SENT 3530: ['drÈWz', 'drÈWzd', '20', 'drowse', 'drowsed', 'reg']
# PRED 3530: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,455 INFO]
# SENT 3531: ['IlÈusIdet', 'IlÈusIdet«d', '20', 'elucidate', 'elucidated', 'reg']
# PRED 3531: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,455 INFO]
# SENT 3532: ['ImbÈold«n', 'ImbÈold«nd', '20', 'embolden', 'emboldened', 'reg']
# PRED 3532: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,455 INFO]
# SENT 3533: ['fÈ\x8dn', 'fÈ\x8dnd', '20', 'fawn', 'fawned', 'reg']
# PRED 3533: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3534: ['fÈIkset', 'fÈIkset«d', '20', 'fixate', 'fixated', 'reg']
# PRED 3534: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3535: ['hÈQndkÃf', 'hÈQndkÃft', '20', 'handcuff', 'handcuffed', 'reg']
# PRED 3535: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3536: ['hamÈaJ«nYz', 'hamÈaJ«nYzd', '20', 'homogenize', 'homogenized', 'reg']
# PRED 3536: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3537: ['IltrÈit', 'IltrÈit«d', '20', 'ill-treat', 'ill-treated', 'reg']
# PRED 3537: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3538: ['ImbÈYb', 'ImbÈYbd', '20', 'imbibe', 'imbibed', 'reg']
# PRED 3538: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3539: ['IntÕsÈid', 'IntÕsÈid«d', '20', 'intercede', 'interceded', 'reg']
# PRED 3539: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,456 INFO]
# SENT 3540: ['JÈIg', 'JÈIgd', '20', 'jig', 'jigged', 'reg']
# PRED 3540: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,485 INFO]
# SENT 3541: ['lÈQkÕ', 'lÈQkÕd', '20', 'lacquer', 'lacquered', 'reg']
# PRED 3541: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,485 INFO]
# SENT 3542: ['lÈaDÕ', 'lÈaDÕd', '20', 'lather', 'lathered', 'reg']
# PRED 3542: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3543: ['mIsk«nsÈiv', 'mIsk«nsÈivd', '20', 'misconceive', 'misconceived', 'reg']
# PRED 3543: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3544: ['nanplÈÃs', 'nanplÈÃst', '20', 'nonplus', 'nonplussed', 'reg']
# PRED 3544: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3545: ['«fÈISiet', '«fÈISiet«d', '20', 'officiate', 'officiated', 'reg']
# PRED 3545: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3546: ['Èorn«mEnt', 'Èorn«mEnt«d', '20', 'ornament', 'ornamented', 'reg']
# PRED 3546: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3547: ['Èorf«n', 'Èorf«nd', '20', 'orphan', 'orphaned', 'reg']
# PRED 3547: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3548: ['pÈeri', 'pÈerid', '20', 'parry', 'parried', 'reg']
# PRED 3548: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3549: ['partÈIS«n', 'partÈIS«nd', '20', 'partition', 'partitioned', 'reg']
# PRED 3549: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,486 INFO]
# SENT 3550: ['pÈIknIk', 'pÈIknIkt', '20', 'picnic', 'picnicked', 'reg']
# PRED 3550: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3551: ['plÈen', 'plÈend', '20', 'plane', 'planed', 'reg']
# PRED 3551: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3552: ['pri«rÈenJ', 'pri«rÈenJd', '20', 'prearrange', 'prearranged', 'reg']
# PRED 3552: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3553: ['pÕlÈOn', 'pÕlÈOnd', '20', 'purloin', 'purloined', 'reg']
# PRED 3553: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3554: ['rÈQsp', 'rÈQspt', '20', 'rasp', 'rasped', 'reg']
# PRED 3554: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3555: ['rilÈod', 'rilÈod«d', '20', 'reload', 'reloaded', 'reg']
# PRED 3555: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3556: ['rIsÈInd', 'rIsÈInd«d', '20', 'rescind', 'rescinded', 'reg']
# PRED 3556: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,487 INFO]
# SENT 3557: ['risÈEt«l', 'risÈEt«ld', '20', 'resettle', 'resettled', 'reg']
# PRED 3557: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3558: ['rÈitel', 'rÈiteld', '20', 'retail', 'retailed', 'reg']
# PRED 3558: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3559: ['rÈIf«l', 'rÈIf«ld', '20', 'riffle', 'riffled', 'reg']
# PRED 3559: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3560: ['rÈÃt', 'rÈÃt«d', '20', 'rut', 'rutted', 'reg']
# PRED 3560: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3561: ['sÈQNktIfY', 'sÈQNktIfYd', '20', 'sanctify', 'sanctified', 'reg']
# PRED 3561: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3562: ['skÈÃlpCÕ', 'skÈÃlpCÕd', '20', 'sculpture', 'sculptured', 'reg']
# PRED 3562: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3563: ['SÈu', 'SÈud', '20', 'shoe', 'shod', 'reg']
# PRED 3563: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3564: ['sÈYdtrQk', 'sÈYdtrQkt', '20', 'sidetrack', 'sidetracked', 'reg']
# PRED 3564: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,488 INFO]
# SENT 3565: ['spÈar', 'spÈard', '20', 'spar', 'sparred', 'reg']
# PRED 3565: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,489 INFO]
# SENT 3566: ['stÈEns«l', 'stÈEns«ld', '20', 'stencil', 'stencilled', 'reg']
# PRED 3566: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,489 INFO]
# SENT 3567: ['strÈimlYn', 'strÈimlYnd', '20', 'streamline', 'streamlined', 'reg']
# PRED 3567: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,489 INFO]
# SENT 3568: ['tÈar', 'tÈard', '20', 'tar', 'tarred', 'reg']
# PRED 3568: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,489 INFO]
# SENT 3569: ['twÈik', 'twÈikt', '20', 'tweak', 'tweaked', 'reg']
# PRED 3569: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,489 INFO]
# SENT 3570: ['ÈÃndÕskor', 'ÈÃndÕskord', '20', 'underscore', 'underscored', 'reg']
# PRED 3570: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,523 INFO]
# SENT 3571: ['ÈÕb«nYz', 'ÈÕb«nYzd', '20', 'urbanize', 'urbanized', 'reg']
# PRED 3571: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,523 INFO]
# SENT 3572: ['vÈQkjum', 'vÈQkjumd', '20', 'vacuum', 'vacuumed', 'reg']
# PRED 3572: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,523 INFO]
# SENT 3573: ['wÈal«p', 'wÈal«pt', '20', 'wallop', 'walloped', 'reg']
# PRED 3573: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,523 INFO]
# SENT 3574: ['rÈiD', 'rÈiDd', '20', 'wreathe', 'wreathed', 'reg']
# PRED 3574: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,523 INFO]
# SENT 3575: ['«bdÈÃkt', '«bdÈÃkt«d', '19', 'abduct', 'abducted', 'reg']
# PRED 3575: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3576: ['bItÈok«n', 'bItÈok«nd', '19', 'betoken', 'betokened', 'reg']
# PRED 3576: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3577: ['kÈQptIn', 'kÈQptInd', '19', 'captain', 'captained', 'reg']
# PRED 3577: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3578: ['k«kÈun', 'k«kÈund', '19', 'cocoon', 'cocooned', 'reg']
# PRED 3578: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3579: ['kÈadIfY', 'kÈadIfYd', '19', 'codify', 'codified', 'reg']
# PRED 3579: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3580: ['dÈQm', 'dÈQmd', '19', 'dam', 'dammed', 'reg']
# PRED 3580: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3581: ['dÈIgnIfY', 'dÈIgnIfYd', '19', 'dignify', 'dignified', 'reg']
# PRED 3581: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3582: ['dIsImbÈark', 'dIsImbÈarkt', '19', 'disembark', 'disembarked', 'reg']
# PRED 3582: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3583: ['dÈop', 'dÈopt', '19', 'dope', 'doped', 'reg']
# PRED 3583: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,524 INFO]
# SENT 3584: ['InTÈuz', 'InTÈuzd', '19', 'enthuse', 'enthused', 'reg']
# PRED 3584: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# SENT 3585: ['IvÈIns', 'IvÈInst', '19', 'evince', 'evinced', 'reg']
# PRED 3585: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# SENT 3586: ['IkskrÈit', 'IkskrÈit«d', '19', 'excrete', 'excreted', 'reg']
# PRED 3586: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# SENT 3587: ['frÈalIk', 'frÈalIkt', '19', 'frolic', 'frolicked', 'reg']
# PRED 3587: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# SENT 3588: ['fÈÃn«l', 'fÈÃn«ld', '19', 'funnel', 'funnelled', 'reg']
# PRED 3588: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# SENT 3589: ['gÈag«l', 'gÈag«ld', '19', 'goggle', 'goggled', 'reg']
# PRED 3589: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# SENT 3590: ['gÈor', 'gÈord', '19', 'gore', 'gored', 'reg']
# PRED 3590: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:46,525 INFO]
# ...
# PRED 4144: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,188 INFO]
# SENT 4145: ['stÈeb«l', 'stÈeb«ld', '11', 'stable', 'stabled', 'reg']
# PRED 4145: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,188 INFO]
# SENT 4146: ['tÈElIskop', 'tÈElIskopt', '11', 'telescope', 'telescoped', 'reg']
# PRED 4146: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,188 INFO]
# SENT 4147: ['ÃnsÈit', 'ÃnsÈit«d', '11', 'unseat', 'unseated', 'reg']
# PRED 4147: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4148: ['vÈQs«let', 'vÈQs«let«d', '11', 'vacillate', 'vacillated', 'reg']
# PRED 4148: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4149: ['wÈeJÕ', 'wÈeJÕd', '11', 'wager', 'wagered', 'reg']
# PRED 4149: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4150: ['wÈele', 'wÈeled', '11', 'waylay', 'waylaid', 'reg']
# PRED 4150: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4151: ['«dÈus', '«dÈust', '10', 'adduce', 'adduced', 'reg']
# PRED 4151: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4152: ['«dÈÃlt«ret', '«dÈÃlt«ret«d', '10', 'adulterate', 'adulterated', 'reg']
# PRED 4152: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4153: ['«dvÈQntIJ', '«dvÈQntIJd', '10', 'advantage', 'advantaged', 'reg']
# PRED 4153: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4154: ['«fÈIks', '«fÈIkst', '10', 'affix', 'affixed', 'reg']
# PRED 4154: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,189 INFO]
# SENT 4155: ['ÈQmortYz', 'ÈQmortYzd', '10', 'amortize', 'amortized', 'reg']
# PRED 4155: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4156: ['ÈQntIdet', 'ÈQntIdet«d', '10', 'antedate', 'antedated', 'reg']
# PRED 4156: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4157: ['«rÈen', '«rÈend', '10', 'arraign', 'arraigned', 'reg']
# PRED 4157: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4158: ['ÈartIk«l', 'ÈartIk«ld', '10', 'article', 'articled', 'reg']
# PRED 4158: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4159: ['ÈQsfQlt', 'ÈQsfQlt«d', '10', 'asphalt', 'asphalted', 'reg']
# PRED 4159: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4160: ['bÈQl«t', 'bÈQl«t«d', '10', 'ballot', 'balloted', 'reg']
# PRED 4160: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4161: ['bIspÈik', 'bIspÈok', '10', 'bespeak', 'bespoke', 'irreg']
# PRED 4161: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4162: ['bItÈek', 'bItÈUk', '10', 'betake', 'betook', 'irreg']
# PRED 4162: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,190 INFO]
# SENT 4163: ['k«rÈWz', 'k«rÈWzd', '10', 'carouse', 'caroused', 'reg']
# PRED 4163: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4164: ['S«grÈIn', 'S«grÈInd', '10', 'chagrin', 'chagrined', 'reg']
# PRED 4164: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4165: ['kÈampost', 'kÈampost«d', '10', 'compost', 'composted', 'reg']
# PRED 4165: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4166: ['krÈIskr\x8ds', 'krÈIskr\x8dst', '10', 'crisscross', 'crisscrossed', 'reg']
# PRED 4166: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4167: ['kÈÃs', 'kÈÃst', '10', 'cuss', 'cussed', 'reg']
# PRED 4167: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4168: ['dÈQnd«l', 'dÈQnd«ld', '10', 'dandle', 'dandled', 'reg']
# PRED 4168: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4169: ['dIbÈark', 'dIbÈarkt', '10', 'debark', 'debarked', 'reg']
# PRED 4169: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,191 INFO]
# SENT 4170: ['dÈEbIt', 'dÈEbIt«d', '10', 'debit', 'debited', 'reg']
# PRED 4170: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,222 INFO]
# SENT 4171: ['dIkÈQmp', 'dIkÈQmpt', '10', 'decamp', 'decamped', 'reg']
# PRED 4171: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,222 INFO]
# SENT 4172: ['disÈEl«ret', 'disÈEl«ret«d', '10', 'decelerate', 'decelerated', 'reg']
# PRED 4172: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,222 INFO]
# SENT 4173: ['dIfrÈ\x8dd', 'dIfrÈ\x8dd«d', '10', 'defraud', 'defrauded', 'reg']
# PRED 4173: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,222 INFO]
# SENT 4174: ['dihÈYdret', 'dihÈYdret«d', '10', 'dehydrate', 'dehydrated', 'reg']
# PRED 4174: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,222 INFO]
# SENT 4175: ['dipÈapjUlet', 'dipÈapjUlet«d', '10', 'depopulate', 'depopulated', 'reg']
# PRED 4175: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,223 INFO]
# SENT 4176: ['dirÈel', 'dirÈeld', '10', 'derail', 'derailed', 'reg']
# PRED 4176: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,223 INFO]
# SENT 4177: ['dIsInklÈYn', 'dIsInklÈYnd', '10', 'disincline', 'disinclined', 'reg']
# PRED 4177: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,223 INFO]
# SENT 4178: ['dIsIntÈÕ', 'dIsIntÈÕd', '10', 'disinter', 'disinterred', 'reg']
# PRED 4178: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,223 INFO]
# SENT 4179: ['dÃb«lCÈEk', 'dÃb«lCÈEkt', '10', 'double-check', 'double-checked', 'reg']
# PRED 4179: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,223 INFO]
# SENT 4180: ['dÈup', 'dÈupt', '10', 'dupe', 'duped', 'reg']
# PRED 4180: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,223 INFO]
# SENT 4181: ['ImblÈez«n', 'ImblÈez«nd', '10', 'emblazon', 'emblazoned', 'reg']
# PRED 4181: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,224 INFO]
# SENT 4182: ['InkÈQmp', 'InkÈQmpt', '10', 'encamp', 'encamped', 'reg']
# PRED 4182: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,224 INFO]
# SENT 4183: ['InrÈQpCÕ', 'InrÈQpCÕd', '10', 'enrapture', 'enraptured', 'reg']
# PRED 4183: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,224 INFO]
# SENT 4184: ['InsnÈer', 'InsnÈerd', '10', 'ensnare', 'ensnared', 'reg']
# PRED 4184: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,224 INFO]
# SENT 4185: ['jÈul«JYz', 'jÈul«JYzd', '10', 'eulogize', 'eulogized', 'reg']
# PRED 4185: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,224 INFO]
# SENT 4186: ['IkspÈÃnJ', 'IkspÈÃnJd', '10', 'expunge', 'expunged', 'reg']
# PRED 4186: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,225 INFO]
# SENT 4187: ['fÈÃlmInet', 'fÈÃlmInet«d', '10', 'fulminate', 'fulminated', 'reg']
# PRED 4187: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,225 INFO]
# SENT 4188: ['gÈarl«nd', 'gÈarl«nd«d', '10', 'garland', 'garlanded', 'reg']
# PRED 4188: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,225 INFO]
# SENT 4189: ['gÈÕd«l', 'gÈÕd«ld', '10', 'girdle', 'girdled', 'reg']
# PRED 4189: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,225 INFO]
# SENT 4190: ['glÈQd«n', 'glÈQd«nd', '10', 'gladden', 'gladdened', 'reg']
# PRED 4190: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,225 INFO]
# SENT 4191: ['glÈÃt', 'glÈÃt«d', '10', 'glut', 'glutted', 'reg']
# PRED 4191: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,226 INFO]
# SENT 4192: ['grÈIt', 'grÈIt«d', '10', 'grit', 'reg']
# PRED 4192: r r e g
# PRED SCORE: -0.3676
#
# [2022-03-22 12:34:47,226 INFO]
# SENT 4193: ['hÈez', 'hÈezd', '10', 'haze', 'hazed', 'reg']
# PRED 4193: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,226 INFO]
# SENT 4194: ['ImpÈiC', 'ImpÈiCt', '10', 'impeach', 'impeached', 'reg']
# PRED 4194: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,226 INFO]
# SENT 4195: ['ImpjÈun', 'ImpjÈund', '10', 'impugn', 'impugned', 'reg']
# PRED 4195: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,226 INFO]
# SENT 4196: ['Ink«nvÈinj«ns', 'Ink«nvÈinj«nst', '10', 'inconvenience', 'inconvenienced', 'reg']
# PRED 4196: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,226 INFO]
# SENT 4197: ['InÈIS«l', 'InÈIS«ld', '10', 'initial', 'initialled', 'reg']
# PRED 4197: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,227 INFO]
# SENT 4198: ['InlÈe', 'InlÈed', '10', 'inlay', 'inlaid', 'reg']
# PRED 4198: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,227 INFO]
# SENT 4199: ['ÈInsEt', 'ÈInsEt', '10', 'inset', 'insetted', 'irreg']
# PRED 4199: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,227 INFO]
# SENT 4200: ['JÈEt', 'JÈEt«d', '10', 'jet', 'jetted', 'reg']
# PRED 4200: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,260 INFO]
# SENT 4201: ['JÃkst«pÈoz', 'JÃkst«pÈozd', '10', 'juxtapose', 'juxtaposed', 'reg']
# PRED 4201: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,260 INFO]
# SENT 4202: ['kÈin', 'kÈind', '10', 'keen', 'keened', 'reg']
# PRED 4202: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,260 INFO]
# SENT 4203: ['lÈQmInet', 'lÈQmInet«d', '10', 'laminate', 'laminated', 'reg']
# PRED 4203: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4204: ['lÈez', 'lÈezd', '10', 'laze', 'lazed', 'reg']
# PRED 4204: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4205: ['lÈEg', 'lÈEgd', '10', 'leg', 'legged', 'reg']
# PRED 4205: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4206: ['lÈIlt', 'lÈIlt«d', '10', 'lilt', 'lilted', 'reg']
# PRED 4206: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4207: ['lÈImbÕ', 'lÈImbÕd', '10', 'limber', 'limbered', 'reg']
# PRED 4207: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4208: ['mÈQn«k«l', 'mÈQn«k«ld', '10', 'manacle', 'manacled', 'reg']
# PRED 4208: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4209: ['mÈÕC«ndYz', 'mÈÕC«ndYzd', '10', 'merchandise', 'merchandised', 'reg']
# PRED 4209: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,261 INFO]
# SENT 4210: ['mÈortÕ', 'mÈortÕd', '10', 'mortar', 'mortared', 'reg']
# PRED 4210: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4211: ['mÈÃmIfY', 'mÈÃmIfYd', '10', 'mummify', 'mummified', 'reg']
# PRED 4211: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4212: ['nÈQb', 'nÈQbd', '10', 'nab', 'nabbed', 'reg']
# PRED 4212: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4213: ['nÈEt«l', 'nÈEt«ld', '10', 'nettle', 'nettled', 'reg']
# PRED 4213: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4214: ['Èoret', 'Èoret«d', '10', 'orate', 'orated', 'reg']
# PRED 4214: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4215: ['WtdÈIst«ns', 'WtdÈIst«nst', '10', 'outdistance', 'outdistanced', 'reg']
# PRED 4215: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4216: ['Wtm«nÈuvÕ', 'Wtm«nÈuvÕd', '10', 'outmanoeuvre', 'outmanoeuvred', 'reg']
# PRED 4216: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,262 INFO]
# SENT 4217: ['ovÕrIndÈÃlJ', 'ovÕrIndÈÃlJd', '10', 'over-indulge', 'over-indulged', 'reg']
# PRED 4217: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4218: ['ovÕbÈQl«ns', 'ovÕbÈQl«nst', '10', 'overbalance', 'overbalanced', 'reg']
# PRED 4218: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4219: ['ovÕrbÈÕd«n', 'ovÕrbÈÕd«nd', '10', 'overburden', 'overburdened', 'reg']
# PRED 4219: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4220: ['ovÕdrÈ\x8d', 'ovÕdrÈu', '10', 'overdraw', 'overdrew', 'irreg']
# PRED 4220: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4221: ['ovÕtÈQks', 'ovÕtÈQkst', '10', 'overtax', 'overtaxed', 'reg']
# PRED 4221: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4222: ['p«rÈol', 'p«rÈold', '10', 'parole', 'paroled', 'reg']
# PRED 4222: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4223: ['partÈIkjUlÕYz', 'partÈIkjUlÕYzd', '10', 'particularize', 'particularized', 'reg']
# PRED 4223: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,263 INFO]
# SENT 4224: ['pÈik', 'pÈikt', '10', 'pique', 'piqued', 'reg']
# PRED 4224: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,264 INFO]
# SENT 4225: ['plÈet', 'plÈet«d', '10', 'plate', 'plated', 'reg']
# PRED 4225: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,264 INFO]
# SENT 4226: ['pridÈEstIn', 'pridÈEstInd', '10', 'predestine', 'predestined', 'reg']
# PRED 4226: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,264 INFO]
# SENT 4227: ['prÈEdIket', 'prÈEdIket«d', '10', 'predicate', 'predicated', 'reg']
# PRED 4227: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,264 INFO]
# SENT 4228: ['prIvÈerIket', 'prIvÈerIket«d', '10', 'prevaricate', 'prevaricated', 'reg']
# PRED 4228: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,264 INFO]
# SENT 4229: ['prap«gÈQndYz', 'prap«gÈQndYzd', '10', 'propagandize', 'propagandized', 'reg']
# PRED 4229: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,264 INFO]
# SENT 4230: ['pjÈuk', 'pjÈukt', '10', 'puke', 'puked', 'reg']
# PRED 4230: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,290 INFO]
# SENT 4231: ['riÈQktIvet', 'riÈQktIvet«d', '10', 'reactivate', 'reactivated', 'reg']
# PRED 4231: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,290 INFO]
# SENT 4232: ['rikÈQst', 'rikÈQst«d', '10', 'recast', 'reg']
# PRED 4232: r r e g
# PRED SCORE: -0.3676
#
# [2022-03-22 12:34:47,290 INFO]
# SENT 4233: ['rIsÈEs', 'rIsÈEst', '10', 'recess', 'recessed', 'reg']
# PRED 4233: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,290 INFO]
# SENT 4234: ['ridIplÈO', 'ridIplÈOd', '10', 'redeploy', 'redeployed', 'reg']
# PRED 4234: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,290 INFO]
# SENT 4235: ['rÈandIvu', 'rÈandIvud', '10', 'rendezvous', 'rendezvoued', 'reg']
# PRED 4235: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,290 INFO]
# SENT 4236: ['rEkwIzÈIS«n', 'rEkwIzÈIS«nd', '10', 'requisition', 'requisitioned', 'reg']
# PRED 4236: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4237: ['rÈisEt', 'rÈisEt', '10', 'reset', 'irreg']
# PRED 4237: r r e g
# PRED SCORE: -0.3676
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4238: ['rIsÈÃsItet', 'rIsÈÃsItet«d', '10', 'resuscitate', 'resuscitated', 'reg']
# PRED 4238: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4239: ['ritÈul', 'ritÈuld', '10', 'retool', 'retooled', 'reg']
# PRED 4239: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4240: ['rÈÃstIket', 'rÈÃstIket«d', '10', 'rusticate', 'rusticated', 'reg']
# PRED 4240: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4241: ['sÈQlv', 'sÈQlvd', '10', 'salve', 'salved', 'reg']
# PRED 4241: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4242: ['SÈortlIst', 'SÈortlIst«d', '10', 'short-list', 'short-listed', 'reg']
# PRED 4242: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,291 INFO]
# SENT 4243: ['splÈYs', 'splÈYst', '10', 'splice', 'spliced', 'reg']
# PRED 4243: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4244: ['splÈÕJ', 'splÈÕJd', '10', 'splurge', 'splurged', 'reg']
# PRED 4244: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4245: ['swÈab', 'swÈabd', '10', 'swab', 'swabbed', 'reg']
# PRED 4245: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4246: ['swÈat', 'swÈat«d', '10', 'swot', 'swotted', 'reg']
# PRED 4246: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4247: ['tÈo', 'tÈod', '10', 'toe', 'reg']
# PRED 4247: r r e g
# PRED SCORE: -0.3676
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4248: ['trÈ\x8dl', 'trÈ\x8dld', '10', 'trawl', 'trawled', 'reg']
# PRED 4248: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4249: ['ÃndÕplÈe', 'ÃndÕplÈed', '10', 'underplay', 'underplayed', 'reg']
# PRED 4249: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,292 INFO]
# SENT 4250: ['ÃpbrÈed', 'ÃpbrÈed«d', '10', 'upbraid', 'upbraided', 'reg']
# PRED 4250: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,293 INFO]
# SENT 4251: ['vÈ\x8dnt', 'vÈ\x8dnt«d', '10', 'vaunt', 'vaunted', 'reg']
# PRED 4251: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,293 INFO]
# SENT 4252: ['vÈEJItet', 'vÈEJItet«d', '10', 'vegetate', 'vegetated', 'reg']
# PRED 4252: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,293 INFO]
# SENT 4253: ['vÈali', 'vÈalid', '10', 'volley', 'volleyed', 'reg']
# PRED 4253: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,293 INFO]
# SENT 4254: ['wÈInC', 'wÈInCt', '10', 'winch', 'winched', 'reg']
# PRED 4254: r r e g
# PRED SCORE: -0.0798
#
# [2022-03-22 12:34:47,293 INFO] PRED AVG SCORE: -0.0206, PRED PPL: 1.0208
