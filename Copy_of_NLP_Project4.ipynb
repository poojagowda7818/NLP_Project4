# %% [markdown]
# <a href="https://colab.research.google.com/github/poojagowda7818/NLP_Project4/blob/main/Copy_of_NLP_Project4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install OpenNMT-py
# Out:
# ...
#      |████████████████████████████████| 216 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 57 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 73 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 50.6 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 44.5 MB/s
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.11.0
#     Uninstalling torchtext-0.11.0:
#       Successfully uninstalled torchtext-0.11.0
# ...

# %%
# !onmt_build_vocab -config config-exp1.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-03-22 10:37:48,265 INFO] Counter vocab from 10000 samples.
# [2022-03-22 10:37:48,265 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-03-22 10:37:48,277 INFO] corpus_1's transforms: TransformPipe()
# [2022-03-22 10:37:48,381 INFO] Counters src:38
# [2022-03-22 10:37:48,381 INFO] Counters tgt:38

# %%
# !onmt_train -config config-exp1.yaml
# Out:
# [2022-03-22 10:38:03,690 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-03-22 10:38:03,690 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-03-22 10:38:03,690 INFO] Missing transforms field for valid data, set to default: [].
# [2022-03-22 10:38:03,690 INFO] Parsed 2 corpora from -data.
# [2022-03-22 10:38:03,690 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-03-22 10:38:03,691 INFO] Loading vocab from text file...
# [2022-03-22 10:38:03,691 INFO] Loading src vocabulary from experiment_1/run/example.vocab.src
# [2022-03-22 10:38:03,691 INFO] Loaded src vocab has 38 tokens.
# [2022-03-22 10:38:03,691 INFO] Loading tgt vocabulary from experiment_1/run/example.vocab.tgt
# [2022-03-22 10:38:03,691 INFO] Loaded tgt vocab has 38 tokens.
# [2022-03-22 10:38:03,691 INFO] Building fields with vocab in counters...
# [2022-03-22 10:38:03,692 INFO]  * tgt vocab size: 42.
# ...

# %%
# !onmt_translate -model experiment_1/run/model_step_1000.pt -src experiment_1/src_test.txt -output experiment_1/test-decoded.txt -gpu 0 -verbose -beam_size 12
# Out:
# [2022-03-22 10:39:09,893 INFO] Translating shard 0.
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:282: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   self._batch_index = self.topk_ids // vocab_size
# [2022-03-22 10:39:09,999 INFO]
# SENT 1: ['k', 'l', 'O', 'z', 'I', 't']
# PRED 1: k l O z I t I d
# PRED SCORE: -0.0346
#
# [2022-03-22 10:39:09,999 INFO]
# SENT 2: ['p', '@', 'U', 's', 't']
# PRED 2: p @ U s t I d
# PRED SCORE: -0.0153
#
# [2022-03-22 10:39:09,999 INFO]
# SENT 3: ['v', '&', 'l', 'j', 'U']
# PRED 3: v & l j U d
# PRED SCORE: -0.0974
#
# [2022-03-22 10:39:09,999 INFO]
# ...

# %% [markdown]
# ##Experiment_2:

# %%
# !onmt_build_vocab -config config-exp2.yaml -n_sample 10000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# path_tgt is None, it should be set unless the task is language modeling
# path_tgt is None, it should be set unless the task is language modeling
# Corpus test's weight should be given. We default it to 1 for you.
# [2022-03-22 10:43:29,617 INFO] Counter vocab from 10000 samples.
# [2022-03-22 10:43:29,617 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-03-22 10:43:29,629 INFO] corpus_1's transforms: TransformPipe()
# [2022-03-22 10:43:29,630 INFO] test's transforms: TransformPipe()
# [2022-03-22 10:43:29,734 INFO] Counters src:64
# [2022-03-22 10:43:29,734 INFO] Counters tgt:39

# %%
# !onmt_train -config config-exp2.yaml
# Out:
# [2022-03-22 10:43:35,852 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-03-22 10:43:35,852 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-03-22 10:43:35,852 INFO] Missing transforms field for valid data, set to default: [].
# [2022-03-22 10:43:35,852 WARNING] path_tgt is None, it should be set unless the task is language modeling
# [2022-03-22 10:43:35,853 INFO] Missing transforms field for test data, set to default: [].
# [2022-03-22 10:43:35,853 WARNING] path_tgt is None, it should be set unless the task is language modeling
# [2022-03-22 10:43:35,853 WARNING] Corpus test's weight should be given. We default it to 1 for you.
# [2022-03-22 10:43:35,853 INFO] Parsed 3 corpora from -data.
# [2022-03-22 10:43:35,853 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-03-22 10:43:35,853 INFO] Loading vocab from text file...
# ...

# %%
# !onmt_translate -model experiment_2/run/model_step_1000.pt -src experiment_2/src_test_tagged.txt -output experiment_2/test-decoded.txt -gpu 0 -verbose -beam_size 12
# Out:
# [2022-03-22 10:44:53,230 INFO] Translating shard 0.
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:282: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   self._batch_index = self.topk_ids // vocab_size
# [2022-03-22 10:44:53,312 INFO]
# SENT 1: ['<V;PST>', 'k', 'l', 'O', 'z', 'I', 't']
# PRED 1: k l O z I t
# PRED SCORE: -2.0570
#
# [2022-03-22 10:44:53,313 INFO]
# SENT 2: ['<V;PST>', 'p', '@', 'U', 's', 't']
# PRED 2: p @ U s t
# PRED SCORE: -0.9490
#
# [2022-03-22 10:44:53,313 INFO]
# SENT 3: ['<V;PST>', 'v', '&', 'l', 'j', 'U']
# PRED 3: w & l z
# PRED SCORE: -3.4090
#
# [2022-03-22 10:44:53,313 INFO]
# ...
